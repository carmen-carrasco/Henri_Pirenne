# %%
## Regarder les erreurs

import os
import xml.etree.ElementTree as ET
from difflib import SequenceMatcher
from evaluate import load

ground_truth_folder = "manuscript_groundtruth"
htr_folder = "manuscript_htr24"
corrected_folder = "manuscript_final"

def extract_lines_from_alto(path):
    tree = ET.parse(path)
    root = tree.getroot()
    ns = {'a': 'http://www.loc.gov/standards/alto/ns-v4#'}
    strings = root.findall(".//a:String", ns)
    return [s.attrib.get("CONTENT", "").strip() for s in strings]

def diff_chars(s1, s2):
    sm = SequenceMatcher(None, s1, s2)
    return [(tag, s1[a:b], s2[c:d]) for tag, a, b, c, d in sm.get_opcodes() if tag != 'equal']

wer = load("wer")
cer = load("cer")

files = sorted(os.listdir(ground_truth_folder))
total_lines = 0

for filename in files:
    if not filename.endswith(".xml"):
        continue

    gt_path = os.path.join(ground_truth_folder, filename)
    htr_path = os.path.join(htr_folder, filename)
    corr_path = os.path.join(corrected_folder, filename)

    gt_lines = extract_lines_from_alto(gt_path)
    htr_lines = extract_lines_from_alto(htr_path)
    corr_lines = extract_lines_from_alto(corr_path)

    for i, (gt, htr, corr) in enumerate(zip(gt_lines, htr_lines, corr_lines)):
        htr_diff = diff_chars(gt, htr)
        corr_diff = diff_chars(gt, corr)
        wer_score = wer.compute(predictions=[corr], references=[gt])
        cer_score = cer.compute(predictions=[corr], references=[gt])

        print(f" File: {filename} | Line {i+1}")
        print(f"   Ground Truth: {gt}")
        print(f"   HTR         : {htr}")
        print(f"   Dif. HTR    : {htr_diff}")
        print(f"   Corrected   : {corr}")
        print(f"   Dif. Corr   : {corr_diff}")
        print(f"   CER corr vs GT: {cer_score:.4f}, WER: {wer_score:.4f}")
        print()
        total_lines += 1
# Out:
#  File: journal1_p.157.xml | Line 1
#    Ground Truth: 157
#    HTR         : 157
#    Dif. HTR    : []
#    Corrected   : 157
#    Dif. Corr   : []
#    CER corr vs GT: 0.0000, WER: 0.0000
#
#  File: journal1_p.157.xml | Line 2
#    Ground Truth: courageusement des nouvelles de Jacques
#    HTR         : Couragemement de nouville d Joeque
#    Dif. HTR    : [('replace', 'c', 'C'), ('replace', 'us', 'm'), ('delete', 's', ''), ('replace', 'e', 'i'), ('delete', 's', ''), ('delete', 'e', ''), ('replace', 'ac', 'oe'), ('delete', 's', '')]
#    Corrected   : courageusement de nouville. Joeque
#    Dif. Corr   : [('delete', 's', ''), ('replace', 'e', 'i'), ('replace', 's de', '.'), ('replace', 'ac', 'oe'), ('delete', 's', '')]
#    CER corr vs GT: 0.2308, WER: 0.8000
#
#  File: journal1_p.157.xml | Line 3
#    Ground Truth: Comme je révasse une musique allemande passe
#    HTR         : Commi se revace uns venique albemands pari
#    Dif. HTR    : [('replace', 'e', 'i'), ('replace', 'j', 's'), ('replace', 'é', 'e'), ('replace', 'ss', 'c'), ('insert', '', 's v'), ('replace', ' mus', 'n'), ('replace', 'l', 'b'), ('replace', 'e', 's'), ('replace', 'sse', 'ri')]
#    Corrected   : Comme je révasse une musique allemande passe
#    Dif. Corr   : []
#    CER corr vs GT: 0.0000, WER: 0.0000
#
#  File: journal1_p.157.xml | Line 4
#    Ground Truth: dans la rue pour me rappeler à la réalité: qu'ils
#    HTR         : dans la me purs un reppeler à le réalité. Qu'il
#    Dif. HTR    : [('replace', 'ru', 'm'), ('delete', 'o', ''), ('insert', '', 's'), ('replace', 'me', 'un'), ('replace', 'a', 'e'), ('replace', 'à', 'à'), ('replace', 'a', 'e'), ('replace', ':', '.'), ('replace', 'q', 'Q'), ('delete', 's', '')]
#    Corrected   : dans la rue pour me rappeler à la réalité. qu'ils
#    Dif. Corr   : [('replace', ':', '.')]
#    CER corr vs GT: 0.0204, WER: 0.1000
#
#  File: journal1_p.157.xml | Line 5
#    Ground Truth: jouent. Ils ne doivent plus en avoir pour longtemps
#    HTR         : prient. Ils ne doivent plhus ee avoir pour bregtemps
#    Dif. HTR    : [('replace', 'jou', 'pri'), ('insert', '', 'h'), ('replace', 'n', 'e'), ('replace', 'lon', 'bre')]
#    Corrected   : jouent. Ils ne doivent plus en avoir pour bregtemps
#    Dif. Corr   : [('replace', 'lon', 'bre')]
#    CER corr vs GT: 0.0588, WER: 0.1111
#
#  File: journal1_p.157.xml | Line 6
#    Ground Truth: Car enfin ils sont pris entre deux murs de fer ne
#    HTR         : Car aufin il sont pris entre decex Vours de Rer in
#    Dif. HTR    : [('replace', 'en', 'au'), ('delete', 's', ''), ('replace', 'u', 'ce'), ('replace', 'm', 'Vo'), ('replace', 'f', 'R'), ('insert', '', 'i'), ('delete', 'e', '')]
#    Corrected   : Car enfin ils sont pris entre deux murs de fer ne
#    Dif. Corr   : []
#    CER corr vs GT: 0.0000, WER: 0.0000
#
#  File: journal1_p.157.xml | Line 7
#    Ground Truth: menant nulle part. Leurs hommes et leurs finances
#    HTR         : perceit mille part. Leves hommes et leure Gevairie
#    Dif. HTR    : [('replace', 'm', 'p'), ('replace', 'nan', 'rcei'), ('replace', 'nu', 'mi'), ('replace', 'ur', 've'), ('replace', 's', 'e'), ('replace', 'f', 'Geva'), ('replace', 'nanc', 'ri'), ('delete', 's', '')]
#    Corrected   : mènent nulle part. Leurs hommes et leurs finances
#    Dif. Corr   : [('insert', '', 'èn'), ('delete', 'na', '')]
#    CER corr vs GT: 0.0408, WER: 0.1250
#
#  File: journal1_p.157.xml | Line 8
#    Ground Truth: s'épuisent. Les Turcs ne font rien. Les Autrichiens se
#    HTR         : d'épérisent. Les Crus ne font rien. Les Oontrichiees le
#    Dif. HTR    : [('replace', 's', 'd'), ('replace', 'u', 'ér'), ('replace', 'T', 'Cr'), ('delete', 'rc', ''), ('replace', 'Au', 'Oon'), ('replace', 'n', 'e'), ('replace', 's', 'l')]
#    Corrected   : s'épuisent. Les Turcs ne font rien. Les Autrichiens se
#    Dif. Corr   : []
#    CER corr vs GT: 0.0000, WER: 0.0000
#
#  File: journal1_p.157.xml | Line 9
#    Ground Truth: font battre. L'opinion du monde est contre l'Al¬
#    HTR         : tont battre. L'ogrnirou de monde est contre l'It
#    Dif. HTR    : [('replace', 'f', 't'), ('replace', 'pi', 'gr'), ('insert', '', 'r'), ('replace', 'n', 'u'), ('replace', 'u', 'e'), ('replace', 'Al¬', 'It')]
#    Corrected   : font battre. L'opinion du monde est contre l'It
#    Dif. Corr   : [('replace', 'Al¬', 'It')]
#    CER corr vs GT: 0.0625, WER: 0.1250
#
#  File: journal1_p.157.xml | Line 10
#    Ground Truth: lemagne. La mer lui est fermée. Les bombarde¬
#    HTR         : bmagne. Le mer lui est fermie, Dle tombarde¬
#    Dif. HTR    : [('replace', 'le', 'b'), ('replace', 'a', 'e'), ('replace', 'é', 'i'), ('replace', '.', ','), ('replace', 'L', 'Dl'), ('delete', 's', ''), ('replace', 'b', 't')]
#    Corrected   : bmagne. La mer lui est fermée, Les bombarde¬
#    Dif. Corr   : [('replace', 'le', 'b'), ('replace', '.', ',')]
#    CER corr vs GT: 0.0667, WER: 0.2500
#
#  File: journal1_p.157.xml | Line 11
#    Ground Truth: ments comme ceux de Scarborough, indiquent de
#    HTR         : ment comme ceux de Scarborongh indiquent de
#    Dif. HTR    : [('delete', 's', ''), ('replace', 'u', 'n'), ('delete', ',', '')]
#    Corrected   : ments comme ceux de Scarborough indiquent de
#    Dif. Corr   : [('delete', ',', '')]
#    CER corr vs GT: 0.0222, WER: 0.1429
#
#  File: journal1_p.157.xml | Line 12
#    Ground Truth: l'affolement ou un paroxysme me dangereux d'ou¬
#    HTR         : l'iffrloment or un parosis me dangereux d'on
#    Dif. HTR    : [('replace', 'a', 'i'), ('insert', '', 'rl'), ('delete', 'le', ''), ('replace', 'u', 'r'), ('delete', 'xy', ''), ('replace', 'me', 'is'), ('replace', 'u¬', 'n')]
#    Corrected   : l'affolement ou un paroxysme me dangereux d'on
#    Dif. Corr   : [('replace', 'u¬', 'n')]
#    CER corr vs GT: 0.0426, WER: 0.1429
#
#  File: journal1_p.157.xml | Line 13
#    Ground Truth: trecuidance brutale. Brutalité qui continue à
#    HTR         : trécnidance brutale. Nutalité qui cntrnue à
#    Dif. HTR    : [('replace', 'e', 'é'), ('replace', 'u', 'n'), ('replace', 'Br', 'N'), ('delete', 'o', ''), ('replace', 'i', 'r'), ('replace', 'à', 'à')]
#    Corrected   : outrecuidance brutale. Brutalité qui continue à
#    Dif. Corr   : [('insert', '', 'ou')]
#    CER corr vs GT: 0.0444, WER: 0.1667
#
#  File: journal1_p.157.xml | Line 14
#    Ground Truth: s'affirmer chez nous avec la paperasserie militaire
#    HTR         : d'affimer cher vons avec la paperassirre Mmilite
#    Dif. HTR    : [('replace', 's', 'd'), ('delete', 'r', ''), ('replace', 'z', 'r'), ('insert', '', 'vo'), ('delete', 'ou', ''), ('replace', 'e', 'i'), ('replace', 'i', 'r'), ('insert', '', 'M'), ('delete', 'air', '')]
#    Corrected   : s'affirmer chez nous avec la paperasserie militaire
#    Dif. Corr   : []
#    CER corr vs GT: 0.0000, WER: 0.0000
#
#  File: journal1_p.157.xml | Line 15
#    Ground Truth: Quelle chance de l’emporter avaient-ils encore ?
#    HTR         : Quelle chance d l'emperter auraient-ils encon?
#    Dif. HTR    : [('delete', 'e', ''), ('replace', '’', "'"), ('replace', 'o', 'e'), ('replace', 'v', 'ur'), ('replace', 're ', 'n')]
#    Corrected   : Quelle chance de l'emporter avaient-ils encore?
#    Dif. Corr   : [('replace', '’', "'"), ('delete', ' ', '')]
#    CER corr vs GT: 0.0417, WER: 0.4286
#
#  File: journal1_p.157.xml | Line 16
#    Ground Truth: Leurs gros canons? Mais il faudrait pour cela qu'ils
#    HTR         : Leres gros candus? Mais il faudrait pour cela qu'ils
#    Dif. HTR    : [('delete', 'u', ''), ('insert', '', 'e'), ('replace', 'on', 'du')]
#    Corrected   : Leurs gros canons? Mais il faudrait pour cela qu'ils
#    Dif. Corr   : []
#    CER corr vs GT: 0.0000, WER: 0.0000
#
#  File: journal1_p.157.xml | Line 17
#    Ground Truth: fussent devant des forteresses. Ces gros canons ajoutent
#    HTR         : fressent devant des firtiresses. Ces por canons ajutiit
#    Dif. HTR    : [('replace', 'u', 're'), ('replace', 'o', 'i'), ('replace', 'e', 'i'), ('replace', 'g', 'po'), ('delete', 'os', ''), ('delete', 'o', ''), ('replace', 'en', 'ii')]
#    Corrected   : fussent devant des forteresses. Ces gros canons ajoutent
#    Dif. Corr   : []
#    CER corr vs GT: 0.0000, WER: 0.0000
#
#  File: journal1_p.157.xml | Line 18
#    Ground Truth: lourdement à la posture ridicule de l'Allemagne.
#    HTR         : Leubrment à la posture rédlicule d l'Allemagne
#    Dif. HTR    : [('replace', 'lo', 'Le'), ('insert', '', 'b'), ('delete', 'de', ''), ('replace', 'à', 'à'), ('replace', 'i', 'é'), ('insert', '', 'l'), ('delete', 'e', ''), ('delete', '.', '')]
#    Corrected   : lourdement à la posture ridicule de l'Allemagne
#    Dif. Corr   : [('delete', '.', '')]
#    CER corr vs GT: 0.0208, WER: 0.1429
#
#  File: journal1_p.157.xml | Line 19
#    Ground Truth: Car je veux bien qu'elle soit héroïque. Mais elle est
#    HTR         : Cas se veux tien qu'elle soit hervique Mais elle est
#    Dif. HTR    : [('replace', 'r', 's'), ('replace', 'j', 's'), ('replace', 'b', 't'), ('replace', 'é', 'e'), ('replace', 'oï', 'vi'), ('delete', '.', '')]
#    Corrected   : Car je veux bien qu'elle soit héroïque Mais elle est
#    Dif. Corr   : [('delete', '.', '')]
#    CER corr vs GT: 0.0189, WER: 0.1000
#
#  File: journal1_p.157.xml | Line 20
#    Ground Truth: ridicule aussi après l'échec du camp sur Paris puis
#    HTR         : ricticule ancai après l'ester des Gelap dur Paris pru
#    Dif. HTR    : [('replace', 'd', 'ct'), ('replace', 'uss', 'nca'), ('delete', 'éch', ''), ('replace', 'c', 'ster'), ('replace', 'u', 'es'), ('replace', 'c', 'Gel'), ('delete', 'm', ''), ('replace', 's', 'd'), ('insert', '', 'r'), ('delete', 'is', '')]
#    Corrected   : ridicule aussi après l'échec du camp sur Paris puis
#    Dif. Corr   : []
#    CER corr vs GT: 0.0000, WER: 0.0000
#
#  File: journal1_p.157.xml | Line 21
#    Ground Truth: du camp sur Calais. A nous sur la campagne si
#    HTR         : du coup lur Calais. A mon leur la Campagne ti
#    Dif. HTR    : [('replace', 'am', 'ou'), ('replace', 's', 'l'), ('insert', '', 'mo'), ('delete', 'ous', ''), ('replace', 's', 'le'), ('replace', 'c', 'C'), ('replace', 's', 't')]
#    Corrected   : du camp sur Calais. A nous sur la campagne si
#    Dif. Corr   : []
#    CER corr vs GT: 0.0000, WER: 0.0000
#
#  File: journal1_p.157.xml | Line 22
#    Ground Truth: minutieusement préparée comme un beau crime
#    HTR         : Miienti eusement préparic Crime un beau crme
#    Dif. HTR    : [('replace', 'm', 'M'), ('insert', '', 'ie'), ('delete', 'u', ''), ('insert', '', ' '), ('replace', 'ée', 'ic'), ('replace', 'com', 'Cri'), ('delete', 'i', '')]
#    Corrected   : Miienti eusement préparée comme un beau crime
#    Dif. Corr   : [('replace', 'm', 'M'), ('insert', '', 'ie'), ('delete', 'u', ''), ('insert', '', ' ')]
#    CER corr vs GT: 0.1163, WER: 0.3333
#
#  File: journal1_p.157.xml | Line 23
#    Ground Truth: une affaire Peltzer, a raté faute d'avoir compté avec
#    HTR         : un offaire Viltses, a raté fauté d'onsir comptiavce
#    Dif. HTR    : [('delete', 'e', ''), ('replace', 'a', 'o'), ('replace', 'Pe', 'Vi'), ('replace', 'z', 's'), ('replace', 'r', 's'), ('replace', 'e', 'é'), ('delete', 'av', ''), ('insert', '', 'ns'), ('replace', 'é ', 'i'), ('insert', '', 'c'), ('delete', 'c', '')]
#    Corrected   : , offaire affaire, a raté faute d'avoir comptiavce
#    Dif. Corr   : [('replace', 'un', ', offair'), ('delete', ' Peltzer', ''), ('replace', 'é ', 'i'), ('insert', '', 'c'), ('delete', 'c', '')]
#    CER corr vs GT: 0.2830, WER: 0.5556
#
#  File: journal1_p.157.xml | Line 24
#    Ground Truth: les causes morales. Le flamingantisme, l'ulstérisme
#    HTR         : les cances Mmorales. Le flamingantiain l'Ulstérisme
#    Dif. HTR    : [('replace', 'us', 'nc'), ('insert', '', 'M'), ('replace', 'sme,', 'ain'), ('replace', 'u', 'U')]
#    Corrected   : les causes morales. Le flamingantisme l'ulstérisme
#    Dif. Corr   : [('delete', ',', '')]
#    CER corr vs GT: 0.0196, WER: 0.1667
#
#  File: journal1_p.157.xml | Line 25
#    Ground Truth: et le caillotisme ont disparu du jour de la déclara¬
#    HTR         : et le Callotisme ont despariu du joir ile la déclara¬
#    Dif. HTR    : [('replace', 'c', 'C'), ('delete', 'i', ''), ('replace', 'i', 'e'), ('insert', '', 'i'), ('replace', 'u', 'i'), ('replace', 'd', 'il')]
#    Corrected   : et le caillotisme ont disparu du jour de la déclara¬
#    Dif. Corr   : []
#    CER corr vs GT: 0.0000, WER: 0.0000
#
#  File: journal1_p.157.xml | Line 26
#    Ground Truth: tion de guerre.
#    HTR         : tion de querre
#    Dif. HTR    : [('replace', 'g', 'q'), ('delete', '.', '')]
#    Corrected   : tion de guerre
#    Dif. Corr   : [('delete', '.', '')]
#    CER corr vs GT: 0.0667, WER: 0.3333
#
#  File: journal1_p.157.xml | Line 27
#    Ground Truth: Du côté des alliés, l'esprit est excellent, d'après tous les
#    HTR         : Du Côté de allies l esprit est excellent, d'après teus les
#    Dif. HTR    : [('replace', 'c', 'C'), ('delete', 's', ''), ('replace', 'é', 'e'), ('delete', ',', ''), ('replace', "'", ' '), ('replace', 'o', 'e')]
#    Corrected   : Du côté des alliés l esprit est excellent, d'après tous les
#    Dif. Corr   : [('delete', ',', ''), ('replace', "'", ' ')]
#    CER corr vs GT: 0.0333, WER: 0.3000
#
#  File: journal1_p.157.xml | Line 28
#    Ground Truth: renseignements. C'en est fini de la désorganisation
#    HTR         : Renciquement. C'en est fini de la désorganisation
#    Dif. HTR    : [('replace', 'r', 'R'), ('replace', 'se', 'c'), ('replace', 'gn', 'qu'), ('delete', 's', '')]
#    Corrected   : Renciquement. C'en est fini de la désorganisation
#    Dif. Corr   : [('replace', 'r', 'R'), ('replace', 'se', 'c'), ('replace', 'gn', 'qu'), ('delete', 's', '')]
#    CER corr vs GT: 0.1176, WER: 0.1429
#
#  File: journal1_p.157.xml | Line 29
#    Ground Truth: des premiers jours. Les hommes arrivent en masse et
#    HTR         : des preiers jours. Les hommes arrivent en masse et
#    Dif. HTR    : [('delete', 'm', '')]
#    Corrected   : des premiers jours. Les hommes arrivent en masse et
#    Dif. Corr   : []
#    CER corr vs GT: 0.0000, WER: 0.0000
#
#  File: journal1_p.157.xml | Line 30
#    Ground Truth: aussi le matériel. La Belgique, profitant de l'indiqua¬
#    HTR         : aussi le matériel. La Belgique, jiofitant de l'indigna¬
#    Dif. HTR    : [('replace', 'pr', 'ji'), ('replace', 'qu', 'gn')]
#    Corrected   : aussi le matériel. La Belgique, profitant de l'indigna¬
#    Dif. Corr   : [('replace', 'qu', 'gn')]
#    CER corr vs GT: 0.0364, WER: 0.1250
#
#  File: journal1_p.157.xml | Line 31
#    Ground Truth: tion de l'Europe, se montre héroïque jusqu'au bout.
#    HTR         : tion, de l'Erope, de montre héroique jusqu'au bout
#    Dif. HTR    : [('insert', '', ','), ('delete', 'u', ''), ('replace', 's', 'd'), ('replace', 'ï', 'i'), ('delete', '.', '')]
#    Corrected   : tion, de l'Europe, se montre héroïque jusqu'au bout
#    Dif. Corr   : [('insert', '', ','), ('delete', '.', '')]
#    CER corr vs GT: 0.0392, WER: 0.2500
#
#  File: journal1_p.157.xml | Line 32
#    Ground Truth: Son roi est à jamais lié au peuple et fait l'admiration
#    HTR         : Son roi est à jamais lié au peuple et fait l'admiration
#    Dif. HTR    : [('replace', 'à', 'à')]
#    Corrected   : Son roi est à jamais lié au peuple et fait l'admiration
#    Dif. Corr   : []
#    CER corr vs GT: 0.0000, WER: 0.0000
#
#  File: journal1_p.157.xml | Line 33
#    Ground Truth: du monde. Le ravitaillement est assuré et aussi
#    HTR         : du monde. Le ravi taillement esi assivé et aussi
#    Dif. HTR    : [('insert', '', ' '), ('replace', 't', 'i'), ('replace', 'ur', 'iv')]
#    Corrected   : du monde. Le ravi taillement est assuré et aussi
#    Dif. Corr   : [('insert', '', ' ')]
#    CER corr vs GT: 0.0213, WER: 0.2500
#
#  File: journal1_p.157.xml | Line 34
#    Ground Truth: les finances
#    HTR         : ls nances
#    Dif. HTR    : [('delete', 'e', ''), ('delete', 'fi', '')]
#    Corrected   : les finances
#    Dif. Corr   : []
#    CER corr vs GT: 0.0000, WER: 0.0000
#
#  File: journal1_p.157.xml | Line 35
#    Ground Truth: On dit que l'Allemagne tiendra en Belgique à l'in¬
#    HTR         : On dit que l'Allemagre tundra ee Belgique à l'en
#    Dif. HTR    : [('replace', 'n', 'r'), ('replace', 'ie', 'u'), ('replace', 'n', 'e'), ('replace', 'à', 'à'), ('replace', 'i', 'e'), ('delete', '¬', '')]
#    Corrected   : On dit que l'Allemagne tiendra en Belgique à l'en
#    Dif. Corr   : [('replace', 'i', 'e'), ('delete', '¬', '')]
#    CER corr vs GT: 0.0400, WER: 0.1111
#
#  File: journal1_p.157.xml | Line 36
#    Ground Truth: fini et que notre pauvre pays lui constitue un gage
#    HTR         : finii et que otre pauire pay lui constitue un gage
#    Dif. HTR    : [('insert', '', 'i'), ('delete', 'n', ''), ('replace', 'v', 'i'), ('delete', 's', '')]
#    Corrected   : infini et que notre pauvre pays lui constitue un gage
#    Dif. Corr   : [('insert', '', 'in')]
#    CER corr vs GT: 0.0392, WER: 0.1000
#
#  File: journal1_p.157.xml | Line 37
#    Ground Truth: pour la discussion de la paix. Mais à supposer même
#    HTR         : puu le dession de la paix. Mais à euppsser même
#    Dif. HTR    : [('delete', 'o', ''), ('replace', 'r', 'u'), ('replace', 'a', 'e'), ('replace', 'iscu', 'e'), ('replace', 'à', 'à'), ('replace', 's', 'e'), ('replace', 'o', 's')]
#    Corrected   : pour la dession de la paix. Mais à supposer même
#    Dif. Corr   : [('replace', 'iscu', 'e')]
#    CER corr vs GT: 0.0784, WER: 0.1000
#
#  File: journal1_p.157.xml | Line 38
#    Ground Truth: qu'elle se tienne à Anvers Namur et Liège si elle est
#    HTR         : qu'elle le tienne à Rivers Nanner et tiège ss ele est
#    Dif. HTR    : [('replace', 's', 'l'), ('replace', 'à', 'à'), ('replace', 'An', 'Ri'), ('replace', 'mu', 'nne'), ('replace', 'L', 't'), ('replace', 'i', 's'), ('delete', 'l', '')]
#    Corrected   : qu'elle se tienne à Anvers Namur et Liège si elle est
#    Dif. Corr   : []
#    CER corr vs GT: 0.0000, WER: 0.0000
#
#  File: journal1_p.157.xml | Line 39
#    Ground Truth: battue, il faudra bien lui céder. Et les neutres ne peuvent
#    HTR         : bottue, il faudra bien le cider. Et les neutes un peuvent
#    Dif. HTR    : [('replace', 'a', 'o'), ('replace', 'ui', 'e'), ('replace', 'é', 'i'), ('delete', 'r', ''), ('insert', '', 'u'), ('delete', 'e', '')]
#    Corrected   : battue, il faudra bien lui céder. Et les neutres ne peuvent
#    Dif. Corr   : []
#    CER corr vs GT: 0.0000, WER: 0.0000
#
#  File: journal1_p.160.xml | Line 1
#    Ground Truth: 160
#    HTR         :
#    Dif. HTR    : [('delete', '160', '')]
#    Corrected   :
#    Dif. Corr   : [('delete', '160', '')]
#    CER corr vs GT: 1.0000, WER: 1.0000
#
#  File: journal1_p.160.xml | Line 2
#    Ground Truth: guerres d'intérêt (Angleterre) guerres d'équilibre
#    HTR         : uerres d'intérêt (Aigliture) guerres d'équilibré
#    Dif. HTR    : [('delete', 'g', ''), ('replace', 'n', 'i'), ('replace', 'e', 'i'), ('replace', 'er', 'u'), ('replace', 'e', 'é')]
#    Corrected   : guerres d'intérêt (Angleterre) guerres d'équilibre
#    Dif. Corr   : []
#    CER corr vs GT: 0.0000, WER: 0.0000
#
#  File: journal1_p.160.xml | Line 3
#    Ground Truth: contre la guerre de magnificence de l'Espagne et de la
#    HTR         : contre les guerces de Magnifisence de l Espagne et de la
#    Dif. HTR    : [('replace', 'a', 'es'), ('replace', 'r', 'c'), ('insert', '', 's'), ('replace', 'm', 'M'), ('replace', 'c', 's'), ('replace', "'", ' ')]
#    Corrected   : contre la guerre de magnificence de l Espagne et de la
#    Dif. Corr   : [('replace', "'", ' ')]
#    CER corr vs GT: 0.0185, WER: 0.2000
#
#  File: journal1_p.160.xml | Line 4
#    Ground Truth: France.
#    HTR         : France.
#    Dif. HTR    : []
#    Corrected   : France.
#    Dif. Corr   : []
#    CER corr vs GT: 0.0000, WER: 0.0000
#
#  File: journal1_p.160.xml | Line 5
#    Ground Truth: A la Révolution, guerre de propagande qui se trans¬
#    HTR         : Al Revalution, juerre de propagande. qui se trains¬
#    Dif. HTR    : [('delete', ' ', ''), ('delete', 'a', ''), ('replace', 'é', 'e'), ('replace', 'o', 'a'), ('replace', 'g', 'j'), ('insert', '', '.'), ('insert', '', 'i')]
#    Corrected   : la Révolution, guerre de propagande. qui se transf¬
#    Dif. Corr   : [('delete', 'A ', ''), ('insert', '', '.'), ('insert', '', 'f')]
#    CER corr vs GT: 0.0784, WER: 0.3333
#
#  File: journal1_p.160.xml | Line 6
#    Ground Truth: forme bientôt en guerre de magnificence <....> à
#    HTR         : fonme binitôt en gerecre de maquificeure roatre à
#    Dif. HTR    : [('replace', 'r', 'n'), ('delete', 'e', ''), ('insert', '', 'i'), ('delete', 'u', ''), ('insert', '', 'ec'), ('replace', 'gn', 'qu'), ('replace', 'nc', 'ur'), ('replace', '<....>', 'roatre'), ('replace', 'à', 'à')]
#    Corrected   : orme bientôt er guerre de magnificence roatre à
#    Dif. Corr   : [('delete', 'f', ''), ('replace', 'n', 'r'), ('replace', '<....>', 'roatre')]
#    CER corr vs GT: 0.1667, WER: 0.3750
#
#  File: journal1_p.160.xml | Line 7
#    Ground Truth: laquelle répond la guerre d'intérêts (Angleterre) et
#    HTR         : laquelle répond la guerre d'intérêtz (Angliterre) et
#    Dif. HTR    : [('replace', 's', 'z'), ('replace', 'e', 'i')]
#    Corrected   : laquelle répond la guerre d'intérêts (Angleterre) et
#    Dif. Corr   : []
#    CER corr vs GT: 0.0000, WER: 0.0000
#
#  File: journal1_p.160.xml | Line 8
#    Ground Truth: d'équilibre.
#    HTR         : d'equilibre.
#    Dif. HTR    : [('replace', 'é', 'e')]
#    Corrected   : d'équilibre.
#    Dif. Corr   : []
#    CER corr vs GT: 0.0000, WER: 0.0000
#
#  File: journal1_p.160.xml | Line 9
#    Ground Truth: Mais en même temps commence à apparaître à la
#    HTR         : Mais en même temps commes à apparaitie à la
#    Dif. HTR    : [('replace', 'nce', 's'), ('replace', 'à', 'à'), ('replace', 'î', 'i'), ('replace', 'r', 'i'), ('replace', 'à', 'à')]
#    Corrected   : Mais en même temps commence à apparaître à la
#    Dif. Corr   : []
#    CER corr vs GT: 0.0000, WER: 0.0000
#
#  File: journal1_p.160.xml | Line 10
#    Ground Truth: fin de l'Empire la guerre nationale - en Allemagne.
#    HTR         : fui de l'Empire la guerre nationale -on Allremaque
#    Dif. HTR    : [('insert', '', 'u'), ('delete', 'n', ''), ('replace', ' e', 'o'), ('insert', '', 'r'), ('replace', 'gn', 'qu'), ('delete', '.', '')]
#    Corrected   : fin de l'Empire la guerre nationale-en Allemagne
#    Dif. Corr   : [('delete', ' ', ''), ('delete', ' ', ''), ('delete', '.', '')]
#    CER corr vs GT: 0.0588, WER: 0.4444
#
#  File: journal1_p.160.xml | Line 11
#    Ground Truth: Depuis lors, cette espèce se multiplie. Celle d’aujourd'hui
#    HTR         : Depuis lors, cette éspèse se multiplie. Celle d'aupurdhur
#    Dif. HTR    : [('replace', 'e', 'é'), ('replace', 'c', 's'), ('replace', '’', "'"), ('replace', 'jo', 'p'), ('delete', "'", ''), ('replace', 'i', 'r')]
#    Corrected   : Depuis lors, cette espèce se multiplie. Celle d'aujourd
#    Dif. Corr   : [('replace', '’', "'"), ('delete', "'hui", '')]
#    CER corr vs GT: 0.0847, WER: 0.1250
#
#  File: journal1_p.160.xml | Line 12
#    Ground Truth: dans son fonds est partout une guerre nationale. Mais
#    HTR         : dans son fons est partont une guerre rationale. Mns
#    Dif. HTR    : [('delete', 'd', ''), ('replace', 'u', 'n'), ('replace', 'n', 'r'), ('replace', 'ai', 'n')]
#    Corrected   : dans son fonds est partout une guerre nationale. Mais
#    Dif. Corr   : []
#    CER corr vs GT: 0.0000, WER: 0.0000
#
#  File: journal1_p.160.xml | Line 13
#    Ground Truth: elle ne l'est peut-être purement qu'en France. Pour l'Angle¬
#    HTR         : elle e l'ést peut-êtc purement qu'en France. Pouu l'Angles
#    Dif. HTR    : [('delete', 'n', ''), ('replace', 'e', 'é'), ('replace', 're', 'c'), ('replace', 'r', 'u'), ('replace', '¬', 's')]
#    Corrected   : elle ne l'est peut-être purement qu'en France. Pour l'Angles
#    Dif. Corr   : [('replace', '¬', 's')]
#    CER corr vs GT: 0.0167, WER: 0.1111
#
#  File: journal1_p.160.xml | Line 14
#    Ground Truth: terre elle est avant tout une guerre d'intérêts comme
#    HTR         : terce elle est avant tont une guerre d'intérêts armmun
#    Dif. HTR    : [('replace', 'r', 'c'), ('replace', 'u', 'n'), ('replace', 'co', 'ar'), ('replace', 'e', 'un')]
#    Corrected   : terce elle est avant tout une guerre d'intérêts comme
#    Dif. Corr   : [('replace', 'r', 'c')]
#    CER corr vs GT: 0.0189, WER: 0.1111
#
#  File: journal1_p.160.xml | Line 15
#    Ground Truth: celle contre Napoléon. Pour l'Allemagne, elle est aussi
#    HTR         : celle contre Napolion- Pou l'Allemagne, elle est ancai
#    Dif. HTR    : [('replace', 'é', 'i'), ('replace', '.', '-'), ('delete', 'r', ''), ('replace', 'uss', 'nca')]
#    Corrected   : celle contre Napoléon. Pour l'Allemagne, elle est aussi
#    Dif. Corr   : []
#    CER corr vs GT: 0.0000, WER: 0.0000
#
#  File: journal1_p.160.xml | Line 16
#    Ground Truth: une guerre d'expansion économique. En Autriche
#    HTR         : une guerre d'expausion écononique. E Orntriche
#    Dif. HTR    : [('replace', 'n', 'u'), ('replace', 'm', 'n'), ('insert', '', ' Or'), ('delete', ' Au', '')]
#    Corrected   : une guerre d'expansion économique. En Autriche
#    Dif. Corr   : []
#    CER corr vs GT: 0.0000, WER: 0.0000
#
#  File: journal1_p.160.xml | Line 17
#    Ground Truth: et en Russie, la tradition du XVIIIe s. se conserve mieux. Il
#    HTR         : et en Russie, la tradtitiorn des XVIII, s. se ansene mieux. Il
#    Dif. HTR    : [('insert', '', 't'), ('insert', '', 'r'), ('replace', 'u', 'es'), ('replace', 'e', ','), ('replace', 'co', 'a'), ('replace', 'rv', 'n')]
#    Corrected   : et en Russie, la tradition du XVIIIe, s. se conserve mieux. Il
#    Dif. Corr   : [('insert', '', ',')]
#    CER corr vs GT: 0.0164, WER: 0.0833
#
#  File: journal1_p.160.xml | Line 18
#    Ground Truth: faut pénétrer en Orient et le vieux conflit. Catherine -
#    HTR         : faut penétrer en Orient et la veux conflit Catteriie¬
#    Dif. HTR    : [('replace', 'é', 'e'), ('replace', 'e', 'a'), ('delete', 'i', ''), ('delete', '.', ''), ('replace', 'h', 't'), ('replace', 'n', 'i'), ('replace', ' -', '¬')]
#    Corrected   : faut pénétrer en Orient et la Grande monarchie Catteriie¬
#    Dif. Corr   : [('insert', '', 'a Grand'), ('replace', 'v', 'monarch'), ('delete', 'ux conflit.', ''), ('replace', 'h', 't'), ('replace', 'n', 'i'), ('replace', ' -', '¬')]
#    CER corr vs GT: 0.3214, WER: 0.5000
#
#  File: journal1_p.160.xml | Line 19
#    Ground Truth: Habsbourg réapparaît.
#    HTR         : Htabsbung réapparait.
#    Dif. HTR    : [('insert', '', 't'), ('delete', 'o', ''), ('replace', 'r', 'n'), ('replace', 'î', 'i')]
#    Corrected   : Htabsbung réapparaît.
#    Dif. Corr   : [('insert', '', 't'), ('delete', 'o', ''), ('replace', 'r', 'n')]
#    CER corr vs GT: 0.1429, WER: 0.5000
#
#  File: journal1_p.160.xml | Line 20
#    Ground Truth: Pour nous, c'est une simple guerre de défense contre la force.
#    HTR         : Poue Tious, c'est uus semple guerrd défense contret force
#    Dif. HTR    : [('replace', 'r', 'e'), ('replace', 'n', 'Ti'), ('replace', 'ne', 'us'), ('replace', 'i', 'e'), ('delete', 'e ', ''), ('delete', 'e', ''), ('replace', ' la', 't'), ('delete', '.', '')]
#    Corrected   : Pour nous, c'est une simple guerre défense contre force
#    Dif. Corr   : [('delete', 'e d', ''), ('delete', 'la ', ''), ('delete', '.', '')]
#    CER corr vs GT: 0.1129, WER: 0.2727
#
#  File: journal1_p.160.xml | Line 21
#    Ground Truth: L'Alemagne a violé notre neutralité par raison d'État
#    HTR         : L'Ullmagne a violé notre ventralité par raison d'Etat
#    Dif. HTR    : [('replace', 'A', 'U'), ('replace', 'e', 'l'), ('insert', '', 've'), ('delete', 'eu', ''), ('replace', 'É', 'E')]
#    Corrected   : L'Ullmagne a violé notre neutralité par raison d'État
#    Dif. Corr   : [('replace', 'A', 'U'), ('replace', 'e', 'l')]
#    CER corr vs GT: 0.0377, WER: 0.1250
#
#  File: journal1_p.160.xml | Line 22
#    Ground Truth: autant que par raison stratégique. Dans tout ce conflit
#    HTR         : autant que par raison stratigique. Dans tout ce mflit
#    Dif. HTR    : [('replace', 'é', 'i'), ('replace', 'con', 'm')]
#    Corrected   : autant que par raison stratégique. Dans tout ce conflit
#    Dif. Corr   : []
#    CER corr vs GT: 0.0000, WER: 0.0000
#
#  File: journal1_p.160.xml | Line 23
#    Ground Truth: où luttent les intérêts et les passions nationales, nous som¬
#    HTR         : où buttent le intérêts et les passions nationmales, nous com¬
#    Dif. HTR    : [('replace', 'l', 'b'), ('delete', 's', ''), ('insert', '', 'm'), ('replace', 's', 'c')]
#    Corrected   : où luttent les intérêts et les passions nationales, nous som¬
#    Dif. Corr   : []
#    CER corr vs GT: 0.0000, WER: 0.0000
#
#  File: journal1_p.160.xml | Line 24
#    Ground Truth: mes seuls à défendre le droit. Et sa défense apparaît com¬
#    HTR         : mes seuls à défendre le droit. Et sa défense apparait com¬
#    Dif. HTR    : [('replace', 'à', 'à'), ('replace', 'î', 'i')]
#    Corrected   : mes seuls à défendre le droit. Et sa défense apparaît com¬
#    Dif. Corr   : []
#    CER corr vs GT: 0.0000, WER: 0.0000
#
#  File: journal1_p.160.xml | Line 25
#    Ground Truth: me d'autant plus éclatante que les belligérants et surtout
#    HTR         : me d'autant plus cclatante que les belligérant et surtme
#    Dif. HTR    : [('replace', 'é', 'c'), ('delete', 's', ''), ('replace', 'out', 'me')]
#    Corrected   : me d'autant plus éclatante que les belligérants et surtout
#    Dif. Corr   : []
#    CER corr vs GT: 0.0000, WER: 0.0000
#
#  File: journal1_p.160.xml | Line 26
#    Ground Truth: l'Allemagne le respectent moins, en renouant à des
#    HTR         : l'Albmagne le réspechent moins, en revenant à des
#    Dif. HTR    : [('replace', 'le', 'b'), ('replace', 'e', 'é'), ('replace', 't', 'h'), ('insert', '', 've'), ('delete', 'ou', ''), ('replace', 'à', 'à')]
#    Corrected   : l'Allemagne le respectent moins, en renouant à des
#    Dif. Corr   : []
#    CER corr vs GT: 0.0000, WER: 0.0000
#
#  File: journal1_p.160.xml | Line 27
#    Ground Truth: procédés de guerre qui violent toutes les conventions inter¬
#    HTR         : procéoés de guerre qui violut tontes les coomentions inter¬
#    Dif. HTR    : [('replace', 'd', 'o'), ('replace', 'en', 'u'), ('replace', 'u', 'n'), ('replace', 'nv', 'om')]
#    Corrected   : procédés de guerre qui violent toutes les conventions inter¬
#    Dif. Corr   : []
#    CER corr vs GT: 0.0000, WER: 0.0000
#
#  File: journal1_p.160.xml | Line 28
#    Ground Truth: nationales.
#    HTR         : nationales.
#    Dif. HTR    : []
#    Corrected   : nationales.
#    Dif. Corr   : []
#    CER corr vs GT: 0.0000, WER: 0.0000
#
#  File: journal1_p.160.xml | Line 29
#    Ground Truth: Celle-ci aurait-elle plus de force après la guerre? Oui sans
#    HTR         : Celle-n auront- elle plus de force après la guerre ? Viii sans
#    Dif. HTR    : [('replace', 'ci', 'n'), ('replace', 'ai', 'on'), ('insert', '', ' '), ('insert', '', ' '), ('replace', 'Ou', 'Vii')]
#    Corrected   : Celle-ci aurait-elle plus de force après la guerre? Oui sans
#    Dif. Corr   : []
#    CER corr vs GT: 0.0000, WER: 0.0000
#
#  File: journal1_p.160.xml | Line 30
#    Ground Truth: doute si l'Allemagne devait l'emporter. Ce serait le tri¬
#    HTR         : donte si l'Allemaqne devait l'importer. Ce derait le tri¬
#    Dif. HTR    : [('replace', 'u', 'n'), ('replace', 'g', 'q'), ('replace', 'e', 'i'), ('replace', 's', 'd')]
#    Corrected   : doute si l'Allemagne devait l'emporter. Ce serait le tri¬
#    Dif. Corr   : []
#    CER corr vs GT: 0.0000, WER: 0.0000
#
#  File: journal1_p.160.xml | Line 31
#    Ground Truth: omphe du nationalisme le plus exclusif. Au contraire
#    HTR         : omphe du Nationalisme la plus exclenif. Au centraire
#    Dif. HTR    : [('replace', 'n', 'N'), ('replace', 'e', 'a'), ('replace', 'us', 'en'), ('replace', 'o', 'e')]
#    Corrected   : omphe du nationalisme le plus exclusif. Au contraire
#    Dif. Corr   : []
#    CER corr vs GT: 0.0000, WER: 0.0000
#
#  File: journal1_p.160.xml | Line 32
#    Ground Truth: il est impossible qu'elles ne prennent pas une vigueur
#    HTR         : il est impossible qu'elles ne preement pas une vigneur
#    Dif. HTR    : [('replace', 'nn', 'em'), ('replace', 'u', 'n')]
#    Corrected   : il est impossible qu'elles ne prennent pas une vigueur
#    Dif. Corr   : []
#    CER corr vs GT: 0.0000, WER: 0.0000
#
#  File: journal1_p.160.xml | Line 33
#    Ground Truth: nouvelle par la victoire de la France et de l’Angleterre qui
#    HTR         : nouvelle par la victoire d l France et de l'Augliterre qui
#    Dif. HTR    : [('delete', 'e', ''), ('delete', 'a', ''), ('replace', '’', "'"), ('replace', 'n', 'u'), ('replace', 'e', 'i')]
#    Corrected   : nouvelle par la victoire de la France et de l'Angleterre qui
#    Dif. Corr   : [('replace', '’', "'")]
#    CER corr vs GT: 0.0167, WER: 0.0909
#
#  File: journal1_p.160.xml | Line 34
#    Ground Truth: d'abord, défendant la Belgique défendent le droit et qui,
#    HTR         : s'abod, défndant le Belgique défendent le droit et qui
#    Dif. HTR    : [('replace', 'd', 's'), ('delete', 'r', ''), ('delete', 'e', ''), ('replace', 'a', 'e'), ('delete', ',', '')]
#    Corrected   : d'abord, défendant la Belgique défendent le droit et qui
#    Dif. Corr   : [('delete', ',', '')]
#    CER corr vs GT: 0.0175, WER: 0.1111
#
#  File: journal1_p.160.xml | Line 35
#    Ground Truth: de plus, trouveront une garantie dans ces conventions.
#    HTR         : de plus trouveront une garantie dans ces conventions
#    Dif. HTR    : [('delete', ',', ''), ('delete', '.', '')]
#    Corrected   : de plus trouveront une garantie dans ces conventions
#    Dif. Corr   : [('delete', ',', ''), ('delete', '.', '')]
#    CER corr vs GT: 0.0370, WER: 0.2500
#
#  File: journal1_p.160.xml | Line 36
#    Ground Truth: Si on en arrive là, on pourra se consoler de tout le sang
#    HTR         : Si on en arrève la on pena se consoler de tant de Laig
#    Dif. HTR    : [('replace', 'i', 'è'), ('replace', 'à,', 'a'), ('replace', 'ourr', 'en'), ('replace', 'ou', 'an'), ('replace', 'l', 'd'), ('replace', 's', 'L'), ('replace', 'n', 'i')]
#    Corrected   : Si on en arrive là on pourra se consoler de tout le sang
#    Dif. Corr   : [('delete', ',', '')]
#    CER corr vs GT: 0.0175, WER: 0.0769
#
#  File: journal1_p.160.xml | Line 37
#    Ground Truth: versé et notre pauvre Pierre, si noble et si jeune ne sera pas mort
#    HTR         : veuse et note pauvre Perre, si imble et si pus, les sera pas imort
#    Dif. HTR    : [('replace', 'r', 'u'), ('replace', 'é', 'e'), ('delete', 'r', ''), ('delete', 'i', ''), ('replace', 'no', 'im'), ('replace', 'j', 'pus, l'), ('replace', 'une ne', 's'), ('insert', '', 'i')]
#    Corrected   : versé et notre pauvre Pierre, si noble et si jeune, ne sera pas mort
#    Dif. Corr   : [('insert', '', ',')]
#    CER corr vs GT: 0.0149, WER: 0.0714
#
#  File: journal1_p.160.xml | Line 38
#    Ground Truth: en vain, si hélas comme je le crains nous devons le pleurer
#    HTR         : le vain, si hélas Comme ple cains nous devons le pleuver
#    Dif. HTR    : [('insert', '', 'l'), ('delete', 'n', ''), ('replace', 'c', 'C'), ('replace', 'je ', 'p'), ('delete', 'r', ''), ('replace', 'r', 'v')]
#    Corrected   : en vain, si hélas comme le crains nous devons le pleurer
#    Dif. Corr   : [('delete', 'e j', '')]
#    CER corr vs GT: 0.0508, WER: 0.0833
#
#  File: journal1_p.160.xml | Line 39
#    Ground Truth: Ce qu il y a de hideux et de néfaste dans le nationalisme allemand,
#    HTR         : C qu'il y a d hideuxet de néfacte dans l'Natronalim alhomand
#    Dif. HTR    : [('delete', 'e', ''), ('replace', ' ', "'"), ('delete', 'e', ''), ('delete', ' ', ''), ('replace', 's', 'c'), ('replace', 'e n', "'N"), ('replace', 'i', 'r'), ('delete', 's', ''), ('delete', 'e', ''), ('replace', 'le', 'ho'), ('delete', ',', '')]
#    Corrected   : Ce qu'il y a de hideux de néfaste dans le'Natronalim alhomand
#    Dif. Corr   : [('replace', ' ', "'"), ('delete', ' et', ''), ('replace', ' n', "'N"), ('replace', 'i', 'r'), ('delete', 's', ''), ('delete', 'e', ''), ('replace', 'le', 'ho'), ('delete', ',', '')]
#    CER corr vs GT: 0.1791, WER: 0.4286
#
#  File: journal1_p.160.xml | Line 40
#    Ground Truth: c'est qu'il s'appuie sur le militarisme prussien d'ancien régime
#    HTR         : C'est qu'l s'appupsur l militaris un pruvine d'ancies réqune
#    Dif. HTR    : [('replace', 'c', 'C'), ('delete', 'i', ''), ('replace', 'ie ', 'p'), ('delete', 'e', ''), ('replace', 'me', ' un'), ('replace', 'ss', 'v'), ('insert', '', 'n'), ('delete', 'n', ''), ('replace', 'n', 's'), ('replace', 'gim', 'qun')]
#    Corrected   : c'est qu'il s'appuie sur militaris un prussien d'Ancien Régime
#    Dif. Corr   : [('delete', 'le ', ''), ('replace', 'me', ' un'), ('replace', 'a', 'A'), ('replace', 'r', 'R')]
#    CER corr vs GT: 0.1250, WER: 0.4444
#
#  File: journal1_p.161.xml | Line 1
#    Ground Truth: <...> en même temps qu'il le justifie par des théories ger¬
#    HTR         : Lerat en même tempe qu'il ce pestifie par des théoies fs
#    Dif. HTR    : [('replace', '<...>', 'Lerat'), ('replace', 's', 'e'), ('replace', 'l', 'c'), ('replace', 'ju', 'pe'), ('delete', 'r', ''), ('replace', 'ger¬', 'fs')]
#    Corrected   : Lerat en même temps qu'il le justifie par des théories fs
#    Dif. Corr   : [('replace', '<...>', 'Lerat'), ('replace', 'ger¬', 'fs')]
#    CER corr vs GT: 0.1525, WER: 0.1818
#
#  File: journal1_p.161.xml | Line 2
#    Ground Truth: manistiques et mystico-sociales, qui l'enveloppent et le
#    HTR         : manistiques et Mystier-dociales, qui l'enveloppent et là
#    Dif. HTR    : [('replace', 'm', 'M'), ('replace', 'co', 'er'), ('replace', 's', 'd'), ('replace', 'e', 'à')]
#    Corrected   : manistiques et mystico-sociales, qui l'enveloppent et le
#    Dif. Corr   : []
#    CER corr vs GT: 0.0000, WER: 0.0000
#
#  File: journal1_p.161.xml | Line 3
#    Ground Truth: justifient comme les théosophes de Frédéric Guillaume I en
#    HTR         : jestifient comme les thévrophes de Frederce Guillame I en
#    Dif. HTR    : [('replace', 'u', 'e'), ('replace', 'os', 'vr'), ('replace', 'é', 'e'), ('replace', 'é', 'e'), ('delete', 'i', ''), ('insert', '', 'e'), ('delete', 'u', '')]
#    Corrected   : justifient comme les théosophes de Frédéric Guillaume Ier en
#    Dif. Corr   : [('insert', '', 'er')]
#    CER corr vs GT: 0.0345, WER: 0.1111
#
#  File: journal1_p.161.xml | Line 4
#    Ground Truth: enveloppaient et en justifiaient les appétits polonais et
#    HTR         : teureloppaient et en pectifiaient les appétits polourais et
#    Dif. HTR    : [('insert', '', 't'), ('replace', 'nv', 'ur'), ('replace', 'jus', 'pec'), ('replace', 'n', 'ur')]
#    Corrected   : enveloppaient et en justifiaient les appétits polonais et
#    Dif. Corr   : []
#    CER corr vs GT: 0.0000, WER: 0.0000
#
#  File: journal1_p.161.xml | Line 5
#    Ground Truth: autres.
#    HTR         : Autes.
#    Dif. HTR    : [('replace', 'a', 'A'), ('delete', 'r', '')]
#    Corrected   : autres.
#    Dif. Corr   : []
#    CER corr vs GT: 0.0000, WER: 0.0000
#
#  File: journal1_p.161.xml | Line 6
#    Ground Truth: L'honnête Bley qui entre et à qui je les ceci bondit. L’Al¬
#    HTR         : honiit Bles quiente et'à qui se les ceci bondit. L At¬
#    Dif. HTR    : [('delete', "L'", ''), ('replace', 'nê', 'ii'), ('delete', 'e', ''), ('replace', 'y', "s quiente et'à"), ('replace', 'entr', 's'), ('delete', 'et à qui je\xa0', ''), ('replace', '’', ' '), ('replace', 'l', 't')]
#    Corrected   : honnête Bleyl entre et'à qui je lis ceci bondit. L Al¬
#    Dif. Corr   : [('delete', "L'", ''), ('replace', ' qui', 'l'), ('replace', ' ', "'"), ('replace', '\xa0', ' '), ('replace', 'e', 'i'), ('replace', '’', ' ')]
#    CER corr vs GT: 0.1695, WER: 0.8182
#
#  File: journal1_p.161.xml | Line 7
#    Ground Truth: lemagne dit-il s'est couverte de honte par l'attaque
#    HTR         : lemagne dit. il s'est couverte de tonte pai l'attagne
#    Dif. HTR    : [('replace', '-', '. '), ('replace', 'h', 't'), ('replace', 'r', 'i'), ('replace', 'qu', 'gn')]
#    Corrected   : lemagne dit-il s'est couverte de honte par l'attaque
#    Dif. Corr   : []
#    CER corr vs GT: 0.0000, WER: 0.0000
#
#  File: journal1_p.161.xml | Line 8
#    Ground Truth: de la Belgique qui ne lui avait rien fait (et dont elle
#    HTR         : de l Rilyque qui ne lui Avait rien fait (et dontelle
#    Dif. HTR    : [('delete', 'a', ''), ('replace', 'Be', 'Ri'), ('replace', 'gi', 'y'), ('replace', 'a', 'A'), ('delete', ' ', '')]
#    Corrected   : de la Belgique qui ne lui avait rien fait (et dontelle
#    Dif. Corr   : [('delete', ' ', '')]
#    CER corr vs GT: 0.0182, WER: 0.1667
#
#  File: journal1_p.161.xml | Line 9
#    Ground Truth: garantissait la neutralité, ajoute Thomas) et par le
#    HTR         : garantirait la entralité, aprit Chonas) et par le
#    Dif. HTR    : [('replace', 'ss', 'r'), ('insert', '', 'e'), ('delete', 'eu', ''), ('replace', 'jou', 'pri'), ('delete', 'e', ''), ('replace', 'T', 'C'), ('replace', 'm', 'n')]
#    Corrected   : garantissait la neutralité, ajoute Thomas) et par le
#    Dif. Corr   : []
#    CER corr vs GT: 0.0000, WER: 0.0000
#
#  File: journal1_p.161.xml | Line 10
#    Ground Truth: traitement auquel, ensuite, elle l'a soumise. Les Al¬
#    HTR         : traitement Anquel, encuite, ell l'a sommise. Les Al¬
#    Dif. HTR    : [('replace', 'au', 'An'), ('replace', 's', 'c'), ('delete', 'e', ''), ('replace', 'u', 'm')]
#    Corrected   : traitement auquel, ensuite, elle l'a soumise. Les Al¬
#    Dif. Corr   : []
#    CER corr vs GT: 0.0000, WER: 0.0000
#
#  File: journal1_p.161.xml | Line 11
#    Ground Truth: lemands le sentent bien. Aussi la Gazette de Cologne
#    HTR         : lemand le Leutent lien. Ancci la Gazethe de Cologne
#    Dif. HTR    : [('delete', 's', ''), ('replace', 's', 'L'), ('replace', 'n', 'u'), ('replace', 'b', 'l'), ('replace', 'uss', 'ncc'), ('replace', 't', 'h')]
#    Corrected   : lemands le sentent bien. Aussi la Gazette de Cologne
#    Dif. Corr   : []
#    CER corr vs GT: 0.0000, WER: 0.0000
#
#  File: journal1_p.161.xml | Line 12
#    Ground Truth: revient-elle constamment sur ce point, pour essayer
#    HTR         : rivient-elle Cristamment sur ce puint, pour esrayer
#    Dif. HTR    : [('replace', 'e', 'i'), ('replace', 'con', 'Cri'), ('replace', 'o', 'u'), ('replace', 's', 'r')]
#    Corrected   : revient-elle constamment sur ce point, pour essayer
#    Dif. Corr   : []
#    CER corr vs GT: 0.0000, WER: 0.0000
#
#  File: journal1_p.161.xml | Line 13
#    Ground Truth: de rejeter l'odieux de l'attentat sur la Belgique !
#    HTR         : de rejiter l'odieux de l'attentat siur l Bulgique .
#    Dif. HTR    : [('replace', 'e', 'i'), ('insert', '', 'i'), ('delete', 'a', ''), ('replace', 'e', 'u'), ('replace', '!', '.')]
#    Corrected   : de rejeter l'odieux de l'attentat sur la Belgique.
#    Dif. Corr   : [('replace', ' !', '.')]
#    CER corr vs GT: 0.0392, WER: 0.2222
#
#  File: journal1_p.161.xml | Line 14
#    Ground Truth: Mais ce qu'il y a d'immonde, c'est que personne
#    HTR         : Mais ce qu'l y a d'vonmonde C'est que personne
#    Dif. HTR    : [('delete', 'i', ''), ('replace', 'im', 'von'), ('delete', ',', ''), ('replace', 'c', 'C')]
#    Corrected   : Mais ce qu'il y a d'immonde c'est que personne
#    Dif. Corr   : [('delete', ',', '')]
#    CER corr vs GT: 0.0213, WER: 0.1111
#
#  File: journal1_p.161.xml | Line 15
#    Ground Truth: en Allemagne n'ose prendre la parole pour s'indi¬
#    HTR         : en Albnagne n'Ore pendre la parale peur l'indi¬
#    Dif. HTR    : [('replace', 'lem', 'bn'), ('replace', 'os', 'Or'), ('delete', 'r', ''), ('replace', 'o', 'a'), ('replace', 'o', 'e'), ('replace', 's', 'l')]
#    Corrected   : en Allemagne n'ose prendre la parole pour s'indi¬
#    Dif. Corr   : []
#    CER corr vs GT: 0.0000, WER: 0.0000
#
#  File: journal1_p.161.xml | Line 16
#    Ground Truth: gner contre l'invasion d'un neutre innocent
#    HTR         : quer contre l'invasion d'un neute imsrent
#    Dif. HTR    : [('replace', 'gn', 'qu'), ('delete', 'r', ''), ('replace', 'nnoc', 'msr')]
#    Corrected   : gner contre l'invasion d'un neutre innocent
#    Dif. Corr   : []
#    CER corr vs GT: 0.0000, WER: 0.0000
#
#  File: journal1_p.161.xml | Line 17
#    Ground Truth: Article idiot de Rud. Eucken dans la Frankfurter Zei¬
#    HTR         : Artice idiot d Rud. Eunken dans le Frautefeuter zi¬
#    Dif. HTR    : [('delete', 'l', ''), ('delete', 'e', ''), ('replace', 'c', 'n'), ('replace', 'a', 'e'), ('replace', 'nk', 'ute'), ('insert', '', 'e'), ('delete', 'r', ''), ('replace', 'Ze', 'z')]
#    Corrected   : Article idiot de Rud. Eucken dans la Frankfurter Ze¬
#    Dif. Corr   : [('delete', 'i', '')]
#    CER corr vs GT: 0.0189, WER: 0.1111
#
#  File: journal1_p.161.xml | Line 18
#    Ground Truth: tung du 1 janvier. Le peuple allemand est supérieur
#    HTR         : teuex du 1jauire. Le peuple Alleemand est sespérius
#    Dif. HTR    : [('insert', '', 'e'), ('replace', 'ng', 'ex'), ('delete', ' ', ''), ('replace', 'nv', 'u'), ('insert', '', 'r'), ('delete', 'r', ''), ('replace', 'a', 'A'), ('insert', '', 'e'), ('replace', 'u', 'es'), ('delete', 'e', ''), ('replace', 'r', 's')]
#    Corrected   : itung du 1jauire. Le peuple allemand est supérieur
#    Dif. Corr   : [('insert', '', 'i'), ('delete', ' ', ''), ('replace', 'nv', 'u'), ('insert', '', 'r'), ('delete', 'r', '')]
#    CER corr vs GT: 0.1176, WER: 0.3333
#
#  File: journal1_p.161.xml | Line 19
#    Ground Truth: à tous les peuples par son "Inhaltskultur". Personne ne la
#    HTR         : à tous les peuples par son a Inhaltakaltus". Percone en la
#    Dif. HTR    : [('replace', 'à', 'à'), ('replace', '"', 'a '), ('replace', 's', 'a'), ('replace', 'u', 'a'), ('replace', 'r', 's'), ('replace', 's', 'c'), ('delete', 'n', ''), ('insert', '', 'e'), ('delete', 'e', '')]
#    Corrected   : à tous les peuples par son « Inhaltskultur ". Personne ne la
#    Dif. Corr   : [('replace', '"', '« '), ('insert', '', ' ')]
#    CER corr vs GT: 0.0517, WER: 0.3000
#
#  File: journal1_p.161.xml | Line 20
#    Ground Truth: comprend. On la comprendra après la victoire. Ce que les autres
#    HTR         : comprend. On la comprendra après le Victoire. E que le aute
#    Dif. HTR    : [('replace', 'a', 'e'), ('replace', 'v', 'V'), ('replace', 'Ce', 'E'), ('delete', 's', ''), ('delete', 'r', ''), ('delete', 's', '')]
#    Corrected   : comprend. On la comprendra après la victoire. Ce que les autres
#    Dif. Corr   : []
#    CER corr vs GT: 0.0000, WER: 0.0000
#
#  File: journal1_p.161.xml | Line 21
#    Ground Truth: peuples ont donné n'est que "Formkultur". Mais la paix venue
#    HTR         : peuples ont donné n'it que " Foriubaltur". Mais l paix venne
#    Dif. HTR    : [('replace', 'es', 'i'), ('insert', '', ' '), ('replace', 'mk', 'i'), ('insert', '', 'ba'), ('delete', 'a', ''), ('replace', 'u', 'n')]
#    Corrected   : peuples ont donné n'est que "Formkultur". Mais la paix venue
#    Dif. Corr   : []
#    CER corr vs GT: 0.0000, WER: 0.0000
#
#  File: journal1_p.161.xml | Line 22
#    Ground Truth: le peuple allemand ne doit pas se replier sur la race mais
#    HTR         : le peuple allemand n dert par se replies siun le rais mais
#    Dif. HTR    : [('delete', 'e', ''), ('replace', 'oi', 'er'), ('replace', 's', 'r'), ('replace', 'r', 's'), ('insert', '', 'i'), ('replace', 'r', 'n'), ('replace', 'a', 'e'), ('replace', 'ce', 'is')]
#    Corrected   : le peuple allemand ne doit pas se replier sur la race mais
#    Dif. Corr   : []
#    CER corr vs GT: 0.0000, WER: 0.0000
#
#  File: journal1_p.161.xml | Line 23
#    Ground Truth: conserver le contact avec l'humanité! Et c'est un
#    HTR         : consuver le contait avec l'hemanite! Et c'est run
#    Dif. HTR    : [('replace', 'er', 'u'), ('replace', 'c', 'i'), ('replace', 'u', 'e'), ('replace', 'é', 'e'), ('insert', '', 'r')]
#    Corrected   : conserver le contact avec l'humanité! Et c'est un
#    Dif. Corr   : []
#    CER corr vs GT: 0.0000, WER: 0.0000
#
#  File: journal1_p.161.xml | Line 24
#    Ground Truth: philosophe qui parle! La preuve pour lui de la supériorité du
#    HTR         : philirophe qui parle ! L preuve poou lui el l hreperisiti re
#    Dif. HTR    : [('replace', 'os', 'ir'), ('insert', '', ' '), ('delete', 'a', ''), ('insert', '', 'o'), ('delete', 'r', ''), ('delete', 'd', ''), ('insert', '', 'l'), ('delete', 'a', ''), ('replace', 'su', 'hre'), ('replace', 'é', 'e'), ('replace', 'or', 's'), ('replace', 'é', 'i'), ('replace', 'du', 're')]
#    Corrected   : philosophe qui parle! La preuve pour lui de la supériorité du
#    Dif. Corr   : []
#    CER corr vs GT: 0.0000, WER: 0.0000
#
#  File: journal1_p.161.xml | Line 25
#    Ground Truth: peuple allemand est dans son unité et son héroïsme
#    HTR         : peuple Allema est dans son linité et son hérirone
#    Dif. HTR    : [('replace', 'a', 'A'), ('delete', 'nd', ''), ('replace', 'u', 'li'), ('insert', '', 'ir'), ('replace', 'ïsm', 'n')]
# ...
#    Corrected   : vre jaune français, accuse le ministre ters belge de tra¬
#    Dif. Corr   : [('insert', '', 'ters ')]
#    CER corr vs GT: 0.0962, WER: 0.1111
#
#  File: journal1_p.218.xml | Line 6
#    Ground Truth: hison, pace quil aurait refusé le 3 août l'envoi
#    HTR         : Lison, panequ il arvait refusé t 3 Aont l'envai
#    Dif. HTR    : [('replace', 'h', 'L'), ('replace', 'c', 'n'), ('delete', ' ', ''), ('insert', '', ' '), ('delete', 'u', ''), ('insert', '', 'v'), ('replace', 'le', 't'), ('replace', 'a', 'A'), ('replace', 'û', 'n'), ('replace', 'o', 'a')]
#    Corrected   : hison, parce il aurait refusé le 3 août l'envoi
#    Dif. Corr   : [('insert', '', 'r'), ('delete', 'qu', '')]
#    CER corr vs GT: 0.0625, WER: 0.2222
#
#  File: journal1_p.218.xml | Line 7
#    Ground Truth: de 5 corps d'armée français. Attendons! Le moment
#    HTR         : e S Cups d'Armée fraumais. Attendoes ! Ls monent
#    Dif. HTR    : [('delete', 'd', ''), ('replace', '5', 'S'), ('replace', 'cor', 'Cu'), ('replace', 'a', 'A'), ('replace', 'nç', 'um'), ('replace', 'n', 'e'), ('insert', '', ' '), ('replace', 'e', 's'), ('replace', 'm', 'n')]
#    Corrected   : de S corps d'armée français. Attendons! Le moment
#    Dif. Corr   : [('replace', '5', 'S')]
#    CER corr vs GT: 0.0204, WER: 0.1250
#
#  File: journal1_p.218.xml | Line 8
#    Ground Truth: n'est pas aux récriminations. Je doute d'ailleurs
#    HTR         : n'est pas aux récréniinations. Je dont d'aillenes
#    Dif. HTR    : [('insert', '', 'én'), ('delete', 'm', ''), ('replace', 'u', 'n'), ('delete', 'e', ''), ('replace', 'ur', 'ne')]
#    Corrected   : n'est pas aux récriminations. Je doute d'ailleurs
#    Dif. Corr   : []
#    CER corr vs GT: 0.0000, WER: 0.0000
#
#  File: journal1_p.218.xml | Line 9
#    Ground Truth: que si les Français avaient pu envoyer 5 corps d'ar¬
#    HTR         : que se les Français avaient pu énvoyer S conps d' Ar¬
#    Dif. HTR    : [('replace', 'i', 'e'), ('replace', 'e', 'é'), ('replace', '5', 'S'), ('replace', 'r', 'n'), ('replace', 'a', ' A')]
#    Corrected   : que si les Français avaient pu envoyer S corps d'ar¬
#    Dif. Corr   : [('replace', '5', 'S')]
#    CER corr vs GT: 0.0192, WER: 0.1000
#
#  File: journal1_p.218.xml | Line 10
#    Ground Truth: mée à Liège le 3 août, ils eussent négligé de le faire.
#    HTR         : mée à Lieg le 3 Aont, ils cussent vrégligé de le faire.
#    Dif. HTR    : [('replace', 'à', 'à'), ('replace', 'è', 'e'), ('delete', 'e', ''), ('replace', 'a', 'A'), ('replace', 'û', 'n'), ('replace', 'e', 'c'), ('replace', 'n', 'vr')]
#    Corrected   : mée à Liège le 3 août, ils eussent négligé de le faire.
#    Dif. Corr   : []
#    CER corr vs GT: 0.0000, WER: 0.0000
#
#  File: journal1_p.218.xml | Line 11
#    Ground Truth: Leur devoir était de protéger la neutralité belge
#    HTR         : Leur devoir était de protiger la ventialiti, bilqe
#    Dif. HTR    : [('replace', 'é', 'i'), ('insert', '', 've'), ('delete', 'eu', ''), ('replace', 'r', 'i'), ('replace', 'é', 'i,'), ('insert', '', 'ilq'), ('delete', 'lge', '')]
#    Corrected   : Leur devoir était de protéger la neutralité, bilqe
#    Dif. Corr   : [('insert', '', ','), ('insert', '', 'ilq'), ('delete', 'lge', '')]
#    CER corr vs GT: 0.0612, WER: 0.2500
#
#  File: journal1_p.218.xml | Line 12
#    Ground Truth: même malgré la Belgique.
#    HTR         : ême malqri le Rilgique.
#    Dif. HTR    : [('delete', 'm', ''), ('replace', 'g', 'q'), ('replace', 'é', 'i'), ('replace', 'a', 'e'), ('replace', 'Be', 'Ri')]
#    Corrected   : même malgré la Belgique.
#    Dif. Corr   : []
#    CER corr vs GT: 0.0000, WER: 0.0000
#
#  File: journal1_p.218.xml | Line 13
#    Ground Truth: Apparition de la Vl. Post. Titre en lettres gothiques.
#    HTR         : Apparition d le Vl. Port. Titre ces littes gothiques.
#    Dif. HTR    : [('delete', 'e', ''), ('replace', 'a', 'e'), ('replace', 's', 'r'), ('insert', '', 'c'), ('replace', 'n', 's'), ('replace', 'e', 'i'), ('delete', 'r', '')]
#    Corrected   : Apparition de la Vl. Post. Titre en lettres gothiques.
#    Dif. Corr   : []
#    CER corr vs GT: 0.0000, WER: 0.0000
#
#  File: journal1_p.218.xml | Line 14
#    Ground Truth: C'est l'apparence d'un journal allemand. 8 pages.
#    HTR         : C'ist l'appaene  un jonal allemand. 8 fages.
#    Dif. HTR    : [('replace', 'e', 'i'), ('delete', 'r', ''), ('delete', 'c', ''), ('replace', "d'", ' '), ('delete', 'ur', ''), ('replace', 'p', 'f')]
#    Corrected   : C'est l'apparence un journal allemand. 8 pages.
#    Dif. Corr   : [('delete', "d'", '')]
#    CER corr vs GT: 0.0408, WER: 0.1429
#
#  File: journal1_p.218.xml | Line 15
#    Ground Truth: Dans le premier article où on expose pourquoi le jour¬
#    HTR         : Dans la preiie Article où on expose purquoi l prim¬
#    Dif. HTR    : [('replace', 'e', 'a'), ('replace', 'm', 'i'), ('delete', 'r', ''), ('replace', 'a', 'A'), ('delete', 'o', ''), ('delete', 'e', ''), ('replace', 'jou', 'p'), ('insert', '', 'im')]
#    Corrected   : Dans le premier article où on expose pourquoi le jour¬
#    Dif. Corr   : []
#    CER corr vs GT: 0.0000, WER: 0.0000
#
#  File: journal1_p.218.xml | Line 16
#    Ground Truth: nal paraît ceci: "Défendre le mouvement fla¬
#    HTR         : nat parait ceci : "Defendre le mouvement fla¬
#    Dif. HTR    : [('replace', 'l', 't'), ('replace', 'î', 'i'), ('insert', '', ' '), ('replace', 'é', 'e')]
#    Corrected   : nal paraît ceci: " Défendre le mouvement fla¬
#    Dif. Corr   : [('insert', '', ' ')]
#    CER corr vs GT: 0.0227, WER: 0.2857
#
#  File: journal1_p.218.xml | Line 17
#    Ground Truth: mand afin que nos amis combattant dans
#    HTR         : mand afin que nos anes combathant dans
#    Dif. HTR    : [('replace', 'mi', 'ne'), ('replace', 't', 'h')]
#    Corrected   : mand afin que nos amis combattant dans
#    Dif. Corr   : []
#    CER corr vs GT: 0.0000, WER: 0.0000
#
#  File: journal1_p.218.xml | Line 18
#    Ground Truth: l'armée belge ne puissent pas nous reprocher
#    HTR         : l'armée bels ne puissent pas Nos reprocher
#    Dif. HTR    : [('replace', 'ge', 's'), ('replace', 'n', 'N'), ('delete', 'u', '')]
#    Corrected   : l'armée belge ne puissent pas nous reprocher
#    Dif. Corr   : []
#    CER corr vs GT: 0.0000, WER: 0.0000
#
#  File: journal1_p.218.xml | Line 19
#    Ground Truth: notre lâcheté à leur retour"! Ce sont des incons¬
#    HTR         : notu lachet à leur retoir"? Ce sont en incirer¬
#    Dif. HTR    : [('replace', 're', 'u'), ('replace', 'â', 'a'), ('delete', 'é', ''), ('replace', 'à', 'à'), ('replace', 'u', 'i'), ('replace', '!', '?'), ('delete', 'd', ''), ('replace', 's', 'n'), ('replace', 'ons', 'irer')]
#    Corrected   : notre lâcheté à leur retour "? Ce sont des inconsc¬
#    Dif. Corr   : [('insert', '', ' '), ('replace', '!', '?'), ('insert', '', 'c')]
#    CER corr vs GT: 0.0612, WER: 0.3333
#
#  File: journal1_p.218.xml | Line 20
#    Ground Truth: cients. Mais combien malpropres!
#    HTR         : Cieuts. Mais coumtien malprapres :
#    Dif. HTR    : [('replace', 'c', 'C'), ('replace', 'n', 'u'), ('insert', '', 'u'), ('replace', 'b', 't'), ('replace', 'o', 'a'), ('replace', '!', ' :')]
#    Corrected   : ients. Mais combien malpropres:
#    Dif. Corr   : [('delete', 'c', ''), ('replace', '!', ':')]
#    CER corr vs GT: 0.0625, WER: 0.5000
#
#  File: journal1_p.218.xml | Line 21
#    Ground Truth: Il paraît que les Allemands veulent supprimer le mo¬
#    HTR         : Il parait que les Allemands Venlent suppriver le Mo¬
#    Dif. HTR    : [('replace', 'î', 'i'), ('replace', 'v', 'V'), ('replace', 'u', 'n'), ('replace', 'm', 'v'), ('replace', 'm', 'M')]
#    Corrected   : Il paraît que les Allemands veulent supprimer le mo¬
#    Dif. Corr   : []
#    CER corr vs GT: 0.0000, WER: 0.0000
#
#  File: journal1_p.218.xml | Line 22
#    Ground Truth: ratorium en Belgique. Ce sera le moyen de provoquer la
#    HTR         : ratoriun ee Belgique. Ce Lera la moyen de juovaprer la
#    Dif. HTR    : [('replace', 'm', 'n'), ('replace', 'n', 'e'), ('replace', 's', 'L'), ('replace', 'e', 'a'), ('insert', '', 'juova'), ('delete', 'ovoqu', '')]
#    Corrected   : ratorium en Belgique. Ce sera le moyen de provoquer la
#    Dif. Corr   : []
#    CER corr vs GT: 0.0000, WER: 0.0000
#
#  File: journal1_p.218.xml | Line 23
#    Ground Truth: faillite de tous les industriels mais en même temps
#    HTR         : faillite d tius les molustrichs mais en même temps
#    Dif. HTR    : [('delete', 'e', ''), ('replace', 'o', 'i'), ('replace', 'ind', 'mol'), ('replace', 'el', 'ch')]
#    Corrected   : faillite de tous les industriels mais en même temps
#    Dif. Corr   : []
#    CER corr vs GT: 0.0000, WER: 0.0000
#
#  File: journal1_p.218.xml | Line 24
#    Ground Truth: un afflux d'argent vers l'Allemagne.
#    HTR         : Un afplux d'Argent ven l'Allemagne.
#    Dif. HTR    : [('replace', 'u', 'U'), ('replace', 'f', 'p'), ('replace', 'a', 'A'), ('replace', 'rs', 'n')]
#    Corrected   : un afflux d'argent vers l'Allemagne.
#    Dif. Corr   : []
#    CER corr vs GT: 0.0000, WER: 0.0000
#
#  File: journal1_p.218.xml | Line 25
#    Ground Truth: J'achète le 1^er gouvernement à la brochure allemande
#    HTR         : 'achête le 1e tupplement à la brochie albemande
#    Dif. HTR    : [('delete', 'J', ''), ('replace', 'è', 'ê'), ('delete', '^', ''), ('delete', 'r', ''), ('replace', 'go', 't'), ('replace', 'vern', 'ppl'), ('replace', 'à', 'à'), ('replace', 'ur', 'i'), ('replace', 'l', 'b')]
#    Corrected   : 'achète le 1e supplément à la brochure allemande
#    Dif. Corr   : [('delete', 'J', ''), ('delete', '^', ''), ('delete', 'r', ''), ('replace', 'go', 's'), ('replace', 'verne', 'pplé')]
#    CER corr vs GT: 0.1887, WER: 0.3750
#
#  File: journal1_p.218.xml | Line 26
#    Ground Truth: des Avis et Nouvelles publiés par le gouvernement alle¬
#    HTR         : des Aies et Nouvilles publies pas le gouvenenent alle¬
#    Dif. HTR    : [('delete', 'v', ''), ('insert', '', 'e'), ('replace', 'e', 'i'), ('replace', 'é', 'e'), ('replace', 'r', 's'), ('delete', 'r', ''), ('replace', 'm', 'n')]
#    Corrected   : des Avis et Nouvelles publiée par le gouvernement alle¬
#    Dif. Corr   : [('replace', 's', 'e')]
#    CER corr vs GT: 0.0182, WER: 0.1111
#
#  File: journal1_p.218.xml | Line 27
#    Ground Truth: mand. Il est inouï de continuer cette publication.
#    HTR         : mand. Il est inoni de contrnuer Cette publication.
#    Dif. HTR    : [('replace', 'uï', 'ni'), ('replace', 'i', 'r'), ('replace', 'c', 'C')]
#    Corrected   : mand. Il est inouï de continuer cette publication.
#    Dif. Corr   : []
#    CER corr vs GT: 0.0000, WER: 0.0000
#
#  File: journal1_p.218.xml | Line 28
#    Ground Truth: Ces gens ne se doutent donc pas des motifs pour lesquels
#    HTR         : Ees gus ne se tontent donc pas de Imotifs porr lesquels
#    Dif. HTR    : [('replace', 'C', 'E'), ('replace', 'en', 'u'), ('replace', 'd', 't'), ('replace', 'u', 'n'), ('delete', 's', ''), ('insert', '', 'I'), ('replace', 'u', 'r')]
#    Corrected   : Ces gens ne se doutent donc pas des motifs pour lesquels
#    Dif. Corr   : []
#    CER corr vs GT: 0.0000, WER: 0.0000
#
#  File: journal1_p.218.xml | Line 29
#    Ground Truth: on les achète!
#    HTR         : on ln'achêté.
#    Dif. HTR    : [('replace', 'es ', "n'"), ('replace', 'è', 'ê'), ('replace', 'e!', 'é.')]
#    Corrected   : on les'achêté.
#    Dif. Corr   : [('replace', ' ', "'"), ('replace', 'è', 'ê'), ('replace', 'e!', 'é.')]
#    CER corr vs GT: 0.2857, WER: 0.6667
#
#  File: journal1_p.218.xml | Line 30
#    Ground Truth: Des bruits circulent: les Allemands ont passé l'Yserm
#    HTR         : Des bruits circulent : les Allemands ont passi l'her
#    Dif. HTR    : [('insert', '', ' '), ('replace', 'é', 'i'), ('replace', 'Ys', 'h'), ('delete', 'm', '')]
#    Corrected   : Des bruits circulent: les Allemands ont passé l'Yser
#    Dif. Corr   : [('delete', 'm', '')]
#    CER corr vs GT: 0.0189, WER: 0.1250
#
#  File: journal1_p.218.xml | Line 31
#    Ground Truth: ils ont remporté sur mer une grande victoire. Ce
#    HTR         : ils ont remporté lur mer une grande virtoire. Ces
#    Dif. HTR    : [('replace', 's', 'l'), ('replace', 'c', 'r'), ('insert', '', 's')]
#    Corrected   : ils ont remporté sur mer une grande victoire. Ce
#    Dif. Corr   : []
#    CER corr vs GT: 0.0000, WER: 0.0000
#
#  File: journal1_p.218.xml | Line 32
#    Ground Truth: sont de simples répliques du découragement produit
#    HTR         : sont de timples reflyes du décinagement produit
#    Dif. HTR    : [('replace', 's', 't'), ('replace', 'ép', 'ef'), ('replace', 'iqu', 'y'), ('replace', 'our', 'in')]
#    Corrected   : sont de simples répliques du découragement produit
#    Dif. Corr   : []
#    CER corr vs GT: 0.0000, WER: 0.0000
#
#  File: journal1_p.218.xml | Line 33
#    Ground Truth: par le recul russe. Pas un mot de tout cela dans
#    HTR         : par le recul Rrisse. Pas un mat de tont cela dans
#    Dif. HTR    : [('insert', '', 'R'), ('replace', 'u', 'i'), ('replace', 'o', 'a'), ('replace', 'u', 'n')]
#    Corrected   : par le recul russe. Pas un mot de tout cela dans
#    Dif. Corr   : []
#    CER corr vs GT: 0.0000, WER: 0.0000
#
#  File: journal1_p.218.xml | Line 34
#    Ground Truth: la dépêche allemande affichée à la Poste. Au con¬
#    HTR         : la dépêche Allemande affichée à la Poste. Oes con¬
#    Dif. HTR    : [('replace', 'a', 'A'), ('replace', 'à', 'à'), ('replace', 'Au', 'Oes')]
#    Corrected   : la dépêche allemande affichée à la Poste. Au con¬
#    Dif. Corr   : []
#    CER corr vs GT: 0.0000, WER: 0.0000
#
#  File: journal1_p.218.xml | Line 35
#    Ground Truth: traire il semble que les Russes reprennent l'offensive.
#    HTR         : fraire il semble que le Russes reprenent l'offincève.
#    Dif. HTR    : [('replace', 't', 'f'), ('delete', 's', ''), ('delete', 'n', ''), ('replace', 'e', 'i'), ('replace', 'si', 'cè')]
#    Corrected   : traire il semble que les Russes reprennent l'offensive.
#    Dif. Corr   : []
#    CER corr vs GT: 0.0000, WER: 0.0000
#
#  File: journal1_p.218.xml | Line 36
#    Ground Truth: Donné à d'Hoop les papiers d'état-civil à envoyer à
#    HTR         : Doné à d'Hoop les papiers d'état-civil à Cavvoyer à
#    Dif. HTR    : [('delete', 'n', ''), ('replace', 'à', 'à'), ('replace', 'à', 'à'), ('replace', 'en', 'Cav'), ('replace', 'à', 'à')]
#    Corrected   : Donné à d'Hoop les papiers d'état-civil à envoyer à
#    Dif. Corr   : []
#    CER corr vs GT: 0.0000, WER: 0.0000
#
#  File: journal1_p.218.xml | Line 37
#    Ground Truth: Jacques.
#    HTR         : Jaeques
#    Dif. HTR    : [('replace', 'c', 'e'), ('delete', '.', '')]
#    Corrected   : Jacques
#    Dif. Corr   : [('delete', '.', '')]
#    CER corr vs GT: 0.1250, WER: 1.0000
#
#  File: journal1_p.218.xml | Line 38
#    Ground Truth: Dîner avec Marie Delecourt et Paul V. D. Haeghen. Inutile
#    HTR         : Dines avec Marie Debuont et Gaul V. d. Wrighes Tuntit
#    Dif. HTR    : [('replace', 'î', 'i'), ('replace', 'r', 's'), ('replace', 'lec', 'bu'), ('replace', 'ur', 'n'), ('replace', 'P', 'G'), ('replace', 'D', 'd'), ('replace', 'Hae', 'Wri'), ('insert', '', 's Tu'), ('delete', '. Inu', ''), ('replace', 'le', 't')]
#    Corrected   : Dîner avec Marie Delecourt et Paul Van Haeghen Inutile
#    Dif. Corr   : [('replace', '. D.', 'an'), ('delete', '.', '')]
#    CER corr vs GT: 0.0877, WER: 0.3000
#
#  File: journal1_p.218.xml | Line 39
#    Ground Truth: de l'interroger sur son séjour en Angleterre. Il n'a rien vu
#    HTR         : d l'interoyer sur sus séjou en Angltorrs. Il n'a rien du
#    Dif. HTR    : [('delete', 'e', ''), ('delete', 'r', ''), ('replace', 'g', 'y'), ('replace', 'on', 'us'), ('delete', 'r', ''), ('delete', 'e', ''), ('replace', 'e', 'o'), ('replace', 'e', 's'), ('replace', 'v', 'd')]
#    Corrected   : de l'interroger sur son séjour en Angleterre. Il n'a rien vu
#    Dif. Corr   : []
#    CER corr vs GT: 0.0000, WER: 0.0000
#
#  File: journal1_p.218.xml | Line 40
#    Ground Truth: et revient tel qu'il était parti.
#    HTR         : et revrent tet qu'l était parts
#    Dif. HTR    : [('replace', 'i', 'r'), ('replace', 'l', 't'), ('delete', 'i', ''), ('replace', 'i.', 's')]
#    Corrected   : et revient tel qui'il était parti
#    Dif. Corr   : [('insert', '', 'i'), ('delete', '.', '')]
#    CER corr vs GT: 0.0606, WER: 0.3333
