# %%
## Regarder les erreurs

import os
import xml.etree.ElementTree as ET
from difflib import SequenceMatcher
from evaluate import load

ground_truth_folder = "manuscript_groundtruth"
htr_folder = "manuscript_htr24"
corrected_folder = "manuscript_final"

def extract_lines_from_alto(path):
    tree = ET.parse(path)
    root = tree.getroot()
    ns = {'a': 'http://www.loc.gov/standards/alto/ns-v4#'}
    strings = root.findall(".//a:String", ns)
    return [s.attrib.get("CONTENT", "").strip() for s in strings]

def diff_chars(s1, s2):
    sm = SequenceMatcher(None, s1, s2)
    return [(tag, s1[a:b], s2[c:d]) for tag, a, b, c, d in sm.get_opcodes() if tag != 'equal']

wer = load("wer")
cer = load("cer")

files = sorted(os.listdir(ground_truth_folder))
total_lines = 0

for filename in files:
    if not filename.endswith(".xml"):
        continue

    gt_path = os.path.join(ground_truth_folder, filename)
    htr_path = os.path.join(htr_folder, filename)
    corr_path = os.path.join(corrected_folder, filename)

    gt_lines = extract_lines_from_alto(gt_path)
    htr_lines = extract_lines_from_alto(htr_path)
    corr_lines = extract_lines_from_alto(corr_path)

    for i, (gt, htr, corr) in enumerate(zip(gt_lines, htr_lines, corr_lines)):
        htr_diff = diff_chars(gt, htr)
        corr_diff = diff_chars(gt, corr)
        wer_score = wer.compute(predictions=[corr], references=[gt])
        cer_score = cer.compute(predictions=[corr], references=[gt])

        print(f" File: {filename} | Line {i+1}")
        print(f"   Ground Truth: {gt}")
        print(f"   HTR         : {htr}")
        print(f"   Dif. HTR    : {htr_diff}")
        print(f"   Corrected   : {corr}")
        print(f"   Dif. Corr   : {corr_diff}")
        print(f"   CER corr vs GT: {cer_score:.4f}, WER: {wer_score:.4f}")
        print()
        total_lines += 1
# Out:
#  File: ARCH-DIV-000494_0037.xml | Line 1
#    Ground Truth: 29
#    HTR         : 29
#    Dif. HTR    : []
#    Corrected   : 29
#    Dif. Corr   : []
#    CER corr vs GT: 0.0000, WER: 0.0000
#
#  File: ARCH-DIV-000494_0037.xml | Line 2
#    Ground Truth: Chapitre II
#    HTR         : Chapitre "1
#    Dif. HTR    : [('replace', 'II', '"1')]
#    Corrected   : Chapitre " 1
#    Dif. Corr   : [('replace', 'II', '" 1')]
#    CER corr vs GT: 0.2727, WER: 1.0000
#
#  File: ARCH-DIV-000494_0037.xml | Line 3
#    Ground Truth: I
#    HTR         : 7
#    Dif. HTR    : [('replace', 'I', '7')]
#    Corrected   : du
#    Dif. Corr   : [('replace', 'I', 'du')]
#    CER corr vs GT: 2.0000, WER: 1.0000
#
#  File: ARCH-DIV-000494_0037.xml | Line 4
#    Ground Truth: Jusque vers le milieu du XI^e siècle, les princes
#    HTR         : pesique ver la Vi li en du Il sécle ls prunees
#    Dif. HTR    : [('replace', 'Ju', 'pe'), ('insert', '', 'i'), ('delete', 's', ''), ('replace', 'e', 'a'), ('replace', 'm', 'V'), ('insert', '', ' '), ('insert', '', ' '), ('replace', 'u', 'n'), ('delete', 'X', ''), ('replace', '^e', 'l'), ('replace', 'iè', 'é'), ('delete', ',', ''), ('delete', 'e', ''), ('replace', 'i', 'u'), ('replace', 'c', 'e')]
#    Corrected   : pesique^e Vi, les du, sécle ls prunees
#    Dif. Corr   : [('replace', 'Ju', 'pe'), ('insert', '', 'i'), ('delete', ' vers le milieu du XI', ''), ('replace', 's', 'V'), ('delete', 'ècle', ''), ('insert', '', 'du, sécle ls '), ('replace', 'i', 'u'), ('replace', 'c', 'e')]
#    CER corr vs GT: 0.5102, WER: 1.0000
#
#  File: ARCH-DIV-000494_0037.xml | Line 5
#    Ground Truth: comme on l'a vu plus haut, ne se sont pas occupés
#    HTR         : commm on l'a vu plus haut, ne desont pas occupés
#    Dif. HTR    : [('replace', 'e', 'm'), ('replace', 's', 'd'), ('delete', ' ', '')]
#    Corrected   : comme on l'a vu plus haut, ne sont pas occupés
#    Dif. Corr   : [('delete', 'e s', '')]
#    CER corr vs GT: 0.0612, WER: 0.0909
#
#  File: ARCH-DIV-000494_0037.xml | Line 6
#    Ground Truth: des colonies marchandes. Abandonnées à elles-
#    HTR         : des colooies maritandes. Abandoinées à elleu¬
#    Dif. HTR    : [('replace', 'n', 'o'), ('replace', 'ch', 'it'), ('replace', 'n', 'i'), ('replace', 'à', 'à'), ('replace', 's-', 'u¬')]
#    Corrected   : des colonies marchandes. Abandonnées à ̀ elleu¬
#    Dif. Corr   : [('insert', '', '̀ '), ('replace', 's-', 'u¬')]
#    CER corr vs GT: 0.0889, WER: 0.3333
#
#  File: ARCH-DIV-000494_0037.xml | Line 7
#    Ground Truth: simple
#    HTR         : simple
#    Dif. HTR    : []
#    Corrected   : simple
#    Dif. Corr   : []
#    CER corr vs GT: 0.0000, WER: 0.0000
#
#  File: ARCH-DIV-000494_0037.xml | Line 8
#    Ground Truth: mêmès, celles-ci ont créé un état de fait auquel
#    HTR         : mêmes, celle, cn ont créi iystat et fait auquel
#    Dif. HTR    : [('replace', 'è', 'e'), ('replace', 's-', ', '), ('replace', 'i', 'n'), ('replace', 'é', 'i'), ('replace', 'un é', 'iys'), ('delete', 'd', ''), ('insert', '', 't')]
#    Corrected   : mêmes, celles, ci ont créé état de fait auquel
#    Dif. Corr   : [('replace', 'è', 'e'), ('replace', '-', ', '), ('delete', ' un', '')]
#    CER corr vs GT: 0.1250, WER: 0.4444
#
#  File: ARCH-DIV-000494_0037.xml | Line 9
#    Ground Truth: manque, avec la consécration légale, toute garantie
#    HTR         : manque, aver la consicratin légale, toute garantie
#    Dif. HTR    : [('replace', 'c', 'r'), ('replace', 'é', 'i'), ('delete', 'o', '')]
#    Corrected   : manque, avec la consécration légale, toute garantie
#    Dif. Corr   : []
#    CER corr vs GT: 0.0000, WER: 0.0000
#
#  File: ARCH-DIV-000494_0037.xml | Line 10
#    Ground Truth: sérieuse de durée. Pour qu'il devienne un état de
#    HTR         : sériise de durie. Pour qu'il devienue tlp Etat de
#    Dif. HTR    : [('replace', 'eu', 'i'), ('replace', 'é', 'i'), ('replace', 'n', 'u'), ('replace', 'un', 'tlp'), ('replace', 'é', 'E')]
#    Corrected   : sérieuse de durée. Pour qu'il devienne un état de
#    Dif. Corr   : []
#    CER corr vs GT: 0.0000, WER: 0.0000
#
#  File: ARCH-DIV-000494_0037.xml | Line 11
#    Ground Truth: droit, pour que le portus se transforme en ville, et les
#    HTR         : droit, pou que le portus Syteans forme les ville et des
#    Dif. HTR    : [('delete', 'r', ''), ('replace', 's', 'Syt'), ('delete', ' tr', ''), ('insert', '', ' '), ('insert', '', 'l'), ('replace', 'n', 's'), ('delete', ',', ''), ('replace', 'l', 'd')]
#    Corrected   : droit, pour que le portus Syteans forme en ville et ses
#    Dif. Corr   : [('replace', 's', 'Syt'), ('delete', ' tr', ''), ('insert', '', ' '), ('delete', ',', ''), ('replace', 'l', 's')]
#    CER corr vs GT: 0.1250, WER: 0.3636
#
#  File: ARCH-DIV-000494_0037.xml | Line 12
#    Ground Truth: l'
#    HTR         : 11
#    Dif. HTR    : [('replace', "l'", '11')]
#    Corrected   : 11
#    Dif. Corr   : [('replace', "l'", '11')]
#    CER corr vs GT: 1.0000, WER: 1.0000
#
#  File: ARCH-DIV-000494_0037.xml | Line 13
#    Ground Truth: habitants en bourgeois, pour que enfin <....> auto¬
#    HTR         : tabitant en baugerii, pounque infin, Laveaai into¬
#    Dif. HTR    : [('replace', 'h', 't'), ('delete', 's', ''), ('replace', 'o', 'a'), ('delete', 'r', ''), ('replace', 'o', 'r'), ('replace', 's', 'i'), ('replace', 'r ', 'n'), ('replace', 'e', 'i'), ('insert', '', ','), ('replace', '<....>', 'Laveaai'), ('replace', 'au', 'in')]
#    Corrected   : habitants en bourgeois, pounque infin, Laveaai into¬
#    Dif. Corr   : [('replace', 'r ', 'n'), ('replace', 'e', 'i'), ('insert', '', ','), ('replace', '<....>', 'Laveaai'), ('replace', 'au', 'in')]
#    CER corr vs GT: 0.2549, WER: 0.6250
#
#  File: ARCH-DIV-000494_0037.xml | Line 14
#    Ground Truth: nomie qu'ils se sont donnée soit officiellement rati¬
#    HTR         : nomire qu'ils se tont dovmée doit officiellement rots
#    Dif. HTR    : [('insert', '', 'r'), ('replace', 's', 't'), ('replace', 'nn', 'vm'), ('replace', 's', 'd'), ('replace', 'a', 'o'), ('replace', 'i¬', 's')]
#    Corrected   : nomire qu'ils son tont dovmée soit officiellement rots
#    Dif. Corr   : [('insert', '', 'r'), ('replace', 'e', 'on'), ('replace', 's', 't'), ('replace', 'nn', 'vm'), ('replace', 'a', 'o'), ('replace', 'i¬', 's')]
#    CER corr vs GT: 0.1698, WER: 0.6250
#
#  File: ARCH-DIV-000494_0037.xml | Line 15
#    Ground Truth: fiée et que naissent les institutions qui doivent la
#    HTR         : fice et que naibent lls mititutiom qui doivent la
#    Dif. HTR    : [('replace', 'é', 'c'), ('replace', 'ss', 'b'), ('replace', 'e', 'l'), ('insert', '', 'm'), ('delete', 'ns', ''), ('replace', 'ns', 'm')]
#    Corrected   : fice et que naissent les mititutiom qui doivent la
#    Dif. Corr   : [('replace', 'é', 'c'), ('insert', '', 'm'), ('delete', 'ns', ''), ('replace', 'ns', 'm')]
#    CER corr vs GT: 0.1154, WER: 0.2222
#
#  File: ARCH-DIV-000494_0037.xml | Line 16
#    Ground Truth: compléter l'intervention du pouvoir public est
#    HTR         : compliter l'intervention des pouvoirs publets est
#    Dif. HTR    : [('replace', 'é', 'i'), ('replace', 'u', 'es'), ('insert', '', 's'), ('replace', 'ic', 'ets')]
#    Corrected   : compléter l'intervention du pouvoir public est
#    Dif. Corr   : []
#    CER corr vs GT: 0.0000, WER: 0.0000
#
#  File: ARCH-DIV-000494_0037.xml | Line 17
#    Ground Truth: indispensable. Elle est <......> en même temps iné¬
#    HTR         : indispeuarble. Ell est dradtaars en ménrle temps iné
#    Dif. HTR    : [('replace', 'ns', 'u'), ('insert', '', 'r'), ('delete', 'e', ''), ('replace', '<......>', 'dradtaars'), ('replace', 'êm', 'énrl'), ('delete', '¬', '')]
#    Corrected   : indispensable. Elle est dradtaars en même temps iné
#    Dif. Corr   : [('replace', '<......>', 'dradtaars'), ('delete', '¬', '')]
#    CER corr vs GT: 0.1961, WER: 0.2500
#
#  File: ARCH-DIV-000494_0037.xml | Line 18
#    Ground Truth: vitable. Car l'intensité croissante de la vie urbaine
#    HTR         : vitable. Car l'intenaité Civissante de la vie ilstaine
#    Dif. HTR    : [('replace', 's', 'a'), ('replace', 'cro', 'Civ'), ('replace', 'urb', 'ilst')]
#    Corrected   : vitable. Car l'intensité croissante de la vie urbaine
#    Dif. Corr   : []
#    CER corr vs GT: 0.0000, WER: 0.0000
#
#  File: ARCH-DIV-000494_0037.xml | Line 19
#    Ground Truth: va nécessairement attirer l'attention des princes et
#    HTR         : la nécessairement attirer l'attention des shuices et
#    Dif. HTR    : [('replace', 'v', 'l'), ('replace', 'pr', 'shu'), ('delete', 'n', '')]
#    Corrected   : va nécessairement attirer l'attention des princes et
#    Dif. Corr   : []
#    CER corr vs GT: 0.0000, WER: 0.0000
#
#  File: ARCH-DIV-000494_0037.xml | Line 20
#    Ground Truth: depuis lors, de siècle  en siècle, leurs rapports avec les
#    HTR         : deprrès lors de siecl on sictle, leurs rapports aves les
#    Dif. HTR    : [('replace', 'ui', 'rrè'), ('delete', ',', ''), ('replace', 'è', 'e'), ('delete', 'e', ''), ('replace', ' e', 'o'), ('delete', 'è', ''), ('insert', '', 't'), ('replace', 'c', 's')]
#    Corrected   : depuis lors de siècle en siècle, leurs rapports avec les
#    Dif. Corr   : [('delete', ',', ''), ('delete', ' ', '')]
#    CER corr vs GT: 0.0345, WER: 0.1000
#
#  File: ARCH-DIV-000494_0037.xml | Line 21
#    Ground Truth: villes ne cesseront plus de se multiplier et de se compliquer.
#    HTR         : Ailles Ne cencoont plus de se mulsiplier et de se compliquee
#    Dif. HTR    : [('replace', 'v', 'A'), ('replace', 'n', 'N'), ('replace', 'sser', 'nco'), ('replace', 't', 's'), ('replace', 'r.', 'e')]
#    Corrected   : villes ne cesseront plus de se multiplier et de se compliquer
#    Dif. Corr   : [('delete', '.', '')]
#    CER corr vs GT: 0.0161, WER: 0.0909
#
#  File: ARCH-DIV-000494_0037.xml | Line 22
#    Ground Truth: En général, dans les Pays-Bas, les princes laïques leur
#    HTR         : En générel dans le Payr. Bas, le prinles loïques Ceur
#    Dif. HTR    : [('replace', 'a', 'e'), ('delete', ',', ''), ('delete', 's', ''), ('replace', 's-', 'r. '), ('delete', 's', ''), ('replace', 'c', 'l'), ('replace', 'a', 'o'), ('replace', 'l', 'C')]
#    Corrected   : En général dans les Pays. Bas, les princes laïques leur
#    Dif. Corr   : [('delete', ',', ''), ('replace', '-', '. ')]
#    CER corr vs GT: 0.0545, WER: 0.3333
#
#  File: ARCH-DIV-000494_0037.xml | Line 23
#    Ground Truth: furent plus favorables que les princes ecclésiastiques.
#    HTR         : fuvent plus favorables que la peinces cccléciastiques
#    Dif. HTR    : [('replace', 'r', 'v'), ('replace', 'es', 'a'), ('replace', 'r', 'e'), ('replace', 'e', 'c'), ('replace', 's', 'c'), ('delete', '.', '')]
#    Corrected   : furent plus favorables que les princes ecclésiastiques
#    Dif. Corr   : [('delete', '.', '')]
#    CER corr vs GT: 0.0182, WER: 0.1429
#
#  File: ARCH-DIV-000494_0037.xml | Line 24
#    Ground Truth: Et il est très compréhensible qu'il en ait été ainsi. Les comtes
#    HTR         : Et il cet tris comprétemint le qu'il en ait étéanisi. Le cous¬
#    Dif. HTR    : [('insert', '', 'c'), ('delete', 's', ''), ('replace', 'è', 'i'), ('replace', 'h', 't'), ('insert', '', 'mi'), ('replace', 'sib', 't '), ('delete', ' ', ''), ('insert', '', 'n'), ('delete', 'n', ''), ('delete', 's', ''), ('replace', 'mte', 'u'), ('insert', '', '¬')]
#    Corrected   : Et il est très comprétemint le qu'il en ait étéanisi. Les comt¬
#    Dif. Corr   : [('replace', 'h', 't'), ('insert', '', 'mi'), ('replace', 'sib', 't '), ('delete', ' ', ''), ('insert', '', 'n'), ('delete', 'n', ''), ('replace', 'es', '¬')]
#    CER corr vs GT: 0.1719, WER: 0.4167
#
#  File: ARCH-DIV-000494_0037.xml | Line 25
#    Ground Truth: de Flandre, de Hainaut, de Hollande, les ducs de Brabant
#    HTR         : de Flandre de Rainant, d Holland. Ces ducs de Bratans
#    Dif. HTR    : [('delete', ',', ''), ('replace', 'H', 'R'), ('replace', 'u', 'n'), ('delete', 'e', ''), ('replace', 'e,', '.'), ('replace', 'l', 'C'), ('replace', 'b', 't'), ('replace', 't', 's')]
#    Corrected   : es Flandre de Hainaut, de Hollande. les ducs de Brabant
#    Dif. Corr   : [('delete', 'd', ''), ('insert', '', 's'), ('delete', ',', ''), ('replace', ',', '.')]
#    CER corr vs GT: 0.0714, WER: 0.3000
#
#  File: ARCH-DIV-000494_0037.xml | Line 26
#    Ground Truth: comme d'ailleurs toute la haute aristocratie du Moyen
#    HTR         : Coaae d Ailleurs toute la tante dus tocratie du moyta
#    Dif. HTR    : [('replace', 'c', 'C'), ('replace', 'mm', 'aa'), ('replace', "'a", ' A'), ('replace', 'h', 't'), ('replace', 'u', 'n'), ('replace', 'ari', 'du'), ('insert', '', ' '), ('replace', 'M', 'm'), ('replace', 'en', 'ta')]
#    Corrected   : comme d ailleurs toute la haute dus tocratie du Moyen
#    Dif. Corr   : [('replace', "'", ' '), ('replace', 'ari', 'du'), ('insert', '', ' ')]
#    CER corr vs GT: 0.0943, WER: 0.5000
#
#  File: ARCH-DIV-000494_0037.xml | Line 27
#    Ground Truth: <...> âge, n'étaient point sédentaires. Ils n'avaient pas
#    HTR         : tr age n'étaient point sidentaises. Ils n'avaient pas
#    Dif. HTR    : [('replace', '<...>', 'tr'), ('replace', 'â', 'a'), ('delete', ',', ''), ('replace', 'é', 'i'), ('replace', 'r', 's')]
#    Corrected   : âge, n'étaient point sédentaires. Ils n'avaient pas
#    Dif. Corr   : [('delete', '<...> ', '')]
#    CER corr vs GT: 0.1053, WER: 0.1250
#
#  File: ARCH-DIV-000494_0037.xml | Line 28
#    Ground Truth: de résidence fixe et <....> se déplaçaient continuel¬
#    HTR         : de résidence fixe et <..> se déplacaient contimnt¬
#    Dif. HTR    : [('delete', '..', ''), ('replace', 'ç', 'c'), ('insert', '', 'm'), ('replace', 'uel', 't')]
#    Corrected   : de résidence fixe et <..> se déplaçaient contimnt¬
#    Dif. Corr   : [('delete', '..', ''), ('insert', '', 'm'), ('replace', 'uel', 't')]
#    CER corr vs GT: 0.1132, WER: 0.2500
#
#  File: ARCH-DIV-000494_0037.xml | Line 29
#    Ground Truth: lement avec leur petite cour à travers leurs terres. Ne se
#    HTR         : Lemert, avec leur putiticoier, à travers lem terre. Nn se
#    Dif. HTR    : [('replace', 'l', 'L'), ('replace', 'n', 'r'), ('insert', '', ','), ('replace', 'e', 'u'), ('replace', 'e ', 'i'), ('replace', 'u', 'ie'), ('insert', '', ','), ('replace', 'à', 'à'), ('replace', 'urs', 'm'), ('delete', 's', ''), ('replace', 'e', 'n')]
#    Corrected   : Lemert, avec leur putiticoier, à ̀ travers leurs terres. Ne se
#    Dif. Corr   : [('replace', 'l', 'L'), ('replace', 'n', 'r'), ('insert', '', ','), ('replace', 'e', 'u'), ('replace', 'e ', 'i'), ('replace', 'u', 'ie'), ('insert', '', ','), ('insert', '', ' ̀')]
#    CER corr vs GT: 0.1897, WER: 0.3636
#
#  File: ARCH-DIV-000494_0037.xml | Line 30
#    Ground Truth: trouvant point en contact permanent avec la population
#    HTR         : trouvant point en contart permanent avec la papulg
#    Dif. HTR    : [('replace', 'c', 'r'), ('replace', 'o', 'a'), ('replace', 'ation', 'g')]
#    Corrected   : trouvant point en contact permanent avec la papulg
#    Dif. Corr   : [('replace', 'o', 'a'), ('replace', 'ation', 'g')]
#    CER corr vs GT: 0.1111, WER: 0.1250
#
#  File: ARCH-DIV-000494_0037.xml | Line 31
#    Ground Truth: urbaine, ils eurent donc peu d'occasions d'en¬
#    HTR         : tin vertaine, ils eurent dovc auais peu Loccasiom s'en¬
#    Dif. HTR    : [('replace', 'u', 'tin ve'), ('replace', 'b', 't'), ('replace', 'n', 'v'), ('insert', '', ' auais'), ('replace', "d'", 'L'), ('replace', 'n', 'm '), ('delete', ' d', '')]
#    Corrected   : tin urbaine, ils eurent donc auais peu Loccasiom’'en¬
#    Dif. Corr   : [('insert', '', 'tin '), ('insert', '', 'auais '), ('replace', "d'", 'L'), ('replace', 'ns d', 'm’')]
#    CER corr vs GT: 0.3478, WER: 0.5714
#
#  File: ARCH-DIV-000494_0037.xml | Line 32
#    Ground Truth: trer en conflit avec elle. <........... ........ ..........>
#    HTR         : tier en conflit Avec elle. <.......... ...........>
#    Dif. HTR    : [('replace', 'r', 'i'), ('replace', 'a', 'A'), ('delete', '. ........', ''), ('insert', '', '.')]
#    Corrected   : trer en conflit avec elle. <.....................>
#    Dif. Corr   : [('delete', ' ........ ', '')]
#    CER corr vs GT: 0.1667, WER: 0.3750
#
#  File: ARCH-DIV-000494_0037.xml | Line 33
#    Ground Truth: <....................................>
#    HTR         : Haute ................. <...
#    Dif. HTR    : [('replace', '<', 'Haute '), ('insert', '', ' <'), ('delete', '................>', '')]
#    Corrected   : Haute................. <...
#    Dif. Corr   : [('replace', '<', 'Haute'), ('insert', '', ' <'), ('delete', '................>', '')]
#    CER corr vs GT: 0.4737, WER: 2.0000
#
#  File: ARCH-DIV-000494_0037.xml | Line 34
#    Ground Truth: <.......................> Avant le XIIe siècle, la
#    HTR         : <............ ..... ...t Anant le IoIi berle, la
#    Dif. HTR    : [('insert', '', ' '), ('insert', '', ' '), ('replace', '...>', 't'), ('replace', 'v', 'n'), ('delete', 'X', ''), ('insert', '', 'o'), ('insert', '', 'i b'), ('replace', ' sièc', 'r')]
#    Corrected   : <.................... t Avant le XIIe siècle, la
#    Dif. Corr   : [('replace', '...>', ' t')]
#    CER corr vs GT: 0.0800, WER: 0.3333
#
#  File: ARCH-DIV-000494_0037.xml | Line 35
#    Ground Truth: I
#    HTR         : 8
#    Dif. HTR    : [('replace', 'I', '8')]
#    Corrected   : 8
#    Dif. Corr   : [('replace', 'I', '8')]
#    CER corr vs GT: 1.0000, WER: 1.0000
#
#  File: ARCH-DIV-000494_0038.xml | Line 1
#    Ground Truth: 30
#    HTR         : 30
#    Dif. HTR    : []
#    Corrected   : 30
#    Dif. Corr   : []
#    CER corr vs GT: 0.0000, WER: 0.0000
#
#  File: ARCH-DIV-000494_0038.xml | Line 2
#    Ground Truth: son
#    HTR         : don
#    Dif. HTR    : [('replace', 's', 'd')]
#    Corrected   : don
#    Dif. Corr   : [('replace', 's', 'd')]
#    CER corr vs GT: 0.3333, WER: 1.0000
#
#  File: ARCH-DIV-000494_0038.xml | Line 3
#    Ground Truth: conduite qu'ils adoptèrent à <...> égard fut géné¬
#    HTR         : conduite qu'ils adoptèrent à seur egard fut geré¬
#    Dif. HTR    : [('replace', '<...>', 'seur'), ('replace', 'é', 'e'), ('replace', 'én', 'er')]
#    Corrected   : conduite qu'ils adoptèrent à son égard fut géné¬
#    Dif. Corr   : [('replace', '<...>', 'son')]
#    CER corr vs GT: 0.1000, WER: 0.1250
#
#  File: ARCH-DIV-000494_0038.xml | Line 4
#    Ground Truth: ralement pacifique. <...... ... ..... .. ....>
#    HTR         : ralament palifique. Baill biin....ave
#    Dif. HTR    : [('replace', 'e', 'a'), ('replace', 'c', 'l'), ('replace', '<', 'Baill biin'), ('replace', '.. ... ..... .. ....>', 'ave')]
#    Corrected   : ralement pacifique. Baill biin.... ave
#    Dif. Corr   : [('replace', '<..', 'Baill biin'), ('replace', '... ..... .. ....>', 'ave')]
#    CER corr vs GT: 0.4348, WER: 0.7143
#
#  File: ARCH-DIV-000494_0038.xml | Line 5
#    Ground Truth: <.................................>
#    HTR         : <..... l. vll.......... ......àsofer
#    Dif. HTR    : [('insert', '', '..... l. vll'), ('insert', '', ' '), ('replace', '.................>', 'àsofer')]
#    Corrected   : <..... l. vll................ àsofer
#    Dif. Corr   : [('insert', '', '..... l. vll'), ('replace', '.................>', ' àsofer')]
#    CER corr vs GT: 0.3714, WER: 4.0000
#
#  File: ARCH-DIV-000494_0038.xml | Line 6
#    Ground Truth: <.....> De leur côté, les villes n'eurent garde <........>
#    HTR         : <..r De leur côté, le villes nneurent garde <......>
#    Dif. HTR    : [('replace', '...>', 'r'), ('delete', 's', ''), ('replace', "'", 'n'), ('delete', '..', '')]
#    Corrected   : <.. r De leur côté, les villes nneurent garde <...... >
#    Dif. Corr   : [('replace', '...>', ' r'), ('replace', "'", 'n'), ('replace', '..', ' ')]
#    CER corr vs GT: 0.1207, WER: 0.5556
#
#  File: ARCH-DIV-000494_0038.xml | Line 7
#    Ground Truth: d'inquiéter
#    HTR         : d'inquiéter
#    Dif. HTR    : []
#    Corrected   : d'inquiéter
#    Dif. Corr   : []
#    CER corr vs GT: 0.0000, WER: 0.0000
#
#  File: ARCH-DIV-000494_0038.xml | Line 8
#    Ground Truth: <..... > un pouvoir qui les protégeait contre les
#    HTR         : <....... cer pouviier qui les protégeait conte les
#    Dif. HTR    : [('insert', '', '..'), ('replace', '> un', 'cer'), ('delete', 'o', ''), ('insert', '', 'ie'), ('delete', 'r', '')]
#    Corrected   : <....... cer pouvoir qui les protégeait contre les
#    Dif. Corr   : [('insert', '', '..'), ('replace', '> un', 'cer')]
#    CER corr vs GT: 0.1020, WER: 0.3333
#
#  File: ARCH-DIV-000494_0038.xml | Line 9
#    Ground Truth: petits seigneurs locaux, voisins gênants et dange¬
#    HTR         : petit seigneurs locaux, voigins géirants et dange¬
#    Dif. HTR    : [('delete', 's', ''), ('replace', 's', 'g'), ('replace', 'ên', 'éir')]
#    Corrected   : petits seigneurs locaux, voisins gênants et dange¬
#    Dif. Corr   : []
#    CER corr vs GT: 0.0000, WER: 0.0000
#
#  File: ARCH-DIV-000494_0038.xml | Line 10
#    Ground Truth: reux, et <... .....> s'abstenait d'intervenir dans
#    HTR         : reux, et taidaaan s'abtenait d'intervenir dars
#    Dif. HTR    : [('replace', '<... .....>', 'taidaaan'), ('delete', 's', ''), ('replace', 'n', 'r')]
#    Corrected   : reux, et taidaaan s'abstenait d'intervenir dans
#    Dif. Corr   : [('replace', '<... .....>', 'taidaaan')]
#    CER corr vs GT: 0.2200, WER: 0.2857
#
#  File: ARCH-DIV-000494_0038.xml | Line 11
#    Ground Truth: qui
#    HTR         : que
#    Dif. HTR    : [('replace', 'i', 'e')]
#    Corrected   : que
#    Dif. Corr   : [('replace', 'i', 'e')]
#    CER corr vs GT: 0.3333, WER: 1.0000
#
#  File: ARCH-DIV-000494_0038.xml | Line 12
#    Ground Truth: leurs affaires. <........ ....... ..... ......>
#    HTR         : leurs affaires. w...................>
#    Dif. HTR    : [('replace', '<', 'w'), ('delete', ' ', ''), ('delete', ' ..... ..', '')]
#    Corrected   : leurs affaires. w................... >
#    Dif. Corr   : [('replace', '<', 'w...........'), ('delete', '....... ..... ......', '')]
#    CER corr vs GT: 0.2128, WER: 0.6667
#
#  File: ARCH-DIV-000494_0038.xml | Line 13
#    Ground Truth: <.........>
#    HTR         : Lovoynôtoltiq.
#    Dif. HTR    : [('replace', '<', 'Lovoynôtoltiq'), ('delete', '........>', '')]
#    Corrected   : Lovoynôtoltiq.
#    Dif. Corr   : [('replace', '<', 'Lovoynôtoltiq'), ('delete', '........>', '')]
#    CER corr vs GT: 1.2727, WER: 1.0000
#
#  File: ARCH-DIV-000494_0038.xml | Line 14
#    Ground Truth: Mais les évêques se trouvaient dans une situa¬
#    HTR         : Mais les criques se trouvaient dans une sitra¬
#    Dif. HTR    : [('replace', 'évê', 'cri'), ('replace', 'u', 'r')]
#    Corrected   : Mais les évêques se trouvaient dans une situa¬
#    Dif. Corr   : []
#    CER corr vs GT: 0.0000, WER: 0.0000
#
#  File: ARCH-DIV-000494_0038.xml | Line 15
#    Ground Truth: tion toute différente. <.........> Établis à demeure
#    HTR         : tins toute diffirente. Babibagate Etablis a Slincure
#    Dif. HTR    : [('delete', 'o', ''), ('insert', '', 's'), ('replace', 'é', 'i'), ('replace', '<.........>', 'Babibagate'), ('replace', 'É', 'E'), ('replace', 'à', 'a'), ('replace', 'deme', 'Slinc')]
#    Corrected   : tion toute différente. Babibagate Etablis a Slincure
#    Dif. Corr   : [('replace', '<.........>', 'Babibagate'), ('replace', 'É', 'E'), ('replace', 'à', 'a'), ('replace', 'deme', 'Slinc')]
#    CER corr vs GT: 0.3462, WER: 0.5714
#
#  File: ARCH-DIV-000494_0038.xml | Line 16
#    Ground Truth: étaient forcés par là
#    HTR         : étaienf forcispar la
#    Dif. HTR    : [('replace', 't', 'f'), ('replace', 'é', 'i'), ('delete', ' ', ''), ('replace', 'à', 'a')]
#    Corrected   : étaienf forcispar la
#    Dif. Corr   : [('replace', 't', 'f'), ('replace', 'é', 'i'), ('delete', ' ', ''), ('replace', 'à', 'a')]
#    CER corr vs GT: 0.1905, WER: 1.0000
#
#  File: ARCH-DIV-000494_0038.xml | Line 17
#    Ground Truth: dans leurs cités <......>, ils <...... .......>
#    HTR         : dam leurs ciths <..... ils .ratt.......> e
#    Dif. HTR    : [('replace', 'ns', 'm'), ('replace', 'é', 'h'), ('delete', '.>,', ''), ('delete', '<', ''), ('replace', '..... ', 'ratt'), ('insert', '', ' e')]
#    Corrected   : dam leurs ciths <..... ils. ratt....... > e
#    Dif. Corr   : [('replace', 'ns', 'm'), ('replace', 'é', 'h'), ('delete', '.>,', ''), ('insert', '', '.'), ('replace', '<', 'ratt.'), ('delete', '.......', ''), ('insert', '', ' e')]
#    CER corr vs GT: 0.3404, WER: 1.0000
#
#  File: ARCH-DIV-000494_0038.xml | Line 18
#    Ground Truth: <....> d'entretenir avec les habitants de celles-ci des rela¬
#    HTR         : opnentieteur avec ls tabitant de celles, en ells rula
#    Dif. HTR    : [('replace', "<....> d'", 'opn'), ('replace', 'r', 'i'), ('replace', 'ni', 'u'), ('delete', 'e', ''), ('replace', 'h', 't'), ('delete', 's', ''), ('replace', '-ci', ','), ('delete', 'd', ''), ('insert', '', 'n ell'), ('replace', 'e', 'u'), ('delete', '¬', '')]
#    Corrected   : opnentieteur avec les habitants de celles, ci des rula
#    Dif. Corr   : [('replace', "<....> d'", 'opn'), ('replace', 'r', 'i'), ('replace', 'ni', 'u'), ('replace', '-', ', '), ('replace', 'e', 'u'), ('delete', '¬', '')]
#    CER corr vs GT: 0.2623, WER: 0.5556
#
#  File: ARCH-DIV-000494_0038.xml | Line 19
#    Ground Truth: tions journalières et de <.....>s'intéresser à leurs faits et
#    HTR         : tion janalies et te tadaientérener De leurs faits et
#    Dif. HTR    : [('delete', 's', ''), ('replace', 'our', 'a'), ('delete', 'èr', ''), ('replace', 'd', 't'), ('replace', "<.....>s'", 'tada'), ('insert', '', 'e'), ('replace', 'ss', 'n'), ('replace', 'à', 'De')]
#    Corrected   : tion janalies et de tadaientérener De leurs faits et
#    Dif. Corr   : [('delete', 's', ''), ('replace', 'our', 'a'), ('delete', 'èr', ''), ('replace', "<.....>s'", 'tada'), ('insert', '', 'e'), ('replace', 'ss', 'n'), ('replace', 'à', 'De')]
#    CER corr vs GT: 0.3279, WER: 0.4444
#
#  File: ARCH-DIV-000494_0038.xml | Line 20
#    Ground Truth: professaient
#    HTR         : professailent
#    Dif. HTR    : [('insert', '', 'l')]
#    Corrected   : professailent
#    Dif. Corr   : [('insert', '', 'l')]
#    CER corr vs GT: 0.0833, WER: 1.0000
#
#  File: ARCH-DIV-000494_0038.xml | Line 21
#    Ground Truth: gestes. Plus cultivés que les laïques, ils <.......> en
#    HTR         : gestes. Plus culttwéxs que les laïques, ils <....t on
#    Dif. HTR    : [('replace', 'iv', 'tw'), ('insert', '', 'x'), ('replace', '...>', 't'), ('replace', 'e', 'o')]
#    Corrected   : gestes. Plus cultivés que les laïques, ils <.... t on
#    Dif. Corr   : [('delete', '...>', ''), ('replace', 'e', 't o')]
#    CER corr vs GT: 0.0909, WER: 0.3333
#
#  File: ARCH-DIV-000494_0038.xml | Line 22
#    Ground Truth: une théorie
#    HTR         : ure théoril
#    Dif. HTR    : [('replace', 'n', 'r'), ('replace', 'e', 'l')]
#    Corrected   : de théoril
#    Dif. Corr   : [('replace', 'un', 'd'), ('replace', 'e', 'l')]
#    CER corr vs GT: 0.2727, WER: 1.0000
#
#  File: ARCH-DIV-000494_0038.xml | Line 23
#    Ground Truth: outre <........> de gouvernement reposant sur
#    HTR         : oetre titértairidiat Oegouvernement reposant tur
#    Dif. HTR    : [('replace', 'u', 'e'), ('replace', '<........>', 'titértairidiat'), ('replace', 'd', 'O'), ('delete', ' ', ''), ('replace', 's', 't')]
#    Corrected   : oetre titértairidiat gouvernement reposant sur
#    Dif. Corr   : [('replace', 'u', 'e'), ('replace', '<........> ', 'titértairi'), ('replace', 'e', 'iat')]
#    CER corr vs GT: 0.3333, WER: 0.5000
#
#  File: ARCH-DIV-000494_0038.xml | Line 24
#    Ground Truth: spirituelle
#    HTR         : apriritueble
#    Dif. HTR    : [('replace', 's', 'a'), ('insert', '', 'r'), ('replace', 'l', 'b')]
#    Corrected   : apriritueble
#    Dif. Corr   : [('replace', 's', 'a'), ('insert', '', 'r'), ('replace', 'l', 'b')]
#    CER corr vs GT: 0.2727, WER: 1.0000
#
#  File: ARCH-DIV-000494_0038.xml | Line 25
#    Ground Truth: le double principe de l'obéissance à l'autorité <....>
#    HTR         : le Aortble paincipe de l'obcisrance à l'autorite ...
#    Dif. HTR    : [('replace', 'd', 'A'), ('replace', 'u', 'rt'), ('replace', 'r', 'a'), ('replace', 'é', 'c'), ('replace', 's', 'r'), ('replace', 'à', 'à'), ('replace', 'é', 'e'), ('delete', '<', ''), ('delete', '.>', '')]
#    Corrected   : le double principe de l'obéissance à ̀ l'autorité...
#    Dif. Corr   : [('insert', '', '̀ '), ('delete', ' <', ''), ('delete', '.>', '')]
#    CER corr vs GT: 0.1111, WER: 0.2500
#
#  File: ARCH-DIV-000494_0038.xml | Line 26
#    Ground Truth: et à l'autorité temporelle, toutes deux émanées de
#    HTR         : et à l'autorité temporelle, toutes deux emanées de
#    Dif. HTR    : [('replace', 'à', 'à'), ('replace', 'é', 'e')]
#    Corrected   : et à ̀ l'autorité temporelle, toutes deux émanées de
#    Dif. Corr   : [('insert', '', ' ̀')]
#    CER corr vs GT: 0.0400, WER: 0.1250
#
#  File: ARCH-DIV-000494_0038.xml | Line 27
#    Ground Truth: Dieu même. A Liège, à Utrecht, à Cambrai, les prélats
#    HTR         : Dien même. A Liège, à Utrcht à Camtran, les prélats
#    Dif. HTR    : [('replace', 'u', 'n'), ('replace', 'à', 'à'), ('delete', 'e', ''), ('delete', ',', ''), ('replace', 'à', 'à'), ('replace', 'b', 't'), ('replace', 'i', 'n')]
#    Corrected   : Dieu même. A Liège, à ̀ Utrcht à ̀ Cambrai, les prélats
#    Dif. Corr   : [('insert', '', '̀ '), ('delete', 'e', ''), ('delete', ',', ''), ('insert', '', ' ̀')]
#    CER corr vs GT: 0.1132, WER: 0.3000
#
#  File: ARCH-DIV-000494_0038.xml | Line 28
#    Ground Truth: excellents que les empereurs chargeaient de l'adminis¬
#    HTR         : excellent que les empereurs charglaient de l'achminis¬
#    Dif. HTR    : [('delete', 's', ''), ('replace', 'e', 'l'), ('replace', 'd', 'ch')]
#    Corrected   : excellents que les empereurs chargeaient de l'administ¬
#    Dif. Corr   : [('insert', '', 't')]
#    CER corr vs GT: 0.0185, WER: 0.1429
#
#  File: ARCH-DIV-000494_0038.xml | Line 29
#    Ground Truth: tration des diocèses, s'efforcèrent durant tout le X^e et
#    HTR         : tration 3s divcèses, l'efforcirent devant tont le I et
#    Dif. HTR    : [('replace', 'de', '3'), ('replace', 'o', 'v'), ('replace', 's', 'l'), ('replace', 'è', 'i'), ('replace', 'ur', 'ev'), ('replace', 'u', 'n'), ('replace', 'X^e', 'I')]
#    Corrected   : ration des diocèses,’'efforcèrent durant tout le X et
#    Dif. Corr   : [('delete', 't', ''), ('replace', ' s', '’'), ('delete', '^e', '')]
#    CER corr vs GT: 0.0877, WER: 0.4444
#
#  File: ARCH-DIV-000494_0038.xml | Line 30
#    Ground Truth: de
#    HTR         : de
#    Dif. HTR    : []
#    Corrected   : de
#    Dif. Corr   : []
#    CER corr vs GT: 0.0000, WER: 0.0000
#
#  File: ARCH-DIV-000494_0038.xml | Line 31
#    Ground Truth: le XI^e siècles <..> maintenir la fidélité au souverain et
#    HTR         : le XI serle I Nmaintenir la fivelité ou souverain et
#    Dif. HTR    : [('replace', '^', ' serl'), ('replace', 'siècles', 'I'), ('replace', '<..> ', 'N'), ('replace', 'dé', 've'), ('replace', 'a', 'o')]
#    Corrected   : le XI serle e maintenir la fidélité au souverain et
#    Dif. Corr   : [('replace', '^', ' serl'), ('delete', 'siècl', ''), ('delete', 's <..>', '')]
#    CER corr vs GT: 0.1724, WER: 0.3000
#
#  File: ARCH-DIV-000494_0038.xml | Line 32
#    Ground Truth: la "discipline teutonique" (1). Il semble bien qu'ils aient
#    HTR         : la "discipline tentonique" (). Il sembt bien qu'ilsaient
#    Dif. HTR    : [('replace', 'u', 'n'), ('delete', '1', ''), ('replace', 'le', 't'), ('delete', ' ', '')]
#    Corrected   : la "discipline teutonique" (). Il semble bien qu'ilsaient
#    Dif. Corr   : [('delete', '1', ''), ('delete', ' ', '')]
#    CER corr vs GT: 0.0339, WER: 0.3333
#
#  File: ARCH-DIV-000494_0038.xml | Line 33
#    Ground Truth: remarquablement organisé les institutions domaniales
#    HTR         : Remarquablement organise les institations domanichs
#    Dif. HTR    : [('replace', 'r', 'R'), ('replace', 'é', 'e'), ('replace', 'u', 'a'), ('replace', 'ale', 'ch')]
#    Corrected   : remarquablement organisé les institutions domaniales
#    Dif. Corr   : []
#    CER corr vs GT: 0.0000, WER: 0.0000
#
#  File: ARCH-DIV-000494_0038.xml | Line 34
#    Ground Truth: de leurs terres et que la condition des paysans, sous leur
#    HTR         : d leurs terres et que la condition des paysans, tous leur
#    Dif. HTR    : [('delete', 'e', ''), ('replace', 's', 't')]
#    Corrected   : de leurs terres et que la condition des paysans, sous leur
#    Dif. Corr   : []
#    CER corr vs GT: 0.0000, WER: 0.0000
#
#  File: ARCH-DIV-000494_0038.xml | Line 35
#    Ground Truth: autorité vigilante et ferme, se soit trouvée <...> singu¬
#    HTR         : antoriti Vigilante efferme, le boit houvée <... diuqu¬
#    Dif. HTR    : [('replace', 'u', 'n'), ('replace', 'é', 'i'), ('replace', 'v', 'V'), ('replace', 't ', 'f'), ('replace', 's', 'l'), ('replace', 's', 'b'), ('replace', 'tr', 'h'), ('delete', '>', ''), ('replace', 's', 'd'), ('replace', 'ng', 'uq')]
#    Corrected   : autorité vigilante ferme, se soit trouvée <... diuqu¬
#    Dif. Corr   : [('delete', ' et', ''), ('delete', '>', ''), ('replace', 's', 'd'), ('replace', 'ng', 'uq')]
#    CER corr vs GT: 0.1228, WER: 0.3333
#
#  File: ARCH-DIV-000494_0038.xml | Line 36
#    Ground Truth: lièrement favorable. La petite noblesse du pays obéis¬
#    HTR         : liérement farorable. La petite Nohlose du pop obin
#    Dif. HTR    : [('replace', 'è', 'é'), ('replace', 'v', 'r'), ('replace', 'n', 'N'), ('replace', 'b', 'h'), ('replace', 'es', 'o'), ('replace', 'ays', 'op'), ('delete', 'é', ''), ('replace', 's¬', 'n')]
#    Corrected   : liérement farorable. La petite noblesse du pays obin
#    Dif. Corr   : [('replace', 'è', 'é'), ('replace', 'v', 'r'), ('delete', 'é', ''), ('replace', 's¬', 'n')]
#    CER corr vs GT: 0.0926, WER: 0.3750
#
#  File: ARCH-DIV-000494_0038.xml | Line 37
#    Ground Truth: sait moins facilement, et c'est elle sans doute
#    HTR         : tait moins facilement, et c'est elle sans doute
#    Dif. HTR    : [('replace', 's', 't')]
#    Corrected   : tait moins facilement, et c'est elle sans doute
#    Dif. Corr   : [('replace', 's', 't')]
#    CER corr vs GT: 0.0213, WER: 0.1250
#
#  File: ARCH-DIV-000494_0038.xml | Line 38
#    Ground Truth: qui provoqua à Liège, sous l'évêque Éracle (958),
#    HTR         : qui provaqua à Liège, sous l'évêque Evarl (959-971)
#    Dif. HTR    : [('replace', 'o', 'a'), ('replace', 'à', 'à'), ('replace', 'É', 'Eva'), ('delete', 'ac', ''), ('delete', 'e', ''), ('replace', '8', '9-971'), ('delete', ',', '')]
#    Corrected   : qui provoqua à ̀ Liège, sous l'évêque Éracle (959-971)
#    Dif. Corr   : [('insert', '', ' ̀'), ('replace', '8', '9-971'), ('delete', ',', '')]
#    CER corr vs GT: 0.1633, WER: 0.2500
#
#  File: ARCH-DIV-000494_0038.xml | Line 39
#    Ground Truth: à Cambrai sous l'évêque Engran (958) des insurrec¬
#    HTR         : "Cauloas sous l'évéque Eugran (958), des insurret¬
#    Dif. HTR    : [('replace', 'à ', '"'), ('replace', 'mbr', 'ulo'), ('replace', 'i', 's'), ('replace', 'ê', 'é'), ('replace', 'n', 'u'), ('insert', '', ','), ('replace', 'c', 't')]
#    Corrected   : " Cambrai sous l'évêque Engran (956), des insurrec¬
#    Dif. Corr   : [('replace', 'à', '"'), ('replace', '8', '6'), ('insert', '', ',')]
#    CER corr vs GT: 0.0600, WER: 0.2500
#
#  File: ARCH-DIV-000494_0038.xml | Line 40
#    Ground Truth: tions sur lesquelles nous sommes d'ailleurs très mal
#    HTR         : tins sur les quelle mus domned'aillees très mal
#    Dif. HTR    : [('delete', 'o', ''), ('insert', '', ' '), ('delete', 's', ''), ('replace', 'no', 'm'), ('replace', 's', 'd'), ('replace', 'm', 'n'), ('delete', 's ', ''), ('replace', 'ur', 'e')]
#    Corrected   : tions sur les quelle mus domned'ailleurs très mal
#    Dif. Corr   : [('insert', '', ' '), ('delete', 's', ''), ('replace', 'no', 'm'), ('replace', 's', 'd'), ('replace', 'm', 'n'), ('delete', 's ', '')]
#    CER corr vs GT: 0.1538, WER: 0.5000
#
#  File: ARCH-DIV-000494_0038.xml | Line 41
#    Ground Truth: renseignés(2). Il est certain, d'autre part, que les cités
#    HTR         : rhméignés (2). Il est certain, d'oute part, que les cités
#    Dif. HTR    : [('replace', 'ense', 'hmé'), ('insert', '', ' '), ('replace', 'a', 'o'), ('delete', 'r', '')]
#    Corrected   : renseignés (2). Il est certain, d'autre part, que les cités
#    Dif. Corr   : [('insert', '', ' ')]
#    CER corr vs GT: 0.0172, WER: 0.2222
#
#  File: ARCH-DIV-000494_0038.xml | Line 42
#    Ground Truth: (1) Voy. H. Pirenne. Histoire de Belgique, t. I, 3^e édit.,
#    HTR         : (IVoy. W. Sisenme, Hutoire de Belyrque, L.I, Ps éoit
#    Dif. HTR    : [('replace', '1) ', 'I'), ('replace', 'H', 'W'), ('replace', 'P', 'S'), ('replace', 'r', 's'), ('replace', 'n', 'm'), ('replace', '.', ','), ('replace', 'is', 'u'), ('replace', 'gi', 'yr'), ('replace', 't', 'L'), ('delete', ' ', ''), ('replace', '3^e', 'Ps'), ('replace', 'd', 'o'), ('delete', '.,', '')]
#    Corrected   : (Voy. H. Sisenme, Histoire de Belgique, t. I, 3e cuit
#    Dif. Corr   : [('delete', '1) ', ''), ('replace', 'P', 'S'), ('replace', 'r', 's'), ('replace', 'n', 'm'), ('replace', '.', ','), ('delete', '^', ''), ('replace', 'éd', 'cu'), ('delete', '.,', '')]
#    CER corr vs GT: 0.2034, WER: 0.4545
#
#  File: ARCH-DIV-000494_0038.xml | Line 43
#    Ground Truth: p. 65 et suiv.
#    HTR         : p. 65 et suiv.
#    Dif. HTR    : []
#    Corrected   : p. 65 et suiv.
#    Dif. Corr   : []
#    CER corr vs GT: 0.0000, WER: 0.0000
#
#  File: ARCH-DIV-000494_0038.xml | Line 44
#    Ground Truth: ces mouvement,
#    HTR         : cex mouvenent,
#    Dif. HTR    : [('replace', 's', 'x'), ('replace', 'm', 'n')]
#    Corrected   : cex mouvenent,
#    Dif. Corr   : [('replace', 's', 'x'), ('replace', 'm', 'n')]
#    CER corr vs GT: 0.1429, WER: 1.0000
#
#  File: ARCH-DIV-000494_0038.xml | Line 45
#    Ground Truth: (2) On a voulu considérer, sans la moindre preuve <...>
#    HTR         : 12) On a vorbe consiiérer, tans la moindre pilleve css
#    Dif. HTR    : [('replace', '(', '1'), ('replace', 'ulu', 'rbe'), ('replace', 'd', 'i'), ('replace', 's', 't'), ('replace', 'r', 'ill'), ('delete', 'u', ''), ('replace', '<...>', 'css')]
#    Corrected   : 12) On a vorbe considérer, sans la moindre pilleve css
#    Dif. Corr   : [('replace', '(', '1'), ('replace', 'ulu', 'rbe'), ('replace', 'r', 'ill'), ('delete', 'u', ''), ('replace', '<...>', 'css')]
#    CER corr vs GT: 0.2364, WER: 0.4000
#
#  File: ARCH-DIV-000494_0038.xml | Line 46
#    Ground Truth: comme des essais de commune.
#    HTR         : comme des essais de commune.
#    Dif. HTR    : []
#    Corrected   : comme des essais de commune.
#    Dif. Corr   : []
#    CER corr vs GT: 0.0000, WER: 0.0000
#
#  File: ARCH-DIV-000494_0039.xml | Line 1
#    Ground Truth: 31
#    HTR         : 31
#    Dif. HTR    : []
#    Corrected   : 31
#    Dif. Corr   : []
#    CER corr vs GT: 0.0000, WER: 0.0000
#
#  File: ARCH-DIV-000494_0039.xml | Line 2
#    Ground Truth: épiscopales, plus peuplées et plus animées que les châ¬
#    HTR         : épiacepales, plus peuplées et plus arimces que les châ¬
#    Dif. HTR    : [('replace', 's', 'a'), ('replace', 'o', 'e'), ('replace', 'n', 'r'), ('replace', 'é', 'c')]
#    Corrected   : épiscopales, plus peuplées et plus animées que les châ¬
#    Dif. Corr   : []
#    CER corr vs GT: 0.0000, WER: 0.0000
#
#  File: ARCH-DIV-000494_0039.xml | Line 3
#    Ground Truth: teaux des princes laïques, jouirent aussi <..> d'un ordre
#    HTR         : teaux des princes laïques, juissent aussi.4 d'une ordeor
#    Dif. HTR    : [('delete', 'o', ''), ('replace', 'r', 'ss'), ('delete', ' <', ''), ('replace', '.>', '4'), ('insert', '', 'e'), ('insert', '', 'eo'), ('delete', 'e', '')]
#    Corrected   : teaux des princes laïques, jouirent aussi. 4 d'un ordre
#    Dif. Corr   : [('insert', '', '.'), ('replace', '<..>', '4')]
#    CER corr vs GT: 0.0702, WER: 0.2222
#
#  File: ARCH-DIV-000494_0039.xml | Line 4
#    Ground Truth: et d'une police beaucoup plus fermes. Les évêques prirent
#    HTR         : et d'une palice beauroup plus ferme. Les lvêques priseut
#    Dif. HTR    : [('replace', 'o', 'a'), ('replace', 'c', 'r'), ('delete', 's', ''), ('replace', 'é', 'l'), ('replace', 'r', 's'), ('replace', 'n', 'u')]
#    Corrected   : et d'une police beauroup plus fermes. Les évêques prirent
#    Dif. Corr   : [('replace', 'c', 'r')]
#    CER corr vs GT: 0.0175, WER: 0.1111
#
#  File: ARCH-DIV-000494_0039.xml | Line 5
#    Ground Truth: des mesures de toutes sortes pour en assurer le ravitaille¬
#    HTR         : des mesures de touts dortes pous er asaons le revitaille¬
#    Dif. HTR    : [('delete', 'e', ''), ('replace', 's', 'd'), ('replace', 'r', 's'), ('replace', 'n', 'r'), ('insert', '', 'aon'), ('delete', 'urer', ''), ('replace', 'a', 'e')]
#    Corrected   : des mesures de toutes sortes pour en asaons le ravitaille¬
#    Dif. Corr   : [('insert', '', 'aon'), ('delete', 'urer', '')]
#    CER corr vs GT: 0.0847, WER: 0.1000
#
#  File: ARCH-DIV-000494_0039.xml | Line 6
#    Ground Truth: ment, y surveiller le marché, y construire des murs
#    HTR         : ment, y turveiller le marché, y construère des murs
#    Dif. HTR    : [('replace', 's', 't'), ('replace', 'i', 'è')]
#    Corrected   : ment, y surveiller le marché, y construire des murs
#    Dif. Corr   : []
#    CER corr vs GT: 0.0000, WER: 0.0000
#
#  File: ARCH-DIV-000494_0039.xml | Line 7
#    Ground Truth: et des ponts. Notger de Liége (972-1018), détourna un
#    HTR         : et des pouts. Notger de Liège (972-1018) détaurma iir
#    Dif. HTR    : [('replace', 'n', 'u'), ('replace', 'é', 'è'), ('delete', ',', ''), ('replace', 'o', 'a'), ('replace', 'n', 'm'), ('replace', 'un', 'iir')]
#    Corrected   : et des ponts. Notger de Liége (972-1018) détaurma iir
#    Dif. Corr   : [('delete', ',', ''), ('replace', 'o', 'a'), ('replace', 'n', 'm'), ('replace', 'un', 'iir')]
#    CER corr vs GT: 0.1132, WER: 0.3333
#
#  File: ARCH-DIV-000494_0039.xml | Line 8
#    Ground Truth: la ville
#    HTR         : le ville
#    Dif. HTR    : [('replace', 'a', 'e')]
#    Corrected   : un ville
#    Dif. Corr   : [('replace', 'la', 'un')]
#    CER corr vs GT: 0.2500, WER: 0.5000
#
#  File: ARCH-DIV-000494_0039.xml | Line 9
#    Ground Truth: la
#    HTR         : le
#    Dif. HTR    : [('replace', 'a', 'e')]
#    Corrected   : le
#    Dif. Corr   : [('replace', 'a', 'e')]
#    CER corr vs GT: 0.5000, WER: 1.0000
#
#  File: ARCH-DIV-000494_0039.xml | Line 10
#    Ground Truth: bras de la Meuse pour assainir et pour fortifier tout
#    HTR         : Gras de la Meusc pour assaiir et pour fortifier tout
#    Dif. HTR    : [('replace', 'b', 'G'), ('replace', 'e', 'c'), ('delete', 'n', '')]
#    Corrected   : bras de la Meuse pour assainir et pour fortifier tout
#    Dif. Corr   : []
#    CER corr vs GT: 0.0000, WER: 0.0000
#
#  File: ARCH-DIV-000494_0039.xml | Line 11
#    Ground Truth: ensemble.
#    HTR         : eusemble.
#    Dif. HTR    : [('replace', 'n', 'u')]
#    Corrected   : ensemble.
#    Dif. Corr   : []
#    CER corr vs GT: 0.0000, WER: 0.0000
#
#  File: ARCH-DIV-000494_0039.xml | Line 12
#    Ground Truth: Mais c'est justement cette activité et cette sollicitude
#    HTR         : Mais c'est justement cette activité et cette sotitude
#    Dif. HTR    : [('replace', 'llic', 't')]
#    Corrected   : Mais c'est justement cette activité et cette sotitude
#    Dif. Corr   : [('replace', 'llic', 't')]
#    CER corr vs GT: 0.0714, WER: 0.1250
#
#  File: ARCH-DIV-000494_0039.xml | Line 13
#    Ground Truth: des évêques
#    HTR         : ses évêque.
#    Dif. HTR    : [('replace', 'd', 's'), ('replace', 's', '.')]
#    Corrected   : des évêques.
#    Dif. Corr   : [('insert', '', '.')]
#    CER corr vs GT: 0.0909, WER: 0.5000
#
#  File: ARCH-DIV-000494_0039.xml | Line 14
#    Ground Truth: devaient la
#    HTR         : dévaient les
#    Dif. HTR    : [('replace', 'e', 'é'), ('replace', 'a', 'es')]
#    Corrected   : dévaient les
#    Dif. Corr   : [('replace', 'e', 'é'), ('replace', 'a', 'es')]
#    CER corr vs GT: 0.2727, WER: 1.0000
#
#  File: ARCH-DIV-000494_0039.xml | Line 15
#    Ground Truth: pour le bien de leurs  sujets qui <.......> mettre <........>
#    HTR         : poir le bien de leus aujets qui 40vailmettre larirgion
#    Dif. HTR    : [('replace', 'u', 'i'), ('delete', 'r', ''), ('replace', ' s', 'a'), ('replace', '<.......> ', '40vail'), ('replace', '<........>', 'larirgion')]
#    Corrected   : pour le bien de leurs sujets qui 40vailmettre larirgion
#    Dif. Corr   : [('delete', ' ', ''), ('replace', '<.......> ', '40vail'), ('replace', '<........>', 'larirgion')]
#    CER corr vs GT: 0.3443, WER: 0.3000
#
#  File: ARCH-DIV-000494_0039.xml | Line 16
#    Ground Truth: aux prises avec ceux-ci. <.......> L'immigration des
#    HTR         : aux prises avec ceux-ci. L.... L'immigrations des
#    Dif. HTR    : [('replace', '<', 'L'), ('delete', '...>', ''), ('insert', '', 's')]
#    Corrected   : aux prises avec ceux-ci. L.... L'immigration des
#    Dif. Corr   : [('replace', '<', 'L'), ('delete', '...>', '')]
#    CER corr vs GT: 0.0962, WER: 0.1429
#
#  File: ARCH-DIV-000494_0039.xml | Line 17
#    Ground Truth: marchands dans les cités, au cours du X^e siècle, <.......>
#    HTR         : mardands dans lescités, au cours du Xe siécle, parbat
#    Dif. HTR    : [('replace', 'ch', 'd'), ('delete', ' ', ''), ('delete', '^', ''), ('replace', 'è', 'é'), ('replace', '<.......>', 'parbat')]
#    Corrected   : marchands dans lescités, au cours du X siécle, parbat
#    Dif. Corr   : [('delete', ' ', ''), ('delete', '^e', ''), ('replace', 'è', 'é'), ('replace', '<.......>', 'parbat')]
#    CER corr vs GT: 0.2203, WER: 0.5000
#
#  File: ARCH-DIV-000494_0039.xml | Line 18
#    Ground Truth: <....... .......> y compliqua la situation, y fit naître
#    HTR         : <<......it y compliqua la fituation, y fit naître
#    Dif. HTR    : [('insert', '', '<'), ('replace', '. .......>', 'it'), ('replace', 's', 'f')]
#    Corrected   : < <...... it y compliqua la situation, y fit naître
#    Dif. Corr   : [('insert', '', '< '), ('delete', '.', ''), ('replace', '.......>', 'it')]
#    CER corr vs GT: 0.1786, WER: 0.3333
#
#  File: ARCH-DIV-000494_0039.xml | Line 19
#    Ground Truth: des besoins nouveaux et y suscita des revendications jusqu'alors
#    HTR         : des beaous nouveaux et y inscita des revendications jusqu'olas
#    Dif. HTR    : [('replace', 's', 'a'), ('replace', 'in', 'u'), ('replace', 'su', 'in'), ('insert', '', 'ol'), ('delete', 'lor', '')]
#    Corrected   : des besoins nouveaux et y suscita des revendications jusqu'alors
#    Dif. Corr   : []
#    CER corr vs GT: 0.0000, WER: 0.0000
#
#  File: ARCH-DIV-000494_0039.xml | Line 20
#    Ground Truth: inconnues. Or, les prélats ne pouvaient sans danger <......>¬
#    HTR         : inconnes. Or les prélats n pouvaient sans danger, imbordou¬
#    Dif. HTR    : [('delete', 'u', ''), ('delete', ',', ''), ('delete', 'e', ''), ('insert', '', ','), ('replace', '<......>', 'imbordou')]
#    Corrected   : inconnues. Or les prélats n pouvaient sans danger, imbordou¬
#    Dif. Corr   : [('delete', ',', ''), ('delete', 'e', ''), ('insert', '', ','), ('replace', '<......>', 'imbordou')]
#    CER corr vs GT: 0.1803, WER: 0.4444
#
#  File: ARCH-DIV-000494_0039.xml | Line 21
#    Ground Truth: <...... ..... .. .... .....> au siège même de leur
#    HTR         : <.... ...... . b.. ........> au tiège meine de leur
#    Dif. HTR    : [('delete', '..', ''), ('insert', '', '.'), ('insert', '', '. b'), ('delete', '. ', ''), ('replace', 's', 't'), ('replace', 'êm', 'ein')]
#    Corrected   : <........... b.......... > au siège même de leur
#    Dif. Corr   : [('delete', ' ', ''), ('insert', '', 'b'), ('replace', ' ', '....'), ('delete', '.....', '')]
#    CER corr vs GT: 0.1000, WER: 0.5000
#
#  File: ARCH-DIV-000494_0039.xml | Line 22
#    Ground Truth: abandonner
#    HTR         : abandonner
#    Dif. HTR    : []
#    Corrected   : abandonner
#    Dif. Corr   : []
#    CER corr vs GT: 0.0000, WER: 0.0000
#
#  File: ARCH-DIV-000494_0039.xml | Line 23
#    Ground Truth: donc
#    HTR         : dont
#    Dif. HTR    : [('replace', 'c', 't')]
#    Corrected   : dont
#    Dif. Corr   : [('replace', 'c', 't')]
#    CER corr vs GT: 0.2500, WER: 1.0000
#
#  File: ARCH-DIV-000494_0039.xml | Line 24
#    Ground Truth: résidence ^(1), <.....> aux marchands cette autonomie <....>
#    HTR         : Réaidenie, Bair eux marctands cett urstonorre que
#    Dif. HTR    : [('replace', 'r', 'R'), ('replace', 's', 'a'), ('replace', 'c', 'i'), ('delete', ' ^(1)', ''), ('replace', '<.....>', 'Bair'), ('replace', 'a', 'e'), ('replace', 'h', 't'), ('delete', 'e', ''), ('delete', 'a', ''), ('insert', '', 'rs'), ('replace', 'mi', 'rr'), ('replace', '<....>', 'que')]
#    Corrected   : Réaidenie, Bair aux marchands cette urstonorre dont
#    Dif. Corr   : [('replace', 'r', 'R'), ('replace', 's', 'a'), ('replace', 'c', 'i'), ('delete', ' ^(1)', ''), ('replace', '<.....>', 'Bair'), ('delete', 'a', ''), ('insert', '', 'rs'), ('replace', 'mi', 'rr'), ('replace', '<....>', 'dont')]
#    CER corr vs GT: 0.4333, WER: 0.6250
#
# ...
#    CER corr vs GT: 1.3158, WER: 5.0000
#
#  File: ARCH-DIV-000494_0043.xml | Line 13
#    Ground Truth: <..........................>
#    HTR         : <... Ilent M...ta. tent qu'elle s.'.téal
#    Dif. HTR    : [('insert', '', ' Ilent M'), ('insert', '', 'ta'), ('insert', '', " tent qu'elle s"), ('insert', '', "'"), ('replace', '.................>', 'téal')]
#    Corrected   : <... Ilent M... ta. tent qu'elle s.'. téal
#    Dif. Corr   : [('insert', '', ' Ilent M'), ('insert', '', ' ta'), ('insert', '', " tent qu'elle s"), ('insert', '', "'"), ('replace', '.................>', ' téal')]
#    CER corr vs GT: 1.1429, WER: 8.0000
#
#  File: ARCH-DIV-000494_0043.xml | Line 14
#    Ground Truth: <....................................>
#    HTR         : <............... .......> fait..>
#    Dif. HTR    : [('replace', '..............', ' '), ('insert', '', ' fait..>')]
#    Corrected   : <......................> fait.. >
#    Dif. Corr   : [('insert', '', '> fait'), ('replace', '............', ' ')]
#    CER corr vs GT: 0.3158, WER: 3.0000
#
#  File: ARCH-DIV-000494_0043.xml | Line 15
#    Ground Truth: <....................................>
#    HTR         : d..a..... II (IVorr 171) la droits de Valrana
#    Dif. HTR    : [('replace', '<', 'd..a'), ('replace', '...............................>', ' II (IVorr 171) la droits de Valrana')]
#    Corrected   : d.. a..... II (IVorr 171) la droits de Valrana
#    Dif. Corr   : [('replace', '<', 'd.. a'), ('replace', '...............................>', ' II (IVorr 171) la droits de Valrana')]
#    CER corr vs GT: 1.0263, WER: 9.0000
#
#  File: ARCH-DIV-000494_0043.xml | Line 16
#    Ground Truth: II
#    HTR         : I1
#    Dif. HTR    : [('replace', 'I', '1')]
#    Corrected   : I1
#    Dif. Corr   : [('replace', 'I', '1')]
#    CER corr vs GT: 0.5000, WER: 1.0000
#
#  File: ARCH-DIV-000494_0043.xml | Line 17
#    Ground Truth: Qu'elles aient vécu en bonne intelligence avec leurs
#    HTR         : Qu elles aient veue een bone intilligeuce avec leurs
#    Dif. HTR    : [('replace', "'", ' '), ('replace', 'éc', 'e'), ('insert', '', 'e'), ('insert', '', 'e'), ('delete', 'n', ''), ('replace', 'e', 'i'), ('replace', 'n', 'u')]
#    Corrected   : Qu elles aient vécu en bonne intelligence avec leurs
#    Dif. Corr   : [('replace', "'", ' ')]
#    CER corr vs GT: 0.0192, WER: 0.2500
#
#  File: ARCH-DIV-000494_0043.xml | Line 18
#    Ground Truth: les combattre
#    HTR         : lys cqibattrt
#    Dif. HTR    : [('replace', 'e', 'y'), ('replace', 'om', 'qi'), ('replace', 'e', 't')]
#    Corrected   : lys cqibattrt
#    Dif. Corr   : [('replace', 'e', 'y'), ('replace', 'om', 'qi'), ('replace', 'e', 't')]
#    CER corr vs GT: 0.3077, WER: 1.0000
#
#  File: ARCH-DIV-000494_0043.xml | Line 19
#    Ground Truth: princes ou qu'elles aient dû <................>
#    HTR         : pinces on qu'elles aient dû l..... c...... poera¬
#    Dif. HTR    : [('delete', 'r', ''), ('replace', 'u', 'n'), ('replace', '<', 'l..... c'), ('replace', '..........>', ' poera¬')]
#    Corrected   : princes ou qu'elles aient dû les..... c...... poera¬
#    Dif. Corr   : [('replace', '<', 'les..... c'), ('replace', '..........>', ' poera¬')]
#    CER corr vs GT: 0.2553, WER: 0.5000
#
#  File: ARCH-DIV-000494_0043.xml | Line 20
#    Ground Truth: <...........> les villes, un peu plus tôt ou un peu plus
#    HTR         : Nabarcitiation, les villes, un peu plus tot au n peu plus
#    Dif. HTR    : [('replace', '<...........>', 'Nabarcitiation,'), ('replace', 'ô', 'o'), ('replace', 'o', 'a'), ('delete', 'u', '')]
#    Corrected   : Nabarcitiation, les villes, un peu plus tôt ou un peu plus
#    Dif. Corr   : [('replace', '<...........>', 'Nabarcitiation,')]
#    CER corr vs GT: 0.2679, WER: 0.0909
#
#  File: ARCH-DIV-000494_0043.xml | Line 21
#    Ground Truth: tard, à la fin du XI^e siècle ou au commencement du XII, sont
#    HTR         : tard à le fen dn XI sert on au coimanement deu X0 tont
#    Dif. HTR    : [('delete', ',', ''), ('replace', 'à', 'à'), ('replace', 'a', 'e'), ('replace', 'i', 'e'), ('replace', 'u', 'n'), ('delete', '^e', ''), ('delete', 'iècl', ''), ('insert', '', 'rt'), ('replace', 'u', 'n'), ('insert', '', 'i'), ('replace', 'me', 'a'), ('delete', 'c', ''), ('insert', '', 'e'), ('replace', 'II,', '0'), ('replace', 's', 't')]
#    Corrected   : tard, à la fin du XI sert ou au commencement du XII sont
#    Dif. Corr   : [('delete', '^e', ''), ('delete', 'iècl', ''), ('insert', '', 'rt'), ('delete', ',', '')]
#    CER corr vs GT: 0.1311, WER: 0.2308
#
#  File: ARCH-DIV-000494_0043.xml | Line 22
#    Ground Truth: arrivées partout à leur bout. Elles constituent désormais
#    HTR         : arrivées partout à leur bst. Elles costituent dérooiara
#    Dif. HTR    : [('replace', 'à', 'à'), ('replace', 'ou', 's'), ('delete', 'n', ''), ('replace', 's', 'r'), ('insert', '', 'oia'), ('delete', 'm', ''), ('delete', 'is', '')]
#    Corrected   : arrivées partout à ̀ leur but. Elles constituent dérooiara
#    Dif. Corr   : [('insert', '', '̀ '), ('delete', 'o', ''), ('replace', 's', 'r'), ('insert', '', 'oia'), ('delete', 'm', ''), ('delete', 'is', '')]
#    CER corr vs GT: 0.1404, WER: 0.3750
#
#  File: ARCH-DIV-000494_0043.xml | Line 23
#    Ground Truth: personnes collectives
#    HTR         : fersones coblactivez
#    Dif. HTR    : [('replace', 'p', 'f'), ('delete', 'n', ''), ('insert', '', 'b'), ('replace', 'le', 'a'), ('replace', 's', 'z')]
#    Corrected   : fersones coblactivez
#    Dif. Corr   : [('replace', 'p', 'f'), ('delete', 'n', ''), ('insert', '', 'b'), ('replace', 'le', 'a'), ('replace', 's', 'z')]
#    CER corr vs GT: 0.2381, WER: 1.0000
#
#  File: ARCH-DIV-000494_0043.xml | Line 24
#    Ground Truth: des <.................> Leur population n'est plus un
#    HTR         : des <.......tabaict Leur papulation nisoples vse
#    Dif. HTR    : [('replace', '..........>', 'tabaict'), ('replace', 'o', 'a'), ('replace', "'", 'isopl'), ('delete', 't', ''), ('replace', 'plu', 'v'), ('replace', ' un', 'e')]
#    Corrected   : des <....... tabaict Leur population nisoples’
#    Dif. Corr   : [('replace', '..........>', ' tabaict'), ('replace', "'", 'isopl'), ('replace', 't plus un', '’')]
#    CER corr vs GT: 0.3585, WER: 0.7143
#
#  File: ARCH-DIV-000494_0043.xml | Line 25
#    Ground Truth: simple groupement d'hommes <...............> recon¬
#    HTR         : timpt Oroliperment d Nunils <....> rccon
#    Dif. HTR    : [('replace', 's', 't'), ('replace', 'le', 't'), ('replace', 'g', 'O'), ('replace', 'u', 'li'), ('insert', '', 'r'), ('replace', "'homme", ' Nunil'), ('delete', '...........', ''), ('replace', 'e', 'c'), ('delete', '¬', '')]
#    Corrected   : est Oroliperment un Nunils <....> rccon
#    Dif. Corr   : [('insert', '', 'e'), ('replace', 'imple', 't'), ('replace', 'g', 'O'), ('replace', 'u', 'li'), ('insert', '', 'r'), ('replace', "d'homme", 'un Nunil'), ('delete', '...........', ''), ('replace', 'e', 'c'), ('delete', '¬', '')]
#    CER corr vs GT: 0.6078, WER: 1.2000
#
#  File: ARCH-DIV-000494_0043.xml | Line 26
#    Ground Truth: naissable à ses caractères sociaux; Elle jouit d'un droit
#    HTR         : Naiseable à Les caractères tova. Elle jouit d'n troit
#    Dif. HTR    : [('replace', 'n', 'N'), ('replace', 's', 'e'), ('replace', 'à', 'à'), ('replace', 's', 'L'), ('replace', 's', 't'), ('replace', 'ci', 'v'), ('replace', 'ux;', '.'), ('delete', 'u', ''), ('replace', 'd', 't')]
#    Corrected   : Naiseable à ses caractères tova. Elle jouit d'un droit
#    Dif. Corr   : [('replace', 'n', 'N'), ('replace', 's', 'e'), ('replace', 'à', 'à'), ('replace', 's', 't'), ('replace', 'ci', 'v'), ('replace', 'ux;', '.')]
#    CER corr vs GT: 0.1754, WER: 0.3333
#
#  File: ARCH-DIV-000494_0043.xml | Line 27
#    Ground Truth: propre: elle est devenue une classe juridique. Comme la
#    HTR         : propre : ell est devenne ume classe pridique. Comme la
#    Dif. HTR    : [('insert', '', ' '), ('delete', 'e', ''), ('replace', 'u', 'n'), ('replace', 'n', 'm'), ('replace', 'ju', 'p')]
#    Corrected   : propre: elle est devenue une classe juridique. Comme la
#    Dif. Corr   : []
#    CER corr vs GT: 0.0000, WER: 0.0000
#
#  File: ARCH-DIV-000494_0043.xml | Line 28
#    Ground Truth: <.........................>
#    HTR         : ..blaqne .. ............. à .........
#    Dif. HTR    : [('replace', '<', '..blaqne .. '), ('insert', '', ' à '), ('delete', '...>', '')]
#    Corrected   : .. blaqne............... à.........
#    Dif. Corr   : [('replace', '<', '.. blaqne'), ('insert', '', ' à'), ('delete', '.>', '')]
#    CER corr vs GT: 0.4074, WER: 3.0000
#
#  File: ARCH-DIV-000494_0043.xml | Line 29
#    Ground Truth: <..........> noblesse, la bourgeoisie obtient
#    HTR         : reaovriit coinaaom Nobbars, le bourgevisic ottrent
#    Dif. HTR    : [('replace', '<..........>', 'reaovriit'), ('insert', '', 'coi'), ('insert', '', 'aaom N'), ('replace', 'le', 'bar'), ('delete', 'se', ''), ('replace', 'a', 'e'), ('replace', 'o', 'v'), ('replace', 'e', 'c'), ('delete', 'b', ''), ('replace', 'i', 'tr')]
#    Corrected   : reaovriit coinaaom Nobbars, la bourgeoisie obtient
#    Dif. Corr   : [('replace', '<..........>', 'reaovriit'), ('insert', '', 'coi'), ('insert', '', 'aaom N'), ('replace', 'le', 'bar'), ('delete', 'se', '')]
#    CER corr vs GT: 0.5111, WER: 0.6000
#
#  File: ARCH-DIV-000494_0043.xml | Line 30
#    Ground Truth: la reconnaissance légale. Pour celle-là la profession des ar¬
#    HTR         : la reconnaissanme légale. Paur celle-là la Grofission des ar¬
#    Dif. HTR    : [('replace', 'c', 'm'), ('replace', 'o', 'a'), ('replace', 'à', 'à'), ('replace', 'p', 'G'), ('replace', 'e', 'i')]
#    Corrected   : la reconnaissance légale. Pour celle-là ̀ la profession des ar¬
#    Dif. Corr   : [('insert', '', '̀ ')]
#    CER corr vs GT: 0.0328, WER: 0.1111
#
#  File: ARCH-DIV-000494_0043.xml | Line 31
#    Ground Truth: mes, pour celle-ci la profession du commerce et de l'indus¬
#    HTR         : Mes, pour celle. ci la professiondu commerce et de l'onds
#    Dif. HTR    : [('replace', 'm', 'M'), ('replace', '-', '. '), ('delete', ' ', ''), ('replace', 'i', 'o'), ('delete', 'u', ''), ('delete', '¬', '')]
#    Corrected   : mes, pour celle. ci la profession commerce et de l'onds
#    Dif. Corr   : [('replace', '-', '. '), ('delete', ' du', ''), ('replace', 'i', 'o'), ('delete', 'u', ''), ('delete', '¬', '')]
#    CER corr vs GT: 0.1356, WER: 0.4000
#
#  File: ARCH-DIV-000494_0043.xml | Line 32
#    Ground Truth: trie ont eu à la longue pour résultat la possesion offi¬
#    HTR         : tie ont en à la lonque pour résultat la possenion affi¬
#    Dif. HTR    : [('delete', 'r', ''), ('replace', 'u', 'n'), ('replace', 'à', 'à'), ('replace', 'g', 'q'), ('replace', 's', 'n'), ('replace', 'o', 'a')]
#    Corrected   : tie ont eu à ̀ la longue pour résultat la possession offi¬
#    Dif. Corr   : [('delete', 'r', ''), ('insert', '', ' ̀'), ('insert', '', 's')]
#    CER corr vs GT: 0.0714, WER: 0.2727
#
#  File: ARCH-DIV-000494_0043.xml | Line 33
#    Ground Truth: ciellement reconnue d'une situation privilégiée. Il im¬
#    HTR         : cellement recomnne d'onne tituatin pévilégiée. I vin¬
#    Dif. HTR    : [('delete', 'i', ''), ('insert', '', 'm'), ('delete', 'u', ''), ('replace', 'u', 'on'), ('replace', 's', 't'), ('delete', 'o', ''), ('replace', 'ri', 'é'), ('delete', 'l', ''), ('insert', '', 'v'), ('replace', 'm', 'n')]
#    Corrected   : ciellement reconnue d'une situation privilégiée. Il imp¬
#    Dif. Corr   : [('insert', '', 'p')]
#    CER corr vs GT: 0.0182, WER: 0.1429
#
#  File: ARCH-DIV-000494_0043.xml | Line 34
#    Ground Truth: porte d'analyser celle-ci et d'en reconnaître les caractères
#    HTR         : porte d'auabyeur cell-ci et d'en reconnaitie les carartère
#    Dif. HTR    : [('replace', 'n', 'u'), ('replace', 'l', 'b'), ('delete', 's', ''), ('insert', '', 'u'), ('delete', 'e', ''), ('replace', 'î', 'i'), ('replace', 'r', 'i'), ('replace', 'c', 'r'), ('delete', 's', '')]
#    Corrected   : orte d'analyser cell-ci et d'en reconnaître les caractères
#    Dif. Corr   : [('delete', 'p', ''), ('delete', 'e', '')]
#    CER corr vs GT: 0.0333, WER: 0.2500
#
#  File: ARCH-DIV-000494_0043.xml | Line 35
#    Ground Truth: spéciaux [ Ces caractères, faut-il le dire, ne sont point propres
#    HTR         : fpéciaux. Cn caractères, faut-il le dère, Uldent point Grrpres
#    Dif. HTR    : [('replace', 's', 'f'), ('replace', ' [', '.'), ('replace', 'es', 'n'), ('replace', 'i', 'è'), ('replace', 'n', 'Uld'), ('delete', ' so', ''), ('replace', 'p', 'G'), ('replace', 'o', 'r')]
#    Corrected   : spéciaux. Ces caractères, faut-il le dire, sont point propres
#    Dif. Corr   : [('replace', ' [', '.'), ('delete', 'ne ', '')]
#    CER corr vs GT: 0.0769, WER: 0.2727
#
#  File: ARCH-DIV-000494_0043.xml | Line 36
#    Ground Truth: aux Pays-Bas. La formation des villes, dans ses traits
#    HTR         : aus Poup. Bas. La formation des villes, dans ses traits
#    Dif. HTR    : [('replace', 'x', 's'), ('replace', 'ays-', 'oup. ')]
#    Corrected   : aux Pays. Bas. La formation du villes, dans ses traits
#    Dif. Corr   : [('replace', '-', '. '), ('replace', 'es', 'u')]
#    CER corr vs GT: 0.0741, WER: 0.3333
#
#  File: ARCH-DIV-000494_0043.xml | Line 37
#    Ground Truth: essentiels, a été la même dans les diverses parties de
#    HTR         : easentiels a été la même dans les diverr es parties de
#    Dif. HTR    : [('replace', 's', 'a'), ('delete', ',', ''), ('replace', 's', 'r ')]
#    Corrected   : essentiels a été la même dans les diverses es parties de
#    Dif. Corr   : [('delete', ',', ''), ('insert', '', 'es ')]
#    CER corr vs GT: 0.0741, WER: 0.2000
#
#  File: ARCH-DIV-000494_0043.xml | Line 38
#    Ground Truth: l'Europe. Elle ne constitue en rien un phénomène
#    HTR         : l'Enrope. Elt ne constitue en rieu un phénonien
#    Dif. HTR    : [('replace', 'u', 'n'), ('replace', 'le', 't'), ('replace', 'n', 'u'), ('delete', 'mè', ''), ('insert', '', 'i'), ('insert', '', 'n')]
#    Corrected   : l'Europe. Il ne constitue en rien un phénomène
#    Dif. Corr   : [('replace', 'E', 'I'), ('delete', 'le', '')]
#    CER corr vs GT: 0.0625, WER: 0.1250
#
#  File: ARCH-DIV-000494_0043.xml | Line 39
#    Ground Truth: national. Les <.........> économiques dont elle
#    HTR         : National. Les <. économiques dont elle
#    Dif. HTR    : [('replace', 'n', 'N'), ('delete', '........>', '')]
#    Corrected   : national. Les <. économiques dont il
#    Dif. Corr   : [('delete', '........>', ''), ('replace', 'e', 'i'), ('delete', 'le', '')]
#    CER corr vs GT: 0.2553, WER: 0.3333
#
#  File: ARCH-DIV-000494_0043.xml | Line 40
#    Ground Truth: transformations
#    HTR         : Traidiformations
#    Dif. HTR    : [('replace', 't', 'T'), ('replace', 'ns', 'idi')]
#    Corrected   : Traidiformations
#    Dif. Corr   : [('replace', 't', 'T'), ('replace', 'ns', 'idi')]
#    CER corr vs GT: 0.2667, WER: 1.0000
#
#  File: ARCH-DIV-000494_0043.xml | Line 41
#    Ground Truth: est la conséquence se sont déroulées parout avec des
#    HTR         : est la conséqueure de toit derau llls hartout pece des
#    Dif. HTR    : [('replace', 'nc', 'ur'), ('replace', 's', 'd'), ('replace', 's', 't'), ('replace', 'n', 'i'), ('replace', 'é', 'e'), ('replace', 'o', 'a'), ('insert', '', ' '), ('replace', 'ée', 'll'), ('replace', 'p', 'h'), ('insert', '', 't'), ('replace', 'av', 'p'), ('insert', '', 'e')]
#    Corrected   : est la conséquence se sont derau llls hartout pece des
#    Dif. Corr   : [('replace', 'é', 'e'), ('replace', 'o', 'a'), ('insert', '', ' '), ('replace', 'ée', 'll'), ('replace', 'p', 'h'), ('insert', '', 't'), ('replace', 'av', 'p'), ('insert', '', 'e')]
#    CER corr vs GT: 0.1923, WER: 0.4444
#
#  File: ARCH-DIV-000494_0043.xml | Line 42
#    Ground Truth: II
#    HTR         : 9
#    Dif. HTR    : [('replace', 'II', '9')]
#    Corrected   : 9
#    Dif. Corr   : [('replace', 'II', '9')]
#    CER corr vs GT: 1.0000, WER: 1.0000
#
#  File: ARCH-DIV-000494_0043.xml | Line 43
#    Ground Truth: à la ligne
#    HTR         : à la lyue,
#    Dif. HTR    : [('replace', 'ign', 'yu'), ('insert', '', ',')]
#    Corrected   : à la des,
#    Dif. Corr   : [('replace', 'lign', 'd'), ('insert', '', 's,')]
#    CER corr vs GT: 0.5000, WER: 0.3333
