# %%
## Regarder les erreurs

import os
import xml.etree.ElementTree as ET
from difflib import SequenceMatcher
from evaluate import load

ground_truth_folder = "manuscript_groundtruth"
htr_folder = "manuscript_htr24"
corrected_folder = "manuscript_final"

def extract_lines_from_alto(path):
    tree = ET.parse(path)
    root = tree.getroot()
    ns = {'a': 'http://www.loc.gov/standards/alto/ns-v4#'}
    strings = root.findall(".//a:String", ns)
    return [s.attrib.get("CONTENT", "").strip() for s in strings]

def diff_chars(s1, s2):
    sm = SequenceMatcher(None, s1, s2)
    return [(tag, s1[a:b], s2[c:d]) for tag, a, b, c, d in sm.get_opcodes() if tag != 'equal']

wer = load("wer")
cer = load("cer")

files = sorted(os.listdir(ground_truth_folder))
total_lines = 0

for filename in files:
    if not filename.endswith(".xml"):
        continue

    gt_path = os.path.join(ground_truth_folder, filename)
    htr_path = os.path.join(htr_folder, filename)
    corr_path = os.path.join(corrected_folder, filename)

    gt_lines = extract_lines_from_alto(gt_path)
    htr_lines = extract_lines_from_alto(htr_path)
    corr_lines = extract_lines_from_alto(corr_path)

    for i, (gt, htr, corr) in enumerate(zip(gt_lines, htr_lines, corr_lines)):
        htr_diff = diff_chars(gt, htr)
        corr_diff = diff_chars(gt, corr)
        wer_score = wer.compute(predictions=[corr], references=[gt])
        cer_score = cer.compute(predictions=[corr], references=[gt])

        print(f" File: {filename} | Line {i+1}")
        print(f"   Ground Truth: {gt}")
        print(f"   HTR         : {htr}")
        print(f"   Dif. HTR    : {htr_diff}")
        print(f"   Corrected   : {corr}")
        print(f"   Dif. Corr   : {corr_diff}")
        print(f"   CER corr vs GT: {cer_score:.4f}, WER: {wer_score:.4f}")
        print()
        total_lines += 1
# Out:
#  File: ARCH-DIV-000494_0037.xml | Line 1
#    Ground Truth: 29
#    HTR         : 29
#    Dif. HTR    : []
#    Corrected   : 29
#    Dif. Corr   : []
#    CER corr vs GT: 0.0000, WER: 0.0000
#
#  File: ARCH-DIV-000494_0037.xml | Line 2
#    Ground Truth: Chapitre II
#    HTR         : Chapitre "1
#    Dif. HTR    : [('replace', 'II', '"1')]
#    Corrected   : Chapitre " 1
#    Dif. Corr   : [('replace', 'II', '" 1')]
#    CER corr vs GT: 0.2727, WER: 1.0000
#
#  File: ARCH-DIV-000494_0037.xml | Line 3
#    Ground Truth: I
#    HTR         : 7
#    Dif. HTR    : [('replace', 'I', '7')]
#    Corrected   : 7
#    Dif. Corr   : [('replace', 'I', '7')]
#    CER corr vs GT: 1.0000, WER: 1.0000
#
#  File: ARCH-DIV-000494_0037.xml | Line 4
#    Ground Truth: Jusque vers le milieu du XI^e siècle, les princes
#    HTR         : pesique ver la Vi li en du Il sécle ls prunees
#    Dif. HTR    : [('replace', 'Ju', 'pe'), ('insert', '', 'i'), ('delete', 's', ''), ('replace', 'e', 'a'), ('replace', 'm', 'V'), ('insert', '', ' '), ('insert', '', ' '), ('replace', 'u', 'n'), ('delete', 'X', ''), ('replace', '^e', 'l'), ('replace', 'iè', 'é'), ('delete', ',', ''), ('delete', 'e', ''), ('replace', 'i', 'u'), ('replace', 'c', 'e')]
#    Corrected   : pesique ver du XI^e du, les ls prunees
#    Dif. Corr   : [('replace', 'Ju', 'pe'), ('insert', '', 'i'), ('delete', 's le milieu', ''), ('replace', 'siècle', 'du'), ('insert', '', 'ls '), ('replace', 'i', 'u'), ('replace', 'c', 'e')]
#    CER corr vs GT: 0.4490, WER: 0.7778
#
#  File: ARCH-DIV-000494_0037.xml | Line 5
#    Ground Truth: comme on l'a vu plus haut, ne se sont pas occupés
#    HTR         : commm on l'a vu plus haut, ne desont pas occupés
#    Dif. HTR    : [('replace', 'e', 'm'), ('replace', 's', 'd'), ('delete', ' ', '')]
#    Corrected   : comme on l'a vu plus haut, ne sont pas occupés
#    Dif. Corr   : [('delete', 'e s', '')]
#    CER corr vs GT: 0.0612, WER: 0.0909
#
#  File: ARCH-DIV-000494_0037.xml | Line 6
#    Ground Truth: des colonies marchandes. Abandonnées à elles-
#    HTR         : des colooies maritandes. Abandoinées à elleu¬
#    Dif. HTR    : [('replace', 'n', 'o'), ('replace', 'ch', 'it'), ('replace', 'n', 'i'), ('replace', 'à', 'à'), ('replace', 's-', 'u¬')]
#    Corrected   : des colonies marchandes. Abandonnées à elleu¬
#    Dif. Corr   : [('replace', 's-', 'u¬')]
#    CER corr vs GT: 0.0444, WER: 0.1667
#
#  File: ARCH-DIV-000494_0037.xml | Line 7
#    Ground Truth: simple
#    HTR         : simple
#    Dif. HTR    : []
#    Corrected   : simple
#    Dif. Corr   : []
#    CER corr vs GT: 0.0000, WER: 0.0000
#
#  File: ARCH-DIV-000494_0037.xml | Line 8
#    Ground Truth: mêmes, celles-ci ont créé un état de fait auquel
#    HTR         : mêmes, celle, cn ont créi iystat et fait auquel
#    Dif. HTR    : [('replace', 's-', ', '), ('replace', 'i', 'n'), ('replace', 'é', 'i'), ('replace', 'un é', 'iys'), ('delete', 'd', ''), ('insert', '', 't')]
#    Corrected   : mêmes, celles, ci ont créé état de fait auquel
#    Dif. Corr   : [('replace', '-', ', '), ('delete', ' un', '')]
#    CER corr vs GT: 0.1042, WER: 0.3333
#
#  File: ARCH-DIV-000494_0037.xml | Line 9
#    Ground Truth: manque, avec la consécration légale, toute garantie
#    HTR         : manque, aver la consicratin légale, toute garantie
#    Dif. HTR    : [('replace', 'c', 'r'), ('replace', 'é', 'i'), ('delete', 'o', '')]
#    Corrected   : manque, avec la consécration légale, toute garantie
#    Dif. Corr   : []
#    CER corr vs GT: 0.0000, WER: 0.0000
#
#  File: ARCH-DIV-000494_0037.xml | Line 10
#    Ground Truth: sérieuse de durée. Pour qu'il devienne un état de
#    HTR         : sériise de durie. Pour qu'il devienue tlp Etat de
#    Dif. HTR    : [('replace', 'eu', 'i'), ('replace', 'é', 'i'), ('replace', 'n', 'u'), ('replace', 'un', 'tlp'), ('replace', 'é', 'E')]
#    Corrected   : sérieuse de durée. Pour qu'il devienne un état de
#    Dif. Corr   : []
#    CER corr vs GT: 0.0000, WER: 0.0000
#
#  File: ARCH-DIV-000494_0037.xml | Line 11
#    Ground Truth: droit, pour que le portus se transforme en ville, et les
#    HTR         : droit, pou que le portus Syteans forme les ville et des
#    Dif. HTR    : [('delete', 'r', ''), ('replace', 's', 'Syt'), ('delete', ' tr', ''), ('insert', '', ' '), ('insert', '', 'l'), ('replace', 'n', 's'), ('delete', ',', ''), ('replace', 'l', 'd')]
#    Corrected   : droit, pour que le portus Syteans forme en ville et ses
#    Dif. Corr   : [('replace', 's', 'Syt'), ('delete', ' tr', ''), ('insert', '', ' '), ('delete', ',', ''), ('replace', 'l', 's')]
#    CER corr vs GT: 0.1250, WER: 0.3636
#
#  File: ARCH-DIV-000494_0037.xml | Line 12
#    Ground Truth: l'
#    HTR         : 11
#    Dif. HTR    : [('replace', "l'", '11')]
#    Corrected   : 11
#    Dif. Corr   : [('replace', "l'", '11')]
#    CER corr vs GT: 1.0000, WER: 1.0000
#
#  File: ARCH-DIV-000494_0037.xml | Line 13
#    Ground Truth: habitants en bourgeois, pour que enfin <....> auto¬
#    HTR         : tabitant en baugerii, pounque infin, Laveaai into¬
#    Dif. HTR    : [('replace', 'h', 't'), ('delete', 's', ''), ('replace', 'o', 'a'), ('delete', 'r', ''), ('replace', 'o', 'r'), ('replace', 's', 'i'), ('replace', 'r ', 'n'), ('replace', 'e', 'i'), ('insert', '', ','), ('replace', '<....>', 'Laveaai'), ('replace', 'au', 'in')]
#    Corrected   : habitants en bourgeois, pounque que, enfin into¬
#    Dif. Corr   : [('replace', 'r', 'nque'), ('insert', '', ','), ('replace', '<....> au', 'in')]
#    CER corr vs GT: 0.2745, WER: 0.5000
#
#  File: ARCH-DIV-000494_0037.xml | Line 14
#    Ground Truth: nomie qu'ils se sont donnée soit officiellement rati¬
#    HTR         : nomire qu'ils se tont dovmée doit officiellement rots
#    Dif. HTR    : [('insert', '', 'r'), ('replace', 's', 't'), ('replace', 'nn', 'vm'), ('replace', 's', 'd'), ('replace', 'a', 'o'), ('replace', 'i¬', 's')]
#    Corrected   : nomire qu'ils son tont dovmée soit officiellement rots
#    Dif. Corr   : [('insert', '', 'r'), ('replace', 'e', 'on'), ('replace', 's', 't'), ('replace', 'nn', 'vm'), ('replace', 'a', 'o'), ('replace', 'i¬', 's')]
#    CER corr vs GT: 0.1698, WER: 0.6250
#
#  File: ARCH-DIV-000494_0037.xml | Line 15
#    Ground Truth: fiée et que naissent les institutions qui doivent la
#    HTR         : fice et que naibent lls mititutiom qui doivent la
#    Dif. HTR    : [('replace', 'é', 'c'), ('replace', 'ss', 'b'), ('replace', 'e', 'l'), ('insert', '', 'm'), ('delete', 'ns', ''), ('replace', 'ns', 'm')]
#    Corrected   : fice et que naissent les institutions qui doivent la
#    Dif. Corr   : [('replace', 'é', 'c')]
#    CER corr vs GT: 0.0192, WER: 0.1111
#
#  File: ARCH-DIV-000494_0037.xml | Line 16
#    Ground Truth: compléter l'intervention du pouvoir public est
#    HTR         : compliter l'intervention des pouvoirs publets est
#    Dif. HTR    : [('replace', 'é', 'i'), ('replace', 'u', 'es'), ('insert', '', 's'), ('replace', 'ic', 'ets')]
#    Corrected   : compléter l'intervention du pouvoir public est
#    Dif. Corr   : []
#    CER corr vs GT: 0.0000, WER: 0.0000
#
#  File: ARCH-DIV-000494_0037.xml | Line 17
#    Ground Truth: indispensable. Elle est <......> en même temps iné¬
#    HTR         : indispeuarble. Ell est dradtaars en ménrle temps iné
#    Dif. HTR    : [('replace', 'ns', 'u'), ('insert', '', 'r'), ('delete', 'e', ''), ('replace', '<......>', 'dradtaars'), ('replace', 'êm', 'énrl'), ('delete', '¬', '')]
#    Corrected   : indispensable. Elle est dradtaars en même temps iné
#    Dif. Corr   : [('replace', '<......>', 'dradtaars'), ('delete', '¬', '')]
#    CER corr vs GT: 0.1961, WER: 0.2500
#
#  File: ARCH-DIV-000494_0037.xml | Line 18
#    Ground Truth: vitable. Car l'intensité croissante de la vie urbaine
#    HTR         : vitable. Car l'intenaité Civissante de la vie ilstaine
#    Dif. HTR    : [('replace', 's', 'a'), ('replace', 'cro', 'Civ'), ('replace', 'urb', 'ilst')]
#    Corrected   : vitable. Car l'intensité croissante de la vie urbaine
#    Dif. Corr   : []
#    CER corr vs GT: 0.0000, WER: 0.0000
#
#  File: ARCH-DIV-000494_0037.xml | Line 19
#    Ground Truth: va nécessairement attirer l'attention des princes et
#    HTR         : la nécessairement attirer l'attention des shuices et
#    Dif. HTR    : [('replace', 'v', 'l'), ('replace', 'pr', 'shu'), ('delete', 'n', '')]
#    Corrected   : va nécessairement attirer l'attention des princes et
#    Dif. Corr   : []
#    CER corr vs GT: 0.0000, WER: 0.0000
#
#  File: ARCH-DIV-000494_0037.xml | Line 20
#    Ground Truth: depuis lors, de siècle  en siècle, leurs rapports avec les
#    HTR         : deprrès lors de siecl on sictle, leurs rapports aves les
#    Dif. HTR    : [('replace', 'ui', 'rrè'), ('delete', ',', ''), ('replace', 'è', 'e'), ('delete', 'e', ''), ('replace', ' e', 'o'), ('delete', 'è', ''), ('insert', '', 't'), ('replace', 'c', 's')]
#    Corrected   : depuis lors de siècle en siècle, leurs rapports avec les
#    Dif. Corr   : [('delete', ',', ''), ('delete', ' ', '')]
#    CER corr vs GT: 0.0345, WER: 0.1000
#
#  File: ARCH-DIV-000494_0037.xml | Line 21
#    Ground Truth: villes ne cesseront plus de se multiplier et de se compliquer.
#    HTR         : Ailles Ne cencoont plus de se mulsiplier et de se compliquee
#    Dif. HTR    : [('replace', 'v', 'A'), ('replace', 'n', 'N'), ('replace', 'sser', 'nco'), ('replace', 't', 's'), ('replace', 'r.', 'e')]
#    Corrected   : villes ne cesseront plus de se multiplier et de se compliquer
#    Dif. Corr   : [('delete', '.', '')]
#    CER corr vs GT: 0.0161, WER: 0.0909
#
#  File: ARCH-DIV-000494_0037.xml | Line 22
#    Ground Truth: En général, dans les Pays-Bas, les princes laïques leur
#    HTR         : En générel dans le Payr. Bas, le prinles loïques Ceur
#    Dif. HTR    : [('replace', 'a', 'e'), ('delete', ',', ''), ('delete', 's', ''), ('replace', 's-', 'r. '), ('delete', 's', ''), ('replace', 'c', 'l'), ('replace', 'a', 'o'), ('replace', 'l', 'C')]
#    Corrected   : En général dans les Pays. Bas, les princes laïques leur
#    Dif. Corr   : [('delete', ',', ''), ('replace', '-', '. ')]
#    CER corr vs GT: 0.0545, WER: 0.3333
#
#  File: ARCH-DIV-000494_0037.xml | Line 23
#    Ground Truth: furent plus favorables que les princes ecclésiastiques.
#    HTR         : fuvent plus favorables que la peinces cccléciastiques
#    Dif. HTR    : [('replace', 'r', 'v'), ('replace', 'es', 'a'), ('replace', 'r', 'e'), ('replace', 'e', 'c'), ('replace', 's', 'c'), ('delete', '.', '')]
#    Corrected   : furent plus favorables que les princes ecclésiastiques
#    Dif. Corr   : [('delete', '.', '')]
#    CER corr vs GT: 0.0182, WER: 0.1429
#
#  File: ARCH-DIV-000494_0037.xml | Line 24
#    Ground Truth: Et il est très compréhensible qu'il en ait été ainsi. Les comtes
#    HTR         : Et il cet tris comprétemint le qu'il en ait étéanisi. Le cous¬
#    Dif. HTR    : [('insert', '', 'c'), ('delete', 's', ''), ('replace', 'è', 'i'), ('replace', 'h', 't'), ('insert', '', 'mi'), ('replace', 'sib', 't '), ('delete', ' ', ''), ('insert', '', 'n'), ('delete', 'n', ''), ('delete', 's', ''), ('replace', 'mte', 'u'), ('insert', '', '¬')]
#    Corrected   : Et il est très compréhensible le qu'il en ait étéanisi. Les comt¬
#    Dif. Corr   : [('insert', '', 'le '), ('delete', ' ', ''), ('insert', '', 'n'), ('delete', 'n', ''), ('replace', 'es', '¬')]
#    CER corr vs GT: 0.1250, WER: 0.3333
#
#  File: ARCH-DIV-000494_0037.xml | Line 25
#    Ground Truth: de Flandre, de Hainaut, de Hollande, les ducs de Brabant
#    HTR         : de Flandre de Rainant, d Holland. Ces ducs de Bratans
#    Dif. HTR    : [('delete', ',', ''), ('replace', 'H', 'R'), ('replace', 'u', 'n'), ('delete', 'e', ''), ('replace', 'e,', '.'), ('replace', 'l', 'C'), ('replace', 'b', 't'), ('replace', 't', 's')]
#    Corrected   : es Flandre de Hainaut, de Hollande. les ducs de Brabant
#    Dif. Corr   : [('delete', 'd', ''), ('insert', '', 's'), ('delete', ',', ''), ('replace', ',', '.')]
#    CER corr vs GT: 0.0714, WER: 0.3000
#
#  File: ARCH-DIV-000494_0037.xml | Line 26
#    Ground Truth: comme d'ailleurs toute la haute aristocratie du Moyen
#    HTR         : Coaae d Ailleurs toute la tante dus tocratie du moyta
#    Dif. HTR    : [('replace', 'c', 'C'), ('replace', 'mm', 'aa'), ('replace', "'a", ' A'), ('replace', 'h', 't'), ('replace', 'u', 'n'), ('replace', 'ari', 'du'), ('insert', '', ' '), ('replace', 'M', 'm'), ('replace', 'en', 'ta')]
#    Corrected   : comme d ailleurs toute la haute dus tocratie du Moyen
#    Dif. Corr   : [('replace', "'", ' '), ('replace', 'ari', 'du'), ('insert', '', ' ')]
#    CER corr vs GT: 0.0943, WER: 0.5000
#
#  File: ARCH-DIV-000494_0037.xml | Line 27
#    Ground Truth: <...> âge, n'étaient point sédentaires. Ils n'avaient pas
#    HTR         : tr age n'étaient point sidentaises. Ils n'avaient pas
#    Dif. HTR    : [('replace', '<...>', 'tr'), ('replace', 'â', 'a'), ('delete', ',', ''), ('replace', 'é', 'i'), ('replace', 'r', 's')]
#    Corrected   : âge, n'étaient point sédentaires. Ils n'avaient pas
#    Dif. Corr   : [('delete', '<...> ', '')]
#    CER corr vs GT: 0.1053, WER: 0.1250
#
#  File: ARCH-DIV-000494_0037.xml | Line 28
#    Ground Truth: de résidence fixe et <....> se déplaçaient continuel¬
#    HTR         : de résidence fixe et <..> se déplacaient contimnt¬
#    Dif. HTR    : [('delete', '..', ''), ('replace', 'ç', 'c'), ('insert', '', 'm'), ('replace', 'uel', 't')]
#    Corrected   : de résidence fixe et <..> se déplaçaient continue¬
#    Dif. Corr   : [('delete', '..', ''), ('delete', 'l', '')]
#    CER corr vs GT: 0.0566, WER: 0.2500
#
#  File: ARCH-DIV-000494_0037.xml | Line 29
#    Ground Truth: lement avec leur petite cour à travers leurs terres. Ne se
#    HTR         : Lemert, avec leur putiticoier, à travers lem terre. Nn se
#    Dif. HTR    : [('replace', 'l', 'L'), ('replace', 'n', 'r'), ('insert', '', ','), ('replace', 'e', 'u'), ('replace', 'e ', 'i'), ('replace', 'u', 'ie'), ('insert', '', ','), ('replace', 'à', 'à'), ('replace', 'urs', 'm'), ('delete', 's', ''), ('replace', 'e', 'n')]
#    Corrected   : llement, avec leur putiticoier, à travers leurs terres. Ne se
#    Dif. Corr   : [('insert', '', 'l'), ('insert', '', ','), ('replace', 'e', 'u'), ('replace', 'e ', 'i'), ('replace', 'u', 'ie'), ('insert', '', ',')]
#    CER corr vs GT: 0.1379, WER: 0.2727
#
#  File: ARCH-DIV-000494_0037.xml | Line 30
#    Ground Truth: trouvant point en contact permanent avec la popula
#    HTR         : trouvant point en contart permanent avec la papulg
#    Dif. HTR    : [('replace', 'c', 'r'), ('replace', 'o', 'a'), ('replace', 'a', 'g')]
#    Corrected   : trouvant point en contact permanent avec la papulg
#    Dif. Corr   : [('replace', 'o', 'a'), ('replace', 'a', 'g')]
#    CER corr vs GT: 0.0400, WER: 0.1250
#
#  File: ARCH-DIV-000494_0037.xml | Line 31
#    Ground Truth: tion urbaine, ils eurent donc peu d'occasions d'en¬
#    HTR         : tin vertaine, ils eurent dovc auais peu Loccasiom s'en¬
#    Dif. HTR    : [('delete', 'o', ''), ('replace', 'u', 've'), ('replace', 'b', 't'), ('replace', 'n', 'v'), ('insert', '', ' auais'), ('replace', "d'", 'L'), ('replace', 'n', 'm '), ('delete', ' d', '')]
#    Corrected   : tin urbaine, ils eurent donc auais peu Loccasiom’'en¬
#    Dif. Corr   : [('delete', 'o', ''), ('insert', '', 'auais '), ('replace', "d'", 'L'), ('replace', 'ns d', 'm’')]
#    CER corr vs GT: 0.2549, WER: 0.5000
#
#  File: ARCH-DIV-000494_0037.xml | Line 32
#    Ground Truth: trer en conflit avec elle. <........... ........ ..........>
#    HTR         : tier en conflit Avec elle. <.......... ...........>
#    Dif. HTR    : [('replace', 'r', 'i'), ('replace', 'a', 'A'), ('delete', '. ........', ''), ('insert', '', '.')]
#    Corrected   : trer en conflit avec elle. <.....................>
#    Dif. Corr   : [('delete', ' ........ ', '')]
#    CER corr vs GT: 0.1667, WER: 0.3750
#
#  File: ARCH-DIV-000494_0037.xml | Line 33
#    Ground Truth: <....................................>
#    HTR         : Haute ................. <...
#    Dif. HTR    : [('replace', '<', 'Haute '), ('insert', '', ' <'), ('delete', '................>', '')]
#    Corrected   : Haute................. <...
#    Dif. Corr   : [('replace', '<', 'Haute'), ('insert', '', ' <'), ('delete', '................>', '')]
#    CER corr vs GT: 0.4737, WER: 2.0000
#
#  File: ARCH-DIV-000494_0037.xml | Line 34
#    Ground Truth: <.......................> Avant le XIIe siècle, la
#    HTR         : <............ ..... ...t Anant le IoIi berle, la
#    Dif. HTR    : [('insert', '', ' '), ('insert', '', ' '), ('replace', '...>', 't'), ('replace', 'v', 'n'), ('delete', 'X', ''), ('insert', '', 'o'), ('insert', '', 'i b'), ('replace', ' sièc', 'r')]
#    Corrected   : <....................t Avant le XIIe siècle, la
#    Dif. Corr   : [('replace', '...>', 't')]
#    CER corr vs GT: 0.0800, WER: 0.1667
#
#  File: ARCH-DIV-000494_0037.xml | Line 35
#    Ground Truth: I
#    HTR         : 8
#    Dif. HTR    : [('replace', 'I', '8')]
#    Corrected   : 8
#    Dif. Corr   : [('replace', 'I', '8')]
#    CER corr vs GT: 1.0000, WER: 1.0000
#
#  File: ARCH-DIV-000494_0038.xml | Line 1
#    Ground Truth: 30
#    HTR         : 30
#    Dif. HTR    : []
#    Corrected   : 30
#    Dif. Corr   : []
#    CER corr vs GT: 0.0000, WER: 0.0000
#
#  File: ARCH-DIV-000494_0038.xml | Line 2
#    Ground Truth: son
#    HTR         : don
#    Dif. HTR    : [('replace', 's', 'd')]
#    Corrected   : don
#    Dif. Corr   : [('replace', 's', 'd')]
#    CER corr vs GT: 0.3333, WER: 1.0000
#
#  File: ARCH-DIV-000494_0038.xml | Line 3
#    Ground Truth: conduite qu'ils adoptèrent à <...> égard fut géné¬
#    HTR         : conduite qu'ils adoptèrent à seur egard fut geré¬
#    Dif. HTR    : [('replace', '<...>', 'seur'), ('replace', 'é', 'e'), ('replace', 'én', 'er')]
#    Corrected   : conduite qu'ils adoptèrent à son égard fut géné¬
#    Dif. Corr   : [('replace', '<...>', 'son')]
#    CER corr vs GT: 0.1000, WER: 0.1250
#
#  File: ARCH-DIV-000494_0038.xml | Line 4
#    Ground Truth: ralement pacifique. <...... ... ..... .. ....>
#    HTR         : ralament palifique. Baill biin....ave
#    Dif. HTR    : [('replace', 'e', 'a'), ('replace', 'c', 'l'), ('replace', '<', 'Baill biin'), ('replace', '.. ... ..... .. ....>', 'ave')]
#    Corrected   : ralement pacifique. Baill biin....ave
#    Dif. Corr   : [('replace', '<', 'Baill biin'), ('replace', '.. ... ..... .. ....>', 'ave')]
#    CER corr vs GT: 0.4565, WER: 0.7143
#
#  File: ARCH-DIV-000494_0038.xml | Line 5
#    Ground Truth: <.................................>
#    HTR         : <..... l. vll.......... ......àsofer
#    Dif. HTR    : [('insert', '', '..... l. vll'), ('insert', '', ' '), ('replace', '.................>', 'àsofer')]
#    Corrected   : <..... l. vll................àsofer
#    Dif. Corr   : [('insert', '', '..... l. vll'), ('replace', '.................>', 'àsofer')]
#    CER corr vs GT: 0.3429, WER: 3.0000
#
#  File: ARCH-DIV-000494_0038.xml | Line 6
#    Ground Truth: <.....> De leur côté, les villes n'eurent garde <........>
#    HTR         : <..r De leur côté, le villes nneurent garde <......>
#    Dif. HTR    : [('replace', '...>', 'r'), ('delete', 's', ''), ('replace', "'", 'n'), ('delete', '..', '')]
#    Corrected   : <..r De leur côté, les villes eurent garde <......>
#    Dif. Corr   : [('replace', '...>', 'r'), ('delete', "n'", ''), ('delete', '..', '')]
#    CER corr vs GT: 0.1379, WER: 0.3333
#
#  File: ARCH-DIV-000494_0038.xml | Line 7
#    Ground Truth: d'inquiéter
#    HTR         : d'inquiéter
#    Dif. HTR    : []
#    Corrected   : d'inquiéter
#    Dif. Corr   : []
#    CER corr vs GT: 0.0000, WER: 0.0000
#
#  File: ARCH-DIV-000494_0038.xml | Line 8
#    Ground Truth: <..... > un pouvoir qui les protégeait contre les
#    HTR         : <....... cer pouviier qui les protégeait conte les
#    Dif. HTR    : [('insert', '', '..'), ('replace', '> un', 'cer'), ('delete', 'o', ''), ('insert', '', 'ie'), ('delete', 'r', '')]
#    Corrected   : <....... cer pouvoir qui les protégeait contre les
#    Dif. Corr   : [('insert', '', '..'), ('replace', '> un', 'cer')]
#    CER corr vs GT: 0.1020, WER: 0.3333
#
#  File: ARCH-DIV-000494_0038.xml | Line 9
#    Ground Truth: petits seigneurs locaux, voisins gênants et dange¬
#    HTR         : petit seigneurs locaux, voigins géirants et dange¬
#    Dif. HTR    : [('delete', 's', ''), ('replace', 's', 'g'), ('replace', 'ên', 'éir')]
#    Corrected   : petits seigneurs locaux, voisins gênants et dange¬
#    Dif. Corr   : []
#    CER corr vs GT: 0.0000, WER: 0.0000
#
#  File: ARCH-DIV-000494_0038.xml | Line 10
#    Ground Truth: reux, et <... .....> s'abstenait d'intervenir dans
#    HTR         : reux, et taidaaan s'abtenait d'intervenir dars
#    Dif. HTR    : [('replace', '<... .....>', 'taidaaan'), ('delete', 's', ''), ('replace', 'n', 'r')]
#    Corrected   : que
#    Dif. Corr   : [('replace', 'r', 'qu'), ('delete', "ux, et <... .....> s'abstenait d'intervenir dans", '')]
#    CER corr vs GT: 0.9600, WER: 1.0000
#
#  File: ARCH-DIV-000494_0038.xml | Line 11
#    Ground Truth: qui
#    HTR         : que
#    Dif. HTR    : [('replace', 'i', 'e')]
#    Corrected   : reux, et taidaaan s'abstenait d'intervenir dans
#    Dif. Corr   : [('replace', 'q', 're'), ('insert', '', 'x, et ta'), ('insert', '', "daaan s'abstenait d'intervenir dans")]
#    CER corr vs GT: 15.0000, WER: 6.0000
#
#  File: ARCH-DIV-000494_0038.xml | Line 12
#    Ground Truth: leurs affaires. <........ ....... ..... ......>
#    HTR         : leurs affaires. w...................>
#    Dif. HTR    : [('replace', '<', 'w'), ('delete', ' ', ''), ('delete', ' ..... ..', '')]
#    Corrected   : leurs affaires. w...................>
#    Dif. Corr   : [('replace', '<', 'w'), ('delete', ' ', ''), ('delete', ' ..... ..', '')]
#    CER corr vs GT: 0.2340, WER: 0.6667
#
#  File: ARCH-DIV-000494_0038.xml | Line 13
#    Ground Truth: <.........>
#    HTR         : Lovoynôtoltiq.
#    Dif. HTR    : [('replace', '<', 'Lovoynôtoltiq'), ('delete', '........>', '')]
#    Corrected   : Lovoynôtoltiq.
#    Dif. Corr   : [('replace', '<', 'Lovoynôtoltiq'), ('delete', '........>', '')]
#    CER corr vs GT: 1.2727, WER: 1.0000
#
#  File: ARCH-DIV-000494_0038.xml | Line 14
#    Ground Truth: Mais les évêques se trouvaient dans une situa¬
#    HTR         : Mais les criques se trouvaient dans une sitra¬
#    Dif. HTR    : [('replace', 'évê', 'cri'), ('replace', 'u', 'r')]
#    Corrected   : Mais les évêques se trouvaient dans une situa¬
#    Dif. Corr   : []
#    CER corr vs GT: 0.0000, WER: 0.0000
#
#  File: ARCH-DIV-000494_0038.xml | Line 15
#    Ground Truth: tion toute différente. <.........> Établis à demeure
#    HTR         : tins toute diffirente. Babibagate Etablis a Slincure
#    Dif. HTR    : [('delete', 'o', ''), ('insert', '', 's'), ('replace', 'é', 'i'), ('replace', '<.........>', 'Babibagate'), ('replace', 'É', 'E'), ('replace', 'à', 'a'), ('replace', 'deme', 'Slinc')]
#    Corrected   : tion toute différente. Babibagate Etablis a demeure
#    Dif. Corr   : [('replace', '<.........>', 'Babibagate'), ('replace', 'É', 'E'), ('replace', 'à', 'a')]
#    CER corr vs GT: 0.2500, WER: 0.4286
#
#  File: ARCH-DIV-000494_0038.xml | Line 16
#    Ground Truth: étaient forcés par là
#    HTR         : étaienf forcispar la
#    Dif. HTR    : [('replace', 't', 'f'), ('replace', 'é', 'i'), ('delete', ' ', ''), ('replace', 'à', 'a')]
#    Corrected   : étaienf forcispar la
#    Dif. Corr   : [('replace', 't', 'f'), ('replace', 'é', 'i'), ('delete', ' ', ''), ('replace', 'à', 'a')]
#    CER corr vs GT: 0.1905, WER: 1.0000
#
#  File: ARCH-DIV-000494_0038.xml | Line 17
#    Ground Truth: dans leurs cités <......>, ils <...... .......>
#    HTR         : dam leurs ciths <..... ils .ratt.......> e
#    Dif. HTR    : [('replace', 'ns', 'm'), ('replace', 'é', 'h'), ('delete', '.>,', ''), ('delete', '<', ''), ('replace', '..... ', 'ratt'), ('insert', '', ' e')]
#    Corrected   : dans leurs cités <..... ils.ratt.......> e
#    Dif. Corr   : [('delete', '.>,', ''), ('delete', ' <', ''), ('replace', '..... ', 'ratt'), ('insert', '', ' e')]
#    CER corr vs GT: 0.2766, WER: 0.5714
#
#  File: ARCH-DIV-000494_0038.xml | Line 18
#    Ground Truth: <....> d'entretenir avec les habitants de celles-ci des rela¬
#    HTR         : opnentieteur avec ls tabitant de celles, en ells rula
#    Dif. HTR    : [('replace', "<....> d'", 'opn'), ('replace', 'r', 'i'), ('replace', 'ni', 'u'), ('delete', 'e', ''), ('replace', 'h', 't'), ('delete', 's', ''), ('replace', '-ci', ','), ('delete', 'd', ''), ('insert', '', 'n ell'), ('replace', 'e', 'u'), ('delete', '¬', '')]
#    Corrected   : entretenir avec les habitants de celles, ci des rula
#    Dif. Corr   : [('delete', "<....> d'", ''), ('replace', '-', ', '), ('replace', 'e', 'u'), ('delete', '¬', '')]
#    CER corr vs GT: 0.2131, WER: 0.5556
#
#  File: ARCH-DIV-000494_0038.xml | Line 19
#    Ground Truth: tions journalières et de <.....>s'intéresser à leurs faits et
#    HTR         : tion janalies et te tadaientérener De leurs faits et
#    Dif. HTR    : [('delete', 's', ''), ('replace', 'our', 'a'), ('delete', 'èr', ''), ('replace', 'd', 't'), ('replace', "<.....>s'", 'tada'), ('insert', '', 'e'), ('replace', 'ss', 'n'), ('replace', 'à', 'De')]
#    Corrected   : tion janalies et de tadaientérener De leurs faits et
#    Dif. Corr   : [('delete', 's', ''), ('replace', 'our', 'a'), ('delete', 'èr', ''), ('replace', "<.....>s'", 'tada'), ('insert', '', 'e'), ('replace', 'ss', 'n'), ('replace', 'à', 'De')]
#    CER corr vs GT: 0.3279, WER: 0.4444
#
#  File: ARCH-DIV-000494_0038.xml | Line 20
#    Ground Truth: professaient
#    HTR         : professailent
#    Dif. HTR    : [('insert', '', 'l')]
#    Corrected   : professailent
#    Dif. Corr   : [('insert', '', 'l')]
#    CER corr vs GT: 0.0833, WER: 1.0000
#
#  File: ARCH-DIV-000494_0038.xml | Line 21
#    Ground Truth: gestes. Plus cultivés que les laïques, ils <.......> en
#    HTR         : gestes. Plus culttwéxs que les laïques, ils <....t on
#    Dif. HTR    : [('replace', 'iv', 'tw'), ('insert', '', 'x'), ('replace', '...>', 't'), ('replace', 'e', 'o')]
#    Corrected   : gestes. Plus cultivés que les laïques, ils <....t en
#    Dif. Corr   : [('replace', '...>', 't')]
#    CER corr vs GT: 0.0727, WER: 0.1111
#
#  File: ARCH-DIV-000494_0038.xml | Line 22
#    Ground Truth: une théorie
#    HTR         : ure théoril
#    Dif. HTR    : [('replace', 'n', 'r'), ('replace', 'e', 'l')]
#    Corrected   : ure théoril
#    Dif. Corr   : [('replace', 'n', 'r'), ('replace', 'e', 'l')]
#    CER corr vs GT: 0.1818, WER: 1.0000
#
#  File: ARCH-DIV-000494_0038.xml | Line 23
#    Ground Truth: outre <........> de gouvernement reposant sur
#    HTR         : oetre titértairidiat Oegouvernement reposant tur
#    Dif. HTR    : [('replace', 'u', 'e'), ('replace', '<........>', 'titértairidiat'), ('replace', 'd', 'O'), ('delete', ' ', ''), ('replace', 's', 't')]
#    Corrected   : outre titértairidiat gouvernement reposant sur
#    Dif. Corr   : [('replace', '<........> ', 'titértairi'), ('replace', 'e', 'iat')]
#    CER corr vs GT: 0.3111, WER: 0.3333
#
#  File: ARCH-DIV-000494_0038.xml | Line 24
#    Ground Truth: spirituelle
#    HTR         : apriritueble
#    Dif. HTR    : [('replace', 's', 'a'), ('insert', '', 'r'), ('replace', 'l', 'b')]
#    Corrected   : apriritueble
#    Dif. Corr   : [('replace', 's', 'a'), ('insert', '', 'r'), ('replace', 'l', 'b')]
#    CER corr vs GT: 0.2727, WER: 1.0000
#
#  File: ARCH-DIV-000494_0038.xml | Line 25
#    Ground Truth: le double principe de l'obéissance à l'autorité <....>
#    HTR         : le Aortble paincipe de l'obcisrance à l'autorite ...
#    Dif. HTR    : [('replace', 'd', 'A'), ('replace', 'u', 'rt'), ('replace', 'r', 'a'), ('replace', 'é', 'c'), ('replace', 's', 'r'), ('replace', 'à', 'à'), ('replace', 'é', 'e'), ('delete', '<', ''), ('delete', '.>', '')]
#    Corrected   : le double principe de l'obéissance à l'autorité...
#    Dif. Corr   : [('delete', ' <', ''), ('delete', '.>', '')]
#    CER corr vs GT: 0.0741, WER: 0.2500
#
#  File: ARCH-DIV-000494_0038.xml | Line 26
#    Ground Truth: et à l'autorité temporelle, toutes deux émanées de
#    HTR         : et à l'autorité temporelle, toutes deux emanées de
#    Dif. HTR    : [('replace', 'à', 'à'), ('replace', 'é', 'e')]
#    Corrected   : et à l'autorité temporelle, toutes deux émanées de
#    Dif. Corr   : []
#    CER corr vs GT: 0.0000, WER: 0.0000
#
#  File: ARCH-DIV-000494_0038.xml | Line 27
#    Ground Truth: Dieu même. A Liège, à Utrecht, à Cambrai, les prélats
#    HTR         : Dien même. A Liège, à Utrcht à Camtran, les prélats
#    Dif. HTR    : [('replace', 'u', 'n'), ('replace', 'à', 'à'), ('delete', 'e', ''), ('delete', ',', ''), ('replace', 'à', 'à'), ('replace', 'b', 't'), ('replace', 'i', 'n')]
#    Corrected   : Dieu même. A Liège, à Utrecht à Cambrai, les prélats
#    Dif. Corr   : [('delete', ',', '')]
#    CER corr vs GT: 0.0189, WER: 0.1000
